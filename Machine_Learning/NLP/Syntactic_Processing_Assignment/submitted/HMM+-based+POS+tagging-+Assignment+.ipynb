# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries
import nltk
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import random
from operator import itemgetter

# %% [markdown]
# ### Downloading - nltk 'universal tagset'

# %%
import nltk
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\viki\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
nltk_data[:5]
# Out:
# [[('Pierre', 'NOUN'),
#   ('Vinken', 'NOUN'),
#   (',', '.'),
#   ('61', 'NUM'),
#   ('years', 'NOUN'),
#   ('old', 'ADJ'),
#   (',', '.'),
#   ('will', 'VERB'),
#   ('join', 'VERB'),
#   ('the', 'DET'),
#   ('board', 'NOUN'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('nonexecutive', 'ADJ'),
#   ('director', 'NOUN'),
#   ('Nov.', 'NOUN'),
#   ('29', 'NUM'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Vinken', 'NOUN'),
#   ('is', 'VERB'),
#   ('chairman', 'NOUN'),
#   ('of', 'ADP'),
#   ('Elsevier', 'NOUN'),
#   ('N.V.', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Dutch', 'NOUN'),
#   ('publishing', 'VERB'),
#   ('group', 'NOUN'),
#   ('.', '.')],
#  [('Rudolph', 'NOUN'),
#   ('Agnew', 'NOUN'),
#   (',', '.'),
#   ('55', 'NUM'),
#   ('years', 'NOUN'),
#   ('old', 'ADJ'),
#   ('and', 'CONJ'),
#   ('former', 'ADJ'),
#   ('chairman', 'NOUN'),
#   ('of', 'ADP'),
#   ('Consolidated', 'NOUN'),
#   ('Gold', 'NOUN'),
#   ('Fields', 'NOUN'),
#   ('PLC', 'NOUN'),
#   (',', '.'),
#   ('was', 'VERB'),
#   ('named', 'VERB'),
#   ('*-1', 'X'),
#   ('a', 'DET'),
#   ('nonexecutive', 'ADJ'),
#   ('director', 'NOUN'),
#   ('of', 'ADP'),
#   ('this', 'DET'),
#   ('British', 'ADJ'),
#   ('industrial', 'ADJ'),
#   ('conglomerate', 'NOUN'),
#   ('.', '.')],
#  [('A', 'DET'),
#   ('form', 'NOUN'),
#   ('of', 'ADP'),
#   ('asbestos', 'NOUN'),
#   ('once', 'ADV'),
#   ('used', 'VERB'),
#   ('*', 'X'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('make', 'VERB'),
#   ('Kent', 'NOUN'),
#   ('cigarette', 'NOUN'),
#   ('filters', 'NOUN'),
#   ('has', 'VERB'),
#   ('caused', 'VERB'),
#   ('a', 'DET'),
#   ('high', 'ADJ'),
#   ('percentage', 'NOUN'),
#   ('of', 'ADP'),
#   ('cancer', 'NOUN'),
#   ('deaths', 'NOUN'),
#   ('among', 'ADP'),
#   ('a', 'DET'),
#   ('group', 'NOUN'),
#   ('of', 'ADP'),
#   ('workers', 'NOUN'),
#   ('exposed', 'VERB'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('it', 'PRON'),
#   ('more', 'ADV'),
#   ('than', 'ADP'),
#   ('30', 'NUM'),
#   ('years', 'NOUN'),
#   ('ago', 'ADP'),
#   (',', '.'),
#   ('researchers', 'NOUN'),
#   ('reported', 'VERB'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('asbestos', 'NOUN'),
#   ('fiber', 'NOUN'),
#   (',', '.'),
#   ('crocidolite', 'NOUN'),
#   (',', '.'),
#   ('is', 'VERB'),
#   ('unusually', 'ADV'),
#   ('resilient', 'ADJ'),
#   ('once', 'ADP'),
#   ('it', 'PRON'),
#   ('enters', 'VERB'),
#   ('the', 'DET'),
#   ('lungs', 'NOUN'),
#   (',', '.'),
#   ('with', 'ADP'),
#   ('even', 'ADV'),
#   ('brief', 'ADJ'),
#   ('exposures', 'NOUN'),
#   ('to', 'PRT'),
#   ('it', 'PRON'),
#   ('causing', 'VERB'),
#   ('symptoms', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-1', 'X'),
#   ('show', 'VERB'),
#   ('up', 'PRT'),
#   ('decades', 'NOUN'),
#   ('later', 'ADJ'),
#   (',', '.'),
#   ('researchers', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('*T*-2', 'X'),
#   ('.', '.')]]

# %% [markdown]
# ### Splitting into Train and Test set (Validation set) (95:5)

# %%
# Splitting into train and test
#random.seed(1234)
train_set, test_set = train_test_split(nltk_data,train_size = 0.95)
print("Lenght of NTLK ('universal tagset'):",len(nltk_data))
print("Length of train dataset:",len(train_set))
print("Length of test dataset:",len(test_set))
# Out:
# Lenght of NTLK ('universal tagset'): 3914
# Length of train dataset: 3718
# Length of test dataset: 196

# %% [markdown]
# ### View - train data for better understanding

# %%
train_set[:2]
# Out:
# [[('Arbitrage', 'NOUN'),
#   ('simply', 'ADV'),
#   ('transfers', 'VERB'),
#   ('his', 'PRON'),
#   ('selling', 'NOUN'),
#   ('pressure', 'NOUN'),
#   ('from', 'ADP'),
#   ('Chicago', 'NOUN'),
#   ('to', 'PRT'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   (',', '.'),
#   ('while', 'ADP'),
#   ('*-1', 'X'),
#   ('functioning', 'VERB'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('buyer', 'NOUN'),
#   ('in', 'ADP'),
#   ('Chicago', 'NOUN'),
#   ('.', '.')],
#  [('*-64', 'X'),
#   ('Founded', 'VERB'),
#   ('as', 'ADP'),
#   ('the', 'DET'),
#   ('Examiner', 'NOUN'),
#   ('in', 'ADP'),
#   ('1903', 'NUM'),
#   ('by', 'ADP'),
#   ('Mr.', 'NOUN'),
#   ('Hearst', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Herald', 'NOUN'),
#   ('was', 'VERB'),
#   ('crippled', 'VERB'),
#   ('*-64', 'X'),
#   ('by', 'ADP'),
#   ('a', 'DET'),
#   ('bitter', 'ADJ'),
#   (',', '.'),
#   ('decade-long', 'ADJ'),
#   ('strike', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-1', 'X'),
#   ('began', 'VERB'),
#   ('in', 'ADP'),
#   ('1967', 'NUM'),
#   ('and', 'CONJ'),
#   ('cut', 'VERB'),
#   ('circulation', 'NOUN'),
#   ('in', 'ADP'),
#   ('half', 'DET'),
#   ('.', '.')]]

# %%
# Getting list of tagged words
train_tagged_words_list = [tup for sent in train_set for tup in sent]
len(train_tagged_words_list)
# Out:
# 95896

# %% [markdown]
# ### View train_tagged_words_list for better understanding

# %%
train_tagged_words_list[:5]
# Out:
# [('Arbitrage', 'NOUN'),
#  ('simply', 'ADV'),
#  ('transfers', 'VERB'),
#  ('his', 'PRON'),
#  ('selling', 'NOUN')]

# %% [markdown]
# ### Words from train_tagged_words_list

# %%
words = [ i[0] for i in train_tagged_words_list]
words = set(words)
print(words)
# Out:
# {'rates', 'times', 'future', 'Vegas', 'video-viewing', 'lore', 'Weisfield', 'Zenith', 'Think', 'exchanging', 'emigres', 'tutorials', 'Though', 'incomplete', 'Powers', 'stressing', 'form', 'Africa', '1997', 'loops', 'upper', 'corporations', 'Palestine', 'Sterling', 'trend', '*T*-122', 'Yoshihashi', 'Factory', 'subskills', 'Jennison', 'Shepperd', 'PETS', '95,142', 'Dallas', '2.5', '29.3', 'breathe', 'preference', 'Fairlawn', 'reacted', 'protesters', 'inventory', '1987', 'Sable', 'longer', 'subscription', 'masters', 'overcome', 'administrators', 'Optical', 'intellectual', '1.5', 'lowest', 'gyrations', 'served', 'reviewing', 'forest-product', '*-72', 'wear', 'Investments', 'Every', 'Duke', 'triggered', 'Pacific', 'fallen', 'prohibited', 'appropriators', 'deposit', 'noncompetitively', 'Edison', 'Chinchon', 'prefecture', 'omnipresent', 'extremely', 'resignation', 'wires', 'street', '4.25', '0.3', 'carefully', 'pie', '1,050,000', '8.1', 'conversations', 'Utsumi', 'praised', 'Image', 'occupant', 'maintenance', '130.6', 'Cincinnati', 'Dominion', 'R.D.', 'insured', '605', 'unattractive', 'mergers', 'absurdity', 'Hubbell', 'substance', 'words', 'Radio', 'intervention', 'wrists', 'crippled', 'polystyrene', 'exists', '11\\/16', 'pick-up', 'court-ordered', 'reaching', 'simultaneous', 'succeeded', 'Criticism', '13.8', 'Opportunity', '271-147', 'respect', 'fragmentation', 'virtually', 'exceedingly', 'discuss', 'Higher', 'overlap', '*T*-214', 'Although', 'market', 'ratings', 'cattle', 'bloods', 'ROGERS', '1:30', 'throughout', 'Wheeland', 'computerized', 'gut-wrenching', 'Commissions', 'confuse', 'attractions', 'Herbert', 'how-to', 'Precious', 'spark', 'Des', 'assemble', 'bombers', 'seasonally', 'problem', 'articles', 'faced', 'each', 'bronze', 'adapted', 'diaper', 'mothers', 'preparatives', 'Cheese', '*T*-176', 'of', 'test-preparation', '23.4', 'fire', '13.15', 'compiled', 'expectation', 'looming', 'joint', 'prevents', 'bowed', 'park', 'Gerald', 'try', 'Biedermann', 'serve', 'normally', 'F.W.', 'Schmidt', 'expire', 'above-market', 'status', 'F.', '16,000', 'loathsome', 'taxpayer', 'Mogavero', 'avenues', '*T*-259', 'cleared', 'Overall', 'volatility', 'letters', 'drinks', 'mid-size', 'Opus', 'Poore', 'silicone', 'Allen', 'insurance', 'railings', 'harped', 'pocket', 'peal', 'rule', 'additions', 'men', 'promised', 'accrue', 'majority', 'truck', 'Insight', '102', 'accounted', 'Lowe', 'extended', 'Gotta', 'Tiphook', '225', 'upward', 'improves', 'given', 'hormone', '22', 'sketch', 'stigma', 'WayMar', 'consistent', 'refuse', 'newspaper-printing', 'Orange', 'vicissitudes', '28', 'Elco', 'What', 'intended', 'Ford', 'benefits', 'chemicals', 'tailoring', 'Florio', 'disputes', '*T*-180', 'appeared', 'utterly', 'breathtaking', 'three-lawyer', 'temptation', 'agenda', 'Stephen', 'appropriated', 'exhibited', 'municipal', 'attack', 'six-bottle', 'Lauderhill', 'imposes', 'entrench', 'Dallara', '1985', 'deficit', 'intellectual-property', 'platinum', 'Funny', 'beer', 'exceeding', '*-51', 'SCI', 'helm', 'directed', 'specific', 'overnight', 'increasingly', 'Dai-Ichi', 'experienced', 'rolled', 'Holding', 'issued', 'COPPER', 'waived', 'stresses', 'drunk', '59.6', 'Tache', 'Hoosier', 'impressed', 'passions', 'traced', 'distinguished', 'Groton', '2,000', 'Reed', 'require', 'emerges', 'good-faith', 'angle', 'limited-partnership', 'Harvard', 'Avenue', '*-89', 'tender', 'Ganes', 'Earle', 'Goodman', 'luck', '*-121', 'distorted', 'fetal', 'designations', 'steeper', 'condition', 'experts', 'Insurance', 'mind-boggling', 'critical', 'influential', 'letter', '188.84', 'explore', '83', 'thinking', 'X', 'attributed', 'Mississippi', '3.625', '*-149', 'Creek', 'Jim', '*-91', 'eligible', "'30s", 'one-week', 'bitterness', 'IRS', 'limitation', 'Analysts', 'Solaia', 'bids', 'Orleans', 'O.', 'friendly', 'resilient', '35', 'manufacturing', 'spurns', 'ambassador', 'replicated', 'Sacramento-based', 'investments', 'painted', '*-79', 'Islamabad', 'learning', 'Tramp', 'existing', 'Achievement' ...

# %% [markdown]
# ### Tags from train_tagged_words_list

# %%
tags = [ i[1] for i in train_tagged_words_list]
tags = set(tags)
print(tags)
# Out:
# {'PRON', 'PRT', '.', 'X', 'DET', 'ADV', 'NUM', 'NOUN', 'ADP', 'VERB', 'ADJ', 'CONJ'}

# %% [markdown]
# ##### Hidden Markov Model( HMM)

# %% [markdown]
# **Emission Probability** of a word 'w' for tag 't':
# P(w|t) = Number of times w has been tagged t /Number of times t appears <br>
# **Transition Probability** of tag t1 followed by tag t2:
# P(t2|t1) = Number of times t1 is followed by tag t2 / Number of times t1 appears

# %% [markdown]
# #### Emission Probability

# %%
# compute word given tag: Emission Probability
# returns count_w_given_tag, count_tag
# count_w_given_tag - Number of times the word has been assigned to the tag
# count_tag - Number of times the tag is present in the corpus
def word_given_tag(word, tag, train_bag = train_tagged_words_list):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)    
    return (count_w_given_tag, count_tag)

# %% [markdown]
# #### Transition Probability

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability
# count_t2_t1 - Number times tag1 followed by tag2
# count_t1 - Number of times tag1 appears in the corpus

def t2_given_t1(t2, t1, train_bag = train_tagged_words_list):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len(tags), len(tags)), dtype='float32')
tags_matrix
for i, t1 in enumerate(list(tags)):
    for j, t2 in enumerate(list(tags)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]
tags_matrix
# Out:
# array([[8.09560530e-03, 1.27216652e-02, 4.04780246e-02, 9.36777145e-02,
#         1.00231301e-02, 3.39244418e-02, 7.71010015e-03, 2.07401693e-01,
#         2.19737850e-02, 4.84579802e-01, 7.40169659e-02, 5.39707020e-03],
#        [1.77165363e-02, 1.96850393e-03, 4.36351709e-02, 1.34514440e-02,
#         1.00721784e-01, 9.51443613e-03, 5.83989508e-02, 2.46719167e-01,
#         2.03412082e-02, 3.98293972e-01, 8.72703418e-02, 1.96850393e-03],
#        [6.51375353e-02, 2.50873575e-03, 9.16584507e-02, 2.71481052e-02,
#         1.74536332e-01, 5.21458648e-02, 8.22506920e-02, 2.21754327e-01,
#         9.09416750e-02, 8.94185081e-02, 4.45300601e-02, 5.78801185e-02],
#        [5.56083657e-02, 1.82034224e-01, 1.64448664e-01, 7.55703449e-02,
#         5.54499365e-02, 2.48732567e-02, 2.85171112e-03, 6.27376437e-02,
#         1.44486696e-01, 2.04214200e-01, 1.71102658e-02, 1.06147025e-02],
#        [3.49819055e-03, 2.41254529e-04, 1.73703264e-02, 4.55971062e-02,
#         5.54885389e-03, 1.27864899e-02, 2.18335353e-02, 6.39806986e-01,
#         9.52955335e-03, 3.94451134e-02, 2.03860074e-01, 4.82509058e-04],
#        [1.46471374e-02, 1.49800265e-02, 1.34154454e-01, 2.23035943e-02,
#         6.82423413e-02, 8.05592537e-02, 3.19573916e-02, 3.19573916e-02,
#         1.17842875e-01, 3.47536623e-01, 1.29161119e-01, 6.65778946e-03],
#        [1.17681676e-03, 2.67725810e-02, 1.16799057e-01, 2.11238593e-01,
#         2.94204173e-03, 2.94204173e-03, 1.86231241e-01, 3.52456599e-01,
#         3.50102969e-02, 1.76522508e-02, 3.32450718e-02, 1.35333920e-02],
#        [4.72109253e-03, 4.37245779e-02, 2.40448862e-01, 2.86170822e-02,
#         1.32190585e-02, 1.69959329e-02, 9.40586906e-03, 2.64126956e-01,
#         1.76677808e-01, 1.47407025e-01, 1.21295759e-02, 4.25261483e-02],
#        [6.85616955e-02, 1.49047165e-03, 4.00298089e-02, 3.50260846e-02,
#         3.22367728e-01, 1.34142451e-02, 6.22804202e-02, 3.23325872e-01,
#         1.72468852e-02, 8.09113216e-03, 1.07313961e-01, 8.51698045e-04],
#        [3.55869122e-02, 3.10125593e-02, 3.48115973e-02, 2.18871146e-01,
#         1.33509070e-01, 8.14855024e-02, 2.32594199e-02, 1.11180030e-01,
#         9.12544578e-02, 1.67622894e-01, 6.59792200e-02, 5.42719802e-03],
#        [6.54878851e-04, 1.08055007e-02, 6.45055696e-02, 2.09561232e-02,
#         5.07531129e-03, 4.91159130e-03, 2.01375242e-02, 7.00392902e-01,
#         7.80943036e-02, 1.19515387e-02, 6.59790412e-02, 1.65356901e-02],
#        [5.89874610e-02, 4.64468170e-03, 3.62285189e-02, 7.89595954e-03,
#         1.17510453e-01, 5.34138419e-02, 4.08731997e-02, 3.50208998e-01,
#         5.29493727e-02, 1.57454714e-01, 1.19832791e-01, 0.00000000e+00]],
#       dtype=float32)

# %% [markdown]
# ### Converting the matrix of transition probability to a dataframe

# %%
# convert the matrix to a df for better readability
transition_probability_df = pd.DataFrame(tags_matrix, columns = list(tags), index=list(tags))
transition_probability_df
# Out:
#           PRON       PRT         .         X       DET       ADV       NUM  \
# PRON  0.008096  0.012722  0.040478  0.093678  0.010023  0.033924  0.007710
# PRT   0.017717  0.001969  0.043635  0.013451  0.100722  0.009514  0.058399
# .     0.065138  0.002509  0.091658  0.027148  0.174536  0.052146  0.082251
# X     0.055608  0.182034  0.164449  0.075570  0.055450  0.024873  0.002852
# DET   0.003498  0.000241  0.017370  0.045597  0.005549  0.012786  0.021834
# ADV   0.014647  0.014980  0.134154  0.022304  0.068242  0.080559  0.031957
# NUM   0.001177  0.026773  0.116799  0.211239  0.002942  0.002942  0.186231
# NOUN  0.004721  0.043725  0.240449  0.028617  0.013219  0.016996  0.009406
# ADP   0.068562  0.001490  0.040030  0.035026  0.322368  0.013414  0.062280
# VERB  0.035587  0.031013  0.034812  0.218871  0.133509  0.081486  0.023259
# ADJ   0.000655  0.010806  0.064506  0.020956  0.005075  0.004912  0.020138
# CONJ  0.058987  0.004645  0.036229  0.007896  0.117510  0.053414  0.040873
#
#           NOUN       ADP      VERB       ADJ      CONJ
# PRON  0.207402  0.021974  0.484580  0.074017  0.005397
# PRT   0.246719  0.020341  0.398294  0.087270  0.001969
# .     0.221754  0.090942  0.089419  0.044530  0.057880
# X     0.062738  0.144487  0.204214  0.017110  0.010615
# DET   0.639807  0.009530  0.039445  0.203860  0.000483
# ADV   0.031957  0.117843  0.347537  0.129161  0.006658
# NUM   0.352457  0.035010  0.017652  0.033245  0.013533
# NOUN  0.264127  0.176678  0.147407  0.012130  0.042526
# ADP   0.323326  0.017247  0.008091  0.107314  0.000852
# VERB  0.111180  0.091254  0.167623  0.065979  0.005427
# ADJ   0.700393  0.078094  0.011952  0.065979  0.016536
# CONJ  0.350209  0.052949  0.157455  0.119833  0.000000

# %% [markdown]
# ### Build the Vanilla Viterbi based POS tagger (no modifications)

# %%
# Viterbi Heuristic
def Viterbi(words, train_tagged_words_list = train_tagged_words_list):
    #state  - list used to hold the state probabilities
    state = []
    
    #T - list contains all the Tags from train_bag
    T = list(set([pair[1] for pair in train_tagged_words_list]))
    
    for key, word in enumerate(words):
        #print("key:",key)
        #print("word:",word)
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            #print("Tag:",tag)
            #if the key is 0, then it is the begining of the sentence.
            if key == 0:
                transition_p = transition_probability_df.loc['.', tag] #"." - represents the start
                #print("transition_p:",transition_p)
            else:
                #state[-1] - refers to the previous tag. tag - refers to the current tag
                transition_p = transition_probability_df.loc[state[-1], tag]
                #print("transition_p:",transition_p)
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            #print("emission_p:",emission_p)
            state_probability = emission_p * transition_p  
            
            p.append(state_probability)
            #print("list of state probabilty:",p)
            
        pmax = max(p)
        #print("Maximum State Probability:",pmax)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)]
        #print("T[p.index(pmax)]:",T[p.index(pmax)])
        #Appending the maximum state probability to the state[]. So, when referring to state[-1] - represents previous tag
        state.append(state_max)
        #print("state:",state)
    return list(zip(words, state))

# %% [markdown]
# ### Test data

# %% [markdown]
# ##### test_tagged_words - contains only the words from the test data. Using vannila Viterbi algorithm, we will tag these words.

# %%
# list of tagged words
test_run_base = [tup for sentences in test_set for tup in sentences]
test_tagged_words = [tup[0] for sentences in test_set for tup in sentences]
print(len(test_set))
print(len(test_tagged_words))
# Out:
# 196
# 4780

# %% [markdown]
# ### Applying the Vanilla Viterbi algorithm to get the tags for the words in test set.

# %%
# tagging the test sentences

tagged_seq = Viterbi(test_tagged_words)
tagged_seq
# Out:
# [('The', 'DET'),
#  ('offer', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-2', 'X'),
#  ('follows', 'VERB'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('55-a-share', 'PRON'),
#  ('*U*', 'X'),
#  ('bid', 'VERB'),
#  ('that', 'ADP'),
#  ('*T*-3', 'X'),
#  ('was', 'VERB'),
#  ('rejected', 'VERB'),
#  ('*-1', 'X'),
#  ('in', 'ADP'),
#  ('September', 'NOUN'),
#  (',', '.'),
#  ('steps', 'NOUN'),
#  ('up', 'PRT'),
#  ('pressure', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('chemicals', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('.', '.'),
#  ('Already', 'PRON'),
#  (',', '.'),
#  ('10', 'NUM'),
#  ('local', 'ADJ'),
#  ('councils', 'NOUN'),
#  ('have', 'VERB'),
#  ('refused', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('honor', 'VERB'),
#  ('fees', 'NOUN'),
#  ('and', 'CONJ'),
#  ('payments', 'NOUN'),
#  ('to', 'PRT'),
#  ('banks', 'NOUN'),
#  ('incurred', 'VERB'),
#  ('*', 'X'),
#  ('during', 'ADP'),
#  ('various', 'ADJ'),
#  ('swaps', 'PRON'),
#  ('dealings', 'NOUN'),
#  ('.', '.'),
#  ('According', 'VERB'),
#  ('to', 'PRT'),
#  ('Ms.', 'NOUN'),
#  ('Poore', 'NOUN'),
#  (',', '.'),
#  ('Old-House', 'PRON'),
#  ('Journal', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  (',', '.'),
#  ('her', 'PRON'),
#  ('publishing', 'VERB'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('printed', 'VERB'),
#  ('and', 'CONJ'),
#  ('sold', 'VERB'),
#  ('all', 'DET'),
#  ('126,000', 'PRON'),
#  ('copies', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('premiere', 'NOUN'),
#  ('issue', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('Mr.', 'NOUN'),
#  ('Barnum', 'NOUN'),
#  ('called', 'VERB'),
#  ('that', 'ADP'),
#  ('``', '.'),
#  ('a', 'DET'),
#  ('worst-case', 'PRON'),
#  ("''", '.'),
#  ('scenario', 'NOUN'),
#  ('.', '.'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('specialists', 'NOUN'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('bold', 'ADJ'),
#  ('palace', 'PRON'),
#  ('revolt', 'PRON'),
#  (',', '.'),
#  ('began', 'VERB'),
#  ('shortly', 'ADV'),
#  ('after', 'ADP'),
#  ('Oct.', 'NOUN'),
#  ('13', 'NUM'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('telephone', 'NOUN'),
#  ('the', 'DET'),
#  ('corporate', 'ADJ'),
#  ('executives', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('companies', 'NOUN'),
#  ('whose', 'PRON'),
#  ('stock', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('is', 'VERB'),
#  ('listed', 'VERB'),
#  ('*-71', 'X'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('them', 'PRON'),
#  ('pressure', 'NOUN'),
#  ('the', 'DET'),
#  ('exchange', 'NOUN'),
#  ('to', 'PRT'),
#  ('ban', 'NOUN'),
#  ('program', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('.', '.'),
#  ('Another', 'DET'),
#  ('proposed', 'VERB'),
#  ('reform', 'NOUN'),
#  ('is', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('program', 'NOUN'),
#  ('traders', 'NOUN'),
#  ('answer', 'NOUN'),
#  ('to', 'PRT'),
#  ('an', 'DET'),
#  ('``', '.'),
#  ('uptick', 'NOUN'),
#  ('rule', 'NOUN'),
#  ("''", '.'),
#  ('a', 'DET'),
#  ('reform', 'NOUN'),
#  ('instituted', 'PRON'),
#  ('*', 'X'),
#  ('after', 'ADP'),
#  ('the', 'DET'),
#  ('Great', 'NOUN'),
#  ('Crash', 'PRON'),
#  ('of', 'ADP'),
#  ('1929', 'NUM'),
#  ('that', 'ADP'),
#  ('*T*-1', 'X'),
#  ('protects', 'PRON'),
#  ('against', 'ADP'),
#  ('stocks', 'NOUN'),
#  ('being', 'VERB'),
#  ('relentlessly', 'PRON'),
#  ('beaten', 'VERB'),
#  ('*-2', 'X'),
#  ('downward', 'ADJ'),
#  ('by', 'ADP'),
#  ('those', 'DET'),
#  ('seeking', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('profit', 'NOUN'),
#  ('from', 'ADP'),
#  ('lower', 'ADJ'),
#  ('prices', 'NOUN'),
#  (',', '.'),
#  ('namely', 'ADV'),
#  ('short', 'ADJ'),
#  ('sellers', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('Bush', 'NOUN'),
#  ('administration', 'NOUN'),
#  ("'s", 'PRT'),
#  ('nomination', 'NOUN'),
#  ('of', 'ADP'),
#  ('Clarence', 'PRON'),
#  ('Thomas', 'NOUN'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('seat', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('federal', 'ADJ'),
#  ('appeals', 'NOUN'),
#  ('court', 'NOUN'),
#  ('here', 'ADV'),
#  ('received', 'VERB'),
#  ('a', 'DET'),
#  ('blow', 'NOUN'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('when', 'ADV'),
#  ('the', 'DET'),
#  ('American', 'ADJ'),
#  ('Bar', 'NOUN'),
#  ('Association', 'NOUN'),
#  ('gave', 'VERB'),
#  ('Mr.', 'NOUN'),
#  ('Thomas', 'NOUN'),
#  ('only', 'ADV'),
#  ('a', 'DET'),
#  ('``', '.'),
#  ('qualified', 'VERB'),
#  ("''", '.'),
#  ('rating', 'NOUN'),
#  (',', '.'),
#  ('rather', 'ADV'),
#  ('than', 'ADP'),
#  ('``', '.'),
#  ('well', 'ADV'),
#  ('qualified', 'VERB'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Attorneys', 'NOUN'),
#  ('have', 'VERB'),
#  ('argued', 'VERB'),
#  ('since', 'ADP'),
#  ('1985', 'NUM'),
#  (',', '.'),
#  ('when', 'ADV'),
#  ('the', 'DET'),
#  ('law', 'NOUN'),
#  ('took', 'VERB'),
#  ('effect', 'NOUN'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('that', 'DET'),
#  ('they', 'PRON'),
#  ('can', 'VERB'),
#  ('not', 'ADV'),
#  ('provide', 'VERB'),
#  ('information', 'NOUN'),
#  ('about', 'ADP'),
#  ('clients', 'NOUN'),
#  ('who', 'PRON'),
#  ('*T*-127', 'PRON'),
#  ('do', 'VERB'),
#  ("n't", 'ADV'),
#  ('wish', 'VERB'),
#  ('their', 'PRON'),
#  ('identities', 'PRON'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('known', 'VERB'),
#  ('*-3', 'X'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('the', 'DET'),
#  ('Army', 'NOUN'),
#  ('Corps', 'NOUN'),
#  ('of', 'ADP'),
#  ('Engineers', 'NOUN'),
#  ('expects', 'VERB'),
#  ('the', 'DET'),
#  ('river', 'NOUN'),
#  ('level', 'NOUN'),
#  ('to', 'PRT'),
#  ('continue', 'VERB'),
#  ('*-1', 'X'),
#  ('falling', 'VERB'),
#  ('this', 'DET'),
#  ('month', 'NOUN'),
#  ('.', '.'),
#  ('Virginia', 'NOUN'),
#  (':', '.'),
#  ('The', 'DET'),
#  ('department', 'NOUN'),
#  ('previously', 'ADV'),
#  ('estimated', 'VERB'),
#  ('that', 'ADP'),
#  ('durable-goods', 'PRON'),
#  ('orders', 'NOUN'),
#  ('fell', 'VERB'),
#  ('0.1', 'NUM'),
#  ('%', 'NOUN'),
#  ('in', 'ADP'),
#  ('September', 'NOUN'),
#  ('.', '.'),
#  ('So', 'ADV'),
#  ('the', 'DET'),
#  ('next', 'ADJ'),
#  ('step', 'NOUN'),
#  (',', '.'),
#  ('I', 'PRON'),
#  ('suspect', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('is', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('try', 'VERB'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('get', 'VERB'),
#  ('the', 'DET'),
#  ('law', 'NOUN'),
#  ('changed', 'VERB'),
#  ('.', '.'),
#  ('Thus', 'ADV'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('institution', 'NOUN'),
#  ('obligated', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('make', 'VERB'),
#  ('fixed-rate', 'ADJ'),
#  ('interest', 'NOUN'),
#  ('payments', 'NOUN'),
#  ('on', 'ADP'),
#  ('debt', 'NOUN'),
#  ('swaps', 'PRON'),
#  ('the', 'DET'),
#  ('payments', 'NOUN'),
#  ('with', 'ADP'),
#  ('another', 'DET'),
#  ('making', 'VERB'),
#  ('floating-rate', 'ADJ'),
#  ('payments', 'NOUN'),
#  ('.', '.'),
#  ('Western', 'NOUN'),
#  ('Gas', 'NOUN'),
#  ('Resources', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  (',', '.'),
#  ('initial', 'ADJ'),
#  ('offering', 'NOUN'),
#  ('of', 'ADP'),
#  ('3,250,000', 'PRON'),
#  ('shares', 'NOUN'),
#  ('of', 'ADP'),
#  ('common', 'ADJ'),
#  ('stock', 'NOUN'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('which', 'DET'),
#  ('3,040,000', 'PRON'),
#  ('shares', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('sold', 'VERB'),
#  ('*-1', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('and', 'CONJ'),
#  ('210,000', 'PRON'),
#  ('shares', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('by', 'ADP'),
#  ('a', 'DET'),
#  ('holder', 'NOUN'),
#  (',', '.'),
#  ('via', 'ADP'),
#  ('Prudential-Bache', 'NOUN'),
#  ('Capital', 'NOUN'),
#  ('Funding', 'PRON'),
#  (',', '.'),
#  ('Smith', 'NOUN'),
#  ('Barney', 'NOUN'),
#  (',', '.'),
#  ('Harris', 'NOUN'),
#  ('Upham', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('Hanifen', 'PRON'),
#  (',', '.'),
#  ('Imhoff', 'PRON'),
#  ('Inc', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('his', 'PRON'),
#  ('ruling', 'NOUN'),
#  (',', '.'),
#  ('Judge', 'NOUN'),
#  ('Curry', 'NOUN'),
#  ('added', 'VERB'),
#  ('an', 'DET'),
#  ('additional', 'ADJ'),
#  ('$', '.'),
#  ('55', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('commission', 'NOUN'),
#  ("'s", 'PRT'),
#  ('calculations', 'PRON'),
#  ('.', '.'),
#  ('Moreover', 'ADV'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Japanese', 'ADJ'),
#  ('government', 'NOUN'),
#  (',', '.'),
#  ('now', 'ADV'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ("'s", 'PRT'),
#  ('largest', 'ADJ'),
#  ('aid', 'NOUN'),
#  ('donor', 'NOUN'),
#  (',', '.'),
#  ('is', 'VERB'),
#  ('pumping', 'VERB'),
#  ('far', 'ADV'),
#  ('more', 'ADV'),
#  ('assistance', 'NOUN'),
#  ('*ICH*-2', 'X'),
#  ('into', 'ADP'),
#  ('the', 'DET'),
#  ('region', 'NOUN'),
#  ('than', 'ADP'),
#  ('the', 'DET'),
#  ('U.S.', 'NOUN'),
#  ('is', 'VERB'),
#  ('*?*', 'X'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Florio', 'NOUN'),
#  ("'s", 'PRT'),
#  ('lying', 'VERB'),
#  (',', '.'),
#  ("''", '.'),
#  ('the', 'DET'),
#  ('voice', 'NOUN'),
#  ('goes', 'VERB'),
#  ('on', 'ADP'),
#  (',', '.'),
#  ('because', 'ADP'),
#  ('``', '.'),
#  ('the', 'DET'),
#  ('barrel', 'NOUN'),
#  ('on', 'ADP'),
#  ('Courter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('land', 'VERB'),
#  ('...', '.'),
#  ('contained', 'VERB'),
#  ('heating', 'NOUN'),
#  ('oil', 'NOUN'),
#  (',', '.'),
#  ('was', 'VERB'),
#  ('cleaned', 'PRON'),
#  ('*-1', 'X'),
#  ('up', 'PRT'),
#  ('and', 'CONJ'),
#  ('caused', 'VERB'),
#  ('no', 'DET'),
#  ('pollution', 'PRON'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('resulting', 'VERB'),
#  ('company', 'NOUN'),
#  ('would', 'VERB'),
#  ('be', 'VERB'),
#  ('the', 'DET'),
#  ('largest', 'ADJ'),
#  ('forest-products', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ('with', 'ADP'),
#  ('combined', 'ADJ'),
#  ('sales', 'NOUN'),
#  ('of', 'ADP'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('$', '.'),
#  ('13', 'NUM'),
#  ('billion', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('Stadium', 'NOUN'),
#  ('boosters', 'NOUN'),
#  ('claim', 'VERB'),
#  ('that', 'ADP'),
#  ('without', 'ADP'),
#  ('public', 'ADJ'),
#  ('money', 'NOUN'),
#  ('they', 'PRON'),
#  ('would', 'VERB'),
#  ('never', 'ADV'),
#  ('be', 'VERB'),
#  ('built', 'VERB'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ('We', 'PRON'),
#  ('must', 'VERB'),
#  ('be', 'VERB'),
#  ('very', 'ADV'),
#  ('cautious', 'ADJ'),
#  ('about', 'ADP'),
#  ('*', 'X'),
#  ('labeling', 'PRON'),
#  ('investors', 'NOUN'),
#  ('as', 'ADP'),
#  ('``', '.'),
#  ('long-term', 'ADJ'),
#  ("''", '.'),
#  ('or', 'CONJ'),
#  ('``', '.'),
#  ('short-term', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('McDermott', 'PRON'),
#  ('International', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('its', 'PRON'),
#  ('Babcock', 'PRON'),
#  ('&', 'CONJ'),
#  ('Wilcox', 'PRON'),
#  ('unit', 'NOUN'),
#  ('completed', 'VERB'),
#  ('the', 'DET'),
#  ('sale', 'NOUN'),
#  ('of', 'ADP'),
#  ('its', 'PRON'),
#  ('Bailey', 'NOUN'),
#  ('Controls', 'NOUN'),
#  ('Operations', 'PRON'),
#  ('to', 'PRT'),
#  ('Finmeccanica', 'NOUN'),
#  ('S.p', 'PRON'),
#  ('.', '.'),
#  ('A.', 'NOUN'),
#  ('for', 'ADP'),
#  ('$', '.'),
#  ('295', 'PRON'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Who', 'PRON'),
#  ('*T*-1', 'X'),
#  ("'s", 'PRT'),
#  ('really', 'ADV'),
#  ('lying', 'VERB'),
#  ('?', '.'),
#  ("''", '.'),
#  ('asks', 'VERB'),
#  ('*T*-2', 'X'),
#  ('a', 'DET'),
#  ('female', 'ADJ'),
#  ('voice', 'NOUN'),
#  ('.', '.'),
#  ('Meanwhile', 'ADV'),
#  (',', '.'),
#  ('business', 'NOUN'),
#  ('and', 'CONJ'),
#  ('government', 'NOUN'),
#  ('leaders', 'NOUN'),
#  ('rebuked', 'PRON'),
#  ('the', 'DET'),
#  ('computer', 'NOUN'),
#  ('makers', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('fretted', 'PRON'),
#  ('about', 'ADP'),
#  ('the', 'DET'),
#  ('broader', 'ADJ'),
#  ('statement', 'NOUN'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('companies', 'NOUN'),
#  ("'", 'PRT'),
#  ('actions', 'NOUN'),
#  ('make', 'VERB'),
#  ('*T*-1', 'X'),
#  ('about', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('cutthroat', 'ADJ'),
#  ('pricing', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('1973', 'PRON'),
#  (',', '.'),
#  ('Wells', 'PRON'),
#  ('Fargo', 'PRON'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  ('of', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('launched', 'VERB'),
#  ('the', 'DET'),
#  ('Gold', 'NOUN'),
#  ('Account', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-198', 'PRON'),
#  ('included', 'VERB'),
#  ('free', 'ADJ'),
#  ('checking', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('credit', 'NOUN'),
#  ('card', 'NOUN'),
#  (',', '.'),
#  ('safe-deposit', 'PRON'),
#  ('box', 'NOUN'),
#  ('and', 'CONJ'),
#  ('travelers', 'PRON'),
#  ('checks', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('3', 'NUM'),
#  ('*U*', 'X'),
#  ('monthly', 'ADJ'),
#  ('fee', 'NOUN'),
#  ('.', '.'),
#  ('*-1', 'X'),
#  ('Asked', 'VERB'),
#  ('*-2', 'X'),
#  ('whether', 'ADP'),
#  ('the', 'DET'),
#  ('bidding', 'NOUN'),
#  ('flap', 'NOUN'),
#  ('would', 'VERB'),
#  ('hurt', 'VERB'),
#  ('U.S.-Japan', 'PRON'),
#  ('relations', 'NOUN'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Yamamoto', 'NOUN'),
#  ('said', 'VERB'),
#  (',', '.'),
#  ('``', '.'),
#  ('this', 'DET'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('a', 'DET'),
#  ('minus', 'PRON'),
#  ('factor', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('For', 'ADP'),
#  ('the', 'DET'),
#  ('Agency', 'NOUN'),
#  ('for', 'ADP'),
#  ('International', 'NOUN'),
#  ('Development', 'NOUN'),
#  (',', '.'),
#  ('appropriators', 'NOUN'),
#  ('approved', 'VERB'),
#  ('$', '.'),
#  ('200', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('secondary', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('under', 'ADP'),
#  ('an', 'DET'),
#  ('expanded', 'VERB'),
#  ('trade', 'VERB'),
#  ('credit', 'NOUN'),
#  ('insurance', 'NOUN'),
#  ('program', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('total', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('Overseas', 'PRON'),
#  ('Private', 'ADJ'),
#  ('Investment', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('are', 'VERB'),
#  ('increased', 'VERB'),
#  ('*-3', 'X'),
#  ('by', 'ADP'),
#  ('$', '.'),
#  ('40', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('over', 'ADP'),
#  ('fiscal', 'ADJ'),
#  ('1989', 'NUM'),
#  ('as', 'ADP'),
#  ('part', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('Poland', 'NOUN'),
#  ('package', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('both', 'DET'),
#  ('cases', 'NOUN'),
#  (',', '.'),
#  ('NEC', 'NOUN'),
#  ('lost', 'VERB'),
#  ('the', 'DET'),
#  ('contract', 'NOUN'),
#  ('to', 'PRT'),
#  ('Fujitsu', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-139', 'PRON'),
#  ('made', 'VERB'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('bid', 'NOUN'),
#  ('and', 'CONJ'),
#  ('won', 'VERB'),
#  ('a', 'DET'),
#  ('tie-breaking', 'PRON'),
#  ('lottery', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Cosby', 'NOUN'),
#  ("''", '.'),
#  ('is', 'VERB'),
#  ('down', 'ADV'),
#  ('a', 'DET'),
#  ('full', 'ADJ'),
#  ('ratings', 'NOUN'),
#  ('point', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('week', 'NOUN'),
#  ('of', 'ADP'),
#  ('Oct.', 'NOUN'),
#  ('2-8', 'PRON'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('week', 'NOUN'),
#  ('a', 'DET'),
#  ('year', 'NOUN'),
#  ('ago', 'ADP'),
#  (',', '.'),
#  ('according', 'VERB'),
#  ('to', 'PRT'),
#  ('A.C.', 'PRON'),
#  ('Nielsen', 'PRON'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('Despite', 'ADP'),
#  ('the', 'DET'),
#  ('Supreme', 'NOUN'),
#  ('Court', 'NOUN'),
#  ("'s", 'PRT'),
#  ('refusal', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('hear', 'VERB'),
#  ('the', 'DET'),
#  ('case', 'NOUN'),
#  (',', '.'),
#  ('there', 'DET'),
#  ('are', 'VERB'),
#  ('serious', 'ADJ'),
#  ('constitutional', 'ADJ'),
#  ('issues', 'NOUN'),
#  ('of', 'ADP'),
#  ('due', 'ADJ'),
#  ('process', 'NOUN'),
#  ('and', 'CONJ'),
#  ('uncompensated', 'PRON'),
#  ('takings', 'PRON'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('defendants', 'NOUN'),
#  ('.', '.'),
#  ('And', 'CONJ'),
#  ('some', 'DET'),
#  ('grain', 'NOUN'),
#  ('analysts', 'NOUN'),
#  ('are', 'VERB'),
#  ('predicting', 'VERB'),
#  ('that', 'ADP'),
#  ('corn', 'NOUN'),
#  ('prices', 'NOUN'),
#  ('might', 'VERB'),
#  ('gyrate', 'PRON'),
#  ('this', 'DET'),
#  ('month', 'NOUN'),
#  ('as', 'ADP'),
#  ('exporters', 'NOUN'),
#  ('scrounge', 'PRON'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('find', 'VERB'),
#  ('enough', 'ADV'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('crop', 'NOUN'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('to', 'PRT'),
#  ('meet', 'VERB'),
#  ('their', 'PRON'),
#  ('obligations', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('Soviets', 'NOUN'),
#  ('.', '.'),
#  ('Still', 'ADV'),
#  ('unresolved', 'PRON'),
#  ('is', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Sony', 'NOUN'),
#  ("'s", 'PRT'),
#  ('effort', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('hire', 'VERB'),
#  ('producers', 'NOUN'),
#  ('Jon', 'PRON'),
#  ('Peters', 'PRON'),
#  ('and', 'CONJ'),
#  ('Peter', 'NOUN'),
#  ('Guber', 'PRON'),
#  ('to', 'PRT'),
#  ('run', 'VERB'),
#  ('the', 'DET'),
#  ('studio', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('if', 'ADP'),
#  ('Columbia', 'NOUN'),
#  ('could', 'VERB'),
#  ('keep', 'VERB'),
#  ('its', 'PRON'),
#  ('junk', 'NOUN'),
#  ('bonds', 'NOUN'),
#  ('separate', 'ADJ'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('thrift', 'NOUN'),
#  ('till', 'PRON'),
#  ('they', 'PRON'),
#  ('mature', 'VERB'),
#  ('--', '.'),
#  ('at', 'ADP'),
#  ('full', 'ADJ'),
#  ('value', 'NOUN'),
#  (',', '.'),
#  ('unless', 'ADP'),
#  ('the', 'DET'),
#  ('issuer', 'PRON'),
#  ('goes', 'VERB'),
#  ('bust', 'PRON'),
#  ('or', 'CONJ'),
#  ('restructures', 'PRON'),
#  ('--', '.'),
#  ('the', 'DET'),
#  ('junk', 'NOUN'),
#  ('portfolio', 'NOUN'),
#  ('might', 'VERB'),
#  ('do', 'VERB'),
#  ('all', 'DET'),
#  ('right', 'NOUN'),
#  ('.', '.'),
#  ('For', 'ADP'),
#  ('some', 'DET'),
#  ('time', 'NOUN'),
#  (',', '.'),
#  ('banks', 'NOUN'),
#  ('have', 'VERB'),
#  ('been', 'VERB'),
#  ('aiming', 'PRON'),
#  ('packages', 'NOUN'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  ('elderly', 'PRON'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('demographic', 'ADJ'),
#  ('segment', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('highest', 'ADJ'),
#  ('savings', 'NOUN'),
#  ('.', '.'),
#  ('Cray', 'NOUN'),
#  ('Research', 'NOUN'),
#  ('indicated', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('survival', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('spinoff', 'NOUN'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-1', 'X'),
#  ('is', 'VERB'),
#  ('developing', 'VERB'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('supercomputer', 'NOUN'),
#  (',', '.'),
#  ('depends', 'PRON'),
#  ('heavily', 'ADV'),
#  ('on', 'ADP'),
#  ('its', 'PRON'),
#  ('chairman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('chief', 'NOUN'),
#  ('designer', 'NOUN'),
#  (',', '.'),
#  ('Seymour', 'NOUN'),
#  ('Cray', 'NOUN'),
#  ('.', '.'),
#  ('Congress', 'NOUN'),
#  ('learned', 'VERB'),
#  ('during', 'ADP'),
#  ('the', 'DET'),
#  ('Reagan', 'NOUN'),
#  ('administration', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('could', 'VERB'),
#  ('intimidate', 'PRON'),
#  ('the', 'DET'),
#  ('executive', 'NOUN'),
#  ('branch', 'NOUN'),
#  ('by', 'ADP'),
#  ('*-1', 'X'),
#  ('uttering', 'PRON'),
#  ('again', 'ADV'),
#  ('and', 'CONJ'),
#  ('again', 'ADV'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('seven', 'NUM'),
#  ('words', 'NOUN'),
#  (':', '.'),
#  ('``', '.'),
#  ('Provided', 'PRON'),
#  (',', '.'),
#  ('that', 'DET'),
#  ('no', 'DET'),
#  ('funds', 'NOUN'),
#  ('shall', 'VERB'),
#  ('be', 'VERB'),
#  ('spent', 'VERB'),
#  ('*-48', 'X'),
#  ('...', '.'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Then', 'ADV'),
#  ('*', 'X'),
#  ('send', 'VERB'),
#  ('your', 'PRON'),
#  ('support', 'VERB'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('savings', 'NOUN'),
#  ('institution', 'NOUN'),
#  ('that', 'ADP'),
#  ('*T*-208', 'PRON'),
#  ('has', 'VERB'),
#  ('taken', 'VERB'),
#  ('a', 'DET'),
#  ('bad', 'ADJ'),
#  ('rap', 'PRON'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('press', 'NOUN'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('its', 'PRON'),
#  ('bottom', 'NOUN'),
#  ('line', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('other', 'ADJ'),
#  ('concern', 'NOUN'),
#  ('was', 'VERB'),
#  ...]

# %% [markdown]
# #### Checking the accuracy between the tags assigned by humans and Viterbi algorithm

# %% [markdown]
# tagged_seq - refers to the tags given by the Virterbi algorithm <br>
# test_run_base - refers to the tags given by humans

# %%
# accuracy for checking matched tags.
#If the tags generated by humans and Viterbi algorithm is same it will add to the list.
Matched_tags = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 
Matched_tags
# Out:
# [('The', 'DET'),
#  ('offer', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-2', 'X'),
#  ('follows', 'VERB'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('*U*', 'X'),
#  ('*T*-3', 'X'),
#  ('was', 'VERB'),
#  ('rejected', 'VERB'),
#  ('*-1', 'X'),
#  ('in', 'ADP'),
#  ('September', 'NOUN'),
#  (',', '.'),
#  ('up', 'PRT'),
#  ('pressure', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('chemicals', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('.', '.'),
#  (',', '.'),
#  ('10', 'NUM'),
#  ('local', 'ADJ'),
#  ('councils', 'NOUN'),
#  ('have', 'VERB'),
#  ('refused', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('honor', 'VERB'),
#  ('fees', 'NOUN'),
#  ('and', 'CONJ'),
#  ('payments', 'NOUN'),
#  ('to', 'PRT'),
#  ('banks', 'NOUN'),
#  ('incurred', 'VERB'),
#  ('*', 'X'),
#  ('during', 'ADP'),
#  ('various', 'ADJ'),
#  ('dealings', 'NOUN'),
#  ('.', '.'),
#  ('According', 'VERB'),
#  ('to', 'PRT'),
#  ('Ms.', 'NOUN'),
#  ('Poore', 'NOUN'),
#  (',', '.'),
#  ('Journal', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  (',', '.'),
#  ('her', 'PRON'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('printed', 'VERB'),
#  ('and', 'CONJ'),
#  ('sold', 'VERB'),
#  ('all', 'DET'),
#  ('copies', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('premiere', 'NOUN'),
#  ('issue', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('Mr.', 'NOUN'),
#  ('Barnum', 'NOUN'),
#  ('called', 'VERB'),
#  ('that', 'ADP'),
#  ('``', '.'),
#  ('a', 'DET'),
#  ("''", '.'),
#  ('scenario', 'NOUN'),
#  ('.', '.'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('specialists', 'NOUN'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('bold', 'ADJ'),
#  (',', '.'),
#  ('began', 'VERB'),
#  ('shortly', 'ADV'),
#  ('after', 'ADP'),
#  ('Oct.', 'NOUN'),
#  ('13', 'NUM'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('corporate', 'ADJ'),
#  ('executives', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('companies', 'NOUN'),
#  ('whose', 'PRON'),
#  ('stock', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('is', 'VERB'),
#  ('listed', 'VERB'),
#  ('*-71', 'X'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('them', 'PRON'),
#  ('the', 'DET'),
#  ('exchange', 'NOUN'),
#  ('to', 'PRT'),
#  ('program', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('.', '.'),
#  ('Another', 'DET'),
#  ('proposed', 'VERB'),
#  ('reform', 'NOUN'),
#  ('is', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('program', 'NOUN'),
#  ('traders', 'NOUN'),
#  ('to', 'PRT'),
#  ('an', 'DET'),
#  ('``', '.'),
#  ('uptick', 'NOUN'),
#  ('rule', 'NOUN'),
#  ("''", '.'),
#  ('a', 'DET'),
#  ('reform', 'NOUN'),
#  ('*', 'X'),
#  ('after', 'ADP'),
#  ('the', 'DET'),
#  ('Great', 'NOUN'),
#  ('of', 'ADP'),
#  ('1929', 'NUM'),
#  ('*T*-1', 'X'),
#  ('against', 'ADP'),
#  ('stocks', 'NOUN'),
#  ('being', 'VERB'),
#  ('beaten', 'VERB'),
#  ('*-2', 'X'),
#  ('by', 'ADP'),
#  ('those', 'DET'),
#  ('seeking', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('from', 'ADP'),
#  ('lower', 'ADJ'),
#  ('prices', 'NOUN'),
#  (',', '.'),
#  ('namely', 'ADV'),
#  ('short', 'ADJ'),
#  ('sellers', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('Bush', 'NOUN'),
#  ('administration', 'NOUN'),
#  ("'s", 'PRT'),
#  ('nomination', 'NOUN'),
#  ('of', 'ADP'),
#  ('Thomas', 'NOUN'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('seat', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('federal', 'ADJ'),
#  ('appeals', 'NOUN'),
#  ('court', 'NOUN'),
#  ('here', 'ADV'),
#  ('received', 'VERB'),
#  ('a', 'DET'),
#  ('blow', 'NOUN'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('when', 'ADV'),
#  ('the', 'DET'),
#  ('Bar', 'NOUN'),
#  ('Association', 'NOUN'),
#  ('gave', 'VERB'),
#  ('Mr.', 'NOUN'),
#  ('Thomas', 'NOUN'),
#  ('only', 'ADV'),
#  ('a', 'DET'),
#  ('``', '.'),
#  ("''", '.'),
#  ('rating', 'NOUN'),
#  (',', '.'),
#  ('rather', 'ADV'),
#  ('than', 'ADP'),
#  ('``', '.'),
#  ('well', 'ADV'),
#  ('qualified', 'VERB'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Attorneys', 'NOUN'),
#  ('have', 'VERB'),
#  ('argued', 'VERB'),
#  ('since', 'ADP'),
#  ('1985', 'NUM'),
#  (',', '.'),
#  ('when', 'ADV'),
#  ('the', 'DET'),
#  ('law', 'NOUN'),
#  ('took', 'VERB'),
#  ('effect', 'NOUN'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('they', 'PRON'),
#  ('can', 'VERB'),
#  ('not', 'ADV'),
#  ('provide', 'VERB'),
#  ('information', 'NOUN'),
#  ('about', 'ADP'),
#  ('clients', 'NOUN'),
#  ('who', 'PRON'),
#  ('do', 'VERB'),
#  ("n't", 'ADV'),
#  ('wish', 'VERB'),
#  ('their', 'PRON'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('known', 'VERB'),
#  ('*-3', 'X'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('the', 'DET'),
#  ('Army', 'NOUN'),
#  ('Corps', 'NOUN'),
#  ('of', 'ADP'),
#  ('Engineers', 'NOUN'),
#  ('expects', 'VERB'),
#  ('the', 'DET'),
#  ('river', 'NOUN'),
#  ('level', 'NOUN'),
#  ('to', 'PRT'),
#  ('continue', 'VERB'),
#  ('*-1', 'X'),
#  ('falling', 'VERB'),
#  ('this', 'DET'),
#  ('month', 'NOUN'),
#  ('.', '.'),
#  ('Virginia', 'NOUN'),
#  (':', '.'),
#  ('The', 'DET'),
#  ('department', 'NOUN'),
#  ('previously', 'ADV'),
#  ('estimated', 'VERB'),
#  ('that', 'ADP'),
#  ('orders', 'NOUN'),
#  ('fell', 'VERB'),
#  ('0.1', 'NUM'),
#  ('%', 'NOUN'),
#  ('in', 'ADP'),
#  ('September', 'NOUN'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('next', 'ADJ'),
#  ('step', 'NOUN'),
#  (',', '.'),
#  ('I', 'PRON'),
#  ('suspect', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('is', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('try', 'VERB'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('get', 'VERB'),
#  ('the', 'DET'),
#  ('law', 'NOUN'),
#  ('changed', 'VERB'),
#  ('.', '.'),
#  ('Thus', 'ADV'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('institution', 'NOUN'),
#  ('obligated', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('make', 'VERB'),
#  ('fixed-rate', 'ADJ'),
#  ('interest', 'NOUN'),
#  ('payments', 'NOUN'),
#  ('on', 'ADP'),
#  ('debt', 'NOUN'),
#  ('the', 'DET'),
#  ('payments', 'NOUN'),
#  ('with', 'ADP'),
#  ('another', 'DET'),
#  ('making', 'VERB'),
#  ('floating-rate', 'ADJ'),
#  ('payments', 'NOUN'),
#  ('.', '.'),
#  ('Western', 'NOUN'),
#  ('Gas', 'NOUN'),
#  ('Resources', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  (',', '.'),
#  ('initial', 'ADJ'),
#  ('offering', 'NOUN'),
#  ('of', 'ADP'),
#  ('shares', 'NOUN'),
#  ('of', 'ADP'),
#  ('common', 'ADJ'),
#  ('stock', 'NOUN'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('which', 'DET'),
#  ('shares', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('sold', 'VERB'),
#  ('*-1', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('and', 'CONJ'),
#  ('shares', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('by', 'ADP'),
#  ('a', 'DET'),
#  ('holder', 'NOUN'),
#  (',', '.'),
#  ('via', 'ADP'),
#  ('Prudential-Bache', 'NOUN'),
#  ('Capital', 'NOUN'),
#  (',', '.'),
#  ('Smith', 'NOUN'),
#  ('Barney', 'NOUN'),
#  (',', '.'),
#  ('Harris', 'NOUN'),
#  ('Upham', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  (',', '.'),
#  ('Inc', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('his', 'PRON'),
#  ('ruling', 'NOUN'),
#  (',', '.'),
#  ('Judge', 'NOUN'),
#  ('Curry', 'NOUN'),
#  ('added', 'VERB'),
#  ('an', 'DET'),
#  ('additional', 'ADJ'),
#  ('$', '.'),
#  ('55', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('commission', 'NOUN'),
#  ("'s", 'PRT'),
#  ('.', '.'),
#  ('Moreover', 'ADV'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Japanese', 'ADJ'),
#  ('government', 'NOUN'),
#  (',', '.'),
#  ('now', 'ADV'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ("'s", 'PRT'),
#  ('largest', 'ADJ'),
#  ('aid', 'NOUN'),
#  ('donor', 'NOUN'),
#  (',', '.'),
#  ('is', 'VERB'),
#  ('pumping', 'VERB'),
#  ('far', 'ADV'),
#  ('assistance', 'NOUN'),
#  ('*ICH*-2', 'X'),
#  ('into', 'ADP'),
#  ('the', 'DET'),
#  ('region', 'NOUN'),
#  ('than', 'ADP'),
#  ('the', 'DET'),
#  ('U.S.', 'NOUN'),
#  ('is', 'VERB'),
#  ('*?*', 'X'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Florio', 'NOUN'),
#  ('lying', 'VERB'),
#  (',', '.'),
#  ("''", '.'),
#  ('the', 'DET'),
#  ('voice', 'NOUN'),
#  ('goes', 'VERB'),
#  (',', '.'),
#  ('because', 'ADP'),
#  ('``', '.'),
#  ('the', 'DET'),
#  ('barrel', 'NOUN'),
#  ('on', 'ADP'),
#  ('Courter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('...', '.'),
#  ('contained', 'VERB'),
#  ('heating', 'NOUN'),
#  ('oil', 'NOUN'),
#  (',', '.'),
#  ('was', 'VERB'),
#  ('*-1', 'X'),
#  ('up', 'PRT'),
#  ('and', 'CONJ'),
#  ('caused', 'VERB'),
#  ('no', 'DET'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('resulting', 'VERB'),
#  ('company', 'NOUN'),
#  ('would', 'VERB'),
#  ('be', 'VERB'),
#  ('the', 'DET'),
#  ('largest', 'ADJ'),
#  ('forest-products', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ('with', 'ADP'),
#  ('sales', 'NOUN'),
#  ('of', 'ADP'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('$', '.'),
#  ('13', 'NUM'),
#  ('billion', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('Stadium', 'NOUN'),
#  ('boosters', 'NOUN'),
#  ('claim', 'VERB'),
#  ('that', 'ADP'),
#  ('without', 'ADP'),
#  ('public', 'ADJ'),
#  ('money', 'NOUN'),
#  ('they', 'PRON'),
#  ('would', 'VERB'),
#  ('never', 'ADV'),
#  ('be', 'VERB'),
#  ('built', 'VERB'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ('We', 'PRON'),
#  ('must', 'VERB'),
#  ('be', 'VERB'),
#  ('very', 'ADV'),
#  ('cautious', 'ADJ'),
#  ('about', 'ADP'),
#  ('*', 'X'),
#  ('investors', 'NOUN'),
#  ('as', 'ADP'),
#  ('``', '.'),
#  ('long-term', 'ADJ'),
#  ("''", '.'),
#  ('or', 'CONJ'),
#  ('``', '.'),
#  ('short-term', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('International', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('its', 'PRON'),
#  ('&', 'CONJ'),
#  ('unit', 'NOUN'),
#  ('completed', 'VERB'),
#  ('the', 'DET'),
#  ('sale', 'NOUN'),
#  ('of', 'ADP'),
#  ('its', 'PRON'),
#  ('Bailey', 'NOUN'),
#  ('Controls', 'NOUN'),
#  ('to', 'PRT'),
#  ('Finmeccanica', 'NOUN'),
#  ('.', '.'),
#  ('A.', 'NOUN'),
#  ('for', 'ADP'),
#  ('$', '.'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Who', 'PRON'),
#  ('*T*-1', 'X'),
#  ('really', 'ADV'),
#  ('lying', 'VERB'),
#  ('?', '.'),
#  ("''", '.'),
#  ('asks', 'VERB'),
#  ('*T*-2', 'X'),
#  ('a', 'DET'),
#  ('female', 'ADJ'),
#  ('voice', 'NOUN'),
#  ('.', '.'),
#  ('Meanwhile', 'ADV'),
#  (',', '.'),
#  ('business', 'NOUN'),
#  ('and', 'CONJ'),
#  ('government', 'NOUN'),
#  ('leaders', 'NOUN'),
#  ('the', 'DET'),
#  ('computer', 'NOUN'),
#  ('makers', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('about', 'ADP'),
#  ('the', 'DET'),
#  ('broader', 'ADJ'),
#  ('statement', 'NOUN'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('companies', 'NOUN'),
#  ("'", 'PRT'),
#  ('actions', 'NOUN'),
#  ('make', 'VERB'),
#  ('*T*-1', 'X'),
#  ('about', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('cutthroat', 'ADJ'),
#  ('pricing', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  (',', '.'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  ('of', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('launched', 'VERB'),
#  ('the', 'DET'),
#  ('Gold', 'NOUN'),
#  ('Account', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('included', 'VERB'),
#  ('free', 'ADJ'),
#  ('checking', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('credit', 'NOUN'),
#  ('card', 'NOUN'),
#  (',', '.'),
#  ('box', 'NOUN'),
#  ('and', 'CONJ'),
#  ('checks', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('3', 'NUM'),
#  ('*U*', 'X'),
#  ('monthly', 'ADJ'),
#  ('fee', 'NOUN'),
#  ('.', '.'),
#  ('*-1', 'X'),
#  ('Asked', 'VERB'),
#  ('*-2', 'X'),
#  ('whether', 'ADP'),
#  ('the', 'DET'),
#  ('bidding', 'NOUN'),
#  ('flap', 'NOUN'),
#  ('would', 'VERB'),
#  ('hurt', 'VERB'),
#  ('relations', 'NOUN'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Yamamoto', 'NOUN'),
#  ('said', 'VERB'),
#  (',', '.'),
#  ('``', '.'),
#  ('this', 'DET'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('a', 'DET'),
#  ('factor', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('For', 'ADP'),
#  ('the', 'DET'),
#  ('Agency', 'NOUN'),
#  ('for', 'ADP'),
#  ('International', 'NOUN'),
#  ('Development', 'NOUN'),
#  (',', '.'),
#  ('appropriators', 'NOUN'),
#  ('approved', 'VERB'),
#  ('$', '.'),
#  ('200', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('secondary', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('under', 'ADP'),
#  ('an', 'DET'),
#  ('expanded', 'VERB'),
#  ('credit', 'NOUN'),
#  ('insurance', 'NOUN'),
#  ('program', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('total', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('Investment', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('are', 'VERB'),
#  ('increased', 'VERB'),
#  ('*-3', 'X'),
#  ('by', 'ADP'),
#  ('$', '.'),
#  ('40', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('over', 'ADP'),
#  ('fiscal', 'ADJ'),
#  ('1989', 'NUM'),
#  ('as', 'ADP'),
#  ('part', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('Poland', 'NOUN'),
#  ('package', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('both', 'DET'),
#  ('cases', 'NOUN'),
#  (',', '.'),
#  ('NEC', 'NOUN'),
#  ('lost', 'VERB'),
#  ('the', 'DET'),
#  ('contract', 'NOUN'),
#  ('to', 'PRT'),
#  ('Fujitsu', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('made', 'VERB'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('bid', 'NOUN'),
#  ('and', 'CONJ'),
#  ('won', 'VERB'),
#  ('a', 'DET'),
#  ('lottery', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Cosby', 'NOUN'),
#  ("''", '.'),
#  ('is', 'VERB'),
#  ('down', 'ADV'),
#  ('a', 'DET'),
#  ('full', 'ADJ'),
#  ('ratings', 'NOUN'),
#  ('point', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('week', 'NOUN'),
#  ('of', 'ADP'),
#  ('Oct.', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('week', 'NOUN'),
#  ('a', 'DET'),
#  ('year', 'NOUN'),
#  (',', '.'),
#  ('according', 'VERB'),
#  ('to', 'PRT'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('Despite', 'ADP'),
#  ('the', 'DET'),
#  ('Supreme', 'NOUN'),
#  ('Court', 'NOUN'),
#  ("'s", 'PRT'),
#  ('refusal', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('hear', 'VERB'),
#  ('the', 'DET'),
#  ('case', 'NOUN'),
#  (',', '.'),
#  ('there', 'DET'),
#  ('are', 'VERB'),
#  ('serious', 'ADJ'),
#  ('constitutional', 'ADJ'),
#  ('issues', 'NOUN'),
#  ('of', 'ADP'),
#  ('due', 'ADJ'),
#  ('process', 'NOUN'),
#  ('and', 'CONJ'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('defendants', 'NOUN'),
#  ('.', '.'),
#  ('And', 'CONJ'),
#  ('some', 'DET'),
#  ('grain', 'NOUN'),
#  ('analysts', 'NOUN'),
#  ('are', 'VERB'),
#  ('predicting', 'VERB'),
#  ('that', 'ADP'),
#  ('corn', 'NOUN'),
#  ('prices', 'NOUN'),
#  ('might', 'VERB'),
#  ('this', 'DET'),
#  ('month', 'NOUN'),
#  ('as', 'ADP'),
#  ('exporters', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('find', 'VERB'),
#  ('enough', 'ADV'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('crop', 'NOUN'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('to', 'PRT'),
#  ('meet', 'VERB'),
#  ('their', 'PRON'),
#  ('obligations', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('Soviets', 'NOUN'),
#  ('.', '.'),
#  ('Still', 'ADV'),
#  ('is', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Sony', 'NOUN'),
#  ("'s", 'PRT'),
#  ('effort', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('hire', 'VERB'),
#  ('producers', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Peter', 'NOUN'),
#  ('to', 'PRT'),
#  ('run', 'VERB'),
#  ('the', 'DET'),
#  ('studio', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('if', 'ADP'),
#  ('Columbia', 'NOUN'),
#  ('could', 'VERB'),
#  ('keep', 'VERB'),
#  ('its', 'PRON'),
#  ('junk', 'NOUN'),
#  ('bonds', 'NOUN'),
#  ('separate', 'ADJ'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('thrift', 'NOUN'),
#  ('they', 'PRON'),
#  ('mature', 'VERB'),
#  ('--', '.'),
#  ('at', 'ADP'),
#  ('full', 'ADJ'),
#  ('value', 'NOUN'),
#  (',', '.'),
#  ('unless', 'ADP'),
#  ('the', 'DET'),
#  ('goes', 'VERB'),
#  ('or', 'CONJ'),
#  ('--', '.'),
#  ('the', 'DET'),
#  ('junk', 'NOUN'),
#  ('portfolio', 'NOUN'),
#  ('might', 'VERB'),
#  ('do', 'VERB'),
#  ('.', '.'),
#  ('For', 'ADP'),
#  ('some', 'DET'),
#  ('time', 'NOUN'),
#  (',', '.'),
#  ('banks', 'NOUN'),
#  ('have', 'VERB'),
#  ('been', 'VERB'),
#  ('packages', 'NOUN'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('demographic', 'ADJ'),
#  ('segment', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('highest', 'ADJ'),
#  ('savings', 'NOUN'),
#  ('.', '.'),
#  ('Cray', 'NOUN'),
#  ('Research', 'NOUN'),
#  ('indicated', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('survival', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('spinoff', 'NOUN'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-1', 'X'),
#  ('is', 'VERB'),
#  ('developing', 'VERB'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('supercomputer', 'NOUN'),
#  (',', '.'),
#  ('heavily', 'ADV'),
#  ('on', 'ADP'),
#  ('its', 'PRON'),
#  ('chairman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('chief', 'NOUN'),
#  ('designer', 'NOUN'),
#  (',', '.'),
#  ('Seymour', 'NOUN'),
#  ('Cray', 'NOUN'),
#  ('.', '.'),
#  ('Congress', 'NOUN'),
#  ('learned', 'VERB'),
#  ('during', 'ADP'),
#  ('the', 'DET'),
#  ('Reagan', 'NOUN'),
#  ('administration', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('could', 'VERB'),
#  ('the', 'DET'),
#  ('branch', 'NOUN'),
#  ('by', 'ADP'),
#  ('*-1', 'X'),
#  ('again', 'ADV'),
#  ('and', 'CONJ'),
#  ('again', 'ADV'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('seven', 'NUM'),
#  ('words', 'NOUN'),
#  (':', '.'),
#  ('``', '.'),
#  (',', '.'),
#  ('no', 'DET'),
#  ('funds', 'NOUN'),
#  ('shall', 'VERB'),
#  ('be', 'VERB'),
#  ('spent', 'VERB'),
#  ('*-48', 'X'),
#  ('...', '.'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Then', 'ADV'),
#  ('*', 'X'),
#  ('send', 'VERB'),
#  ('your', 'PRON'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('savings', 'NOUN'),
#  ('institution', 'NOUN'),
#  ('has', 'VERB'),
#  ('taken', 'VERB'),
#  ('a', 'DET'),
#  ('bad', 'ADJ'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('press', 'NOUN'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('its', 'PRON'),
#  ('line', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('other', 'ADJ'),
#  ('concern', 'NOUN'),
#  ('was', 'VERB'),
#  ("n't", 'ADV'),
#  ('identified', 'VERB'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('Stronach', 'NOUN'),
#  (',', '.'),
#  ('founder', 'NOUN'),
#  ('and', 'CONJ'),
#  ('controlling', 'VERB'),
#  ('shareholder', 'NOUN'),
#  ('of', 'ADP'),
#  ('Magna', 'NOUN'),
#  (',', '.'),
#  ('resigned', 'VERB'),
#  ('as', 'ADP'),
#  ('chief', 'NOUN'),
#  ('executive', 'NOUN'),
#  ('officer', 'NOUN'),
#  ('last', 'ADJ'),
#  ('year', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('seek', 'VERB'),
#  (',', '.'),
#  ('unsuccessfully', 'ADV'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('seat', 'NOUN'),
#  ('in', 'ADP'),
#  ('Canada', 'NOUN'),
#  ("'s", 'PRT'),
#  ('Parliament', 'NOUN'),
#  ('.', '.'),
#  ('60', 'NUM'),
#  ('million', 'NUM'),
#  ('Swiss', 'ADJ'),
#  ('francs', 'NOUN'),
#  ('of', 'ADP'),
#  ('privately', 'ADV'),
#  ('placed', 'VERB'),
#  ('convertible', 'ADJ'),
#  ('notes', 'NOUN'),
#  ('due', 'ADJ'),
#  ('Dec.', 'NOUN'),
#  ('31', 'NUM'),
#  (',', '.'),
#  ('1993', 'NUM'),
#  (',', '.'),
#  ('with', 'ADP'),
#  ('a', 'DET'),
#  ('fixed', 'VERB'),
#  ('0.25', 'NUM'),
#  ('%', 'NOUN'),
#  ('coupon', 'NOUN'),
#  ('at', 'ADP'),
#  ('par', 'NOUN'),
#  ('via', 'ADP'),
#  ('Union', 'NOUN'),
#  ('Bank', 'NOUN'),
#  ('of', 'ADP'),
#  ('Switzerland', 'NOUN'),
#  ('.', '.'),
#  ('It', 'PRON'),
#  ('also', 'ADV'),
#  ('would', 'VERB'),
#  ('an', 'DET'),
#  ('system', 'NOUN'),
#  ('for', 'ADP'),
#  ('*', 'X'),
#  ('emissions', 'NOUN'),
#  ('credits', 'NOUN'),
#  ('among', 'ADP'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('other', 'ADJ'),
#  ('commodity', 'NOUN'),
#  ('markets', 'NOUN'),
#  ('yesterday', 'NOUN'),
#  (':', '.'),
#  (',', '.'),
#  ('it', 'PRON'),
#  ('never', 'ADV'),
#  ('recovered', 'VERB'),
#  (';', '.'),
#  ('editorially', 'ADV'),
#  (',', '.'),
#  ('it', 'PRON'),
#  ('had', 'VERB'),
#  ('its', 'PRON'),
#  ('.', '.'),
#  ('that', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('investors', 'NOUN'),
#  ('are', 'VERB'),
#  ('buying', 'VERB'),
#  ('America', 'NOUN'),
#  ('have', 'VERB'),
#  ('sharply', 'ADV'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ...]

# %%
accuracy = len(Matched_tags)/len(tagged_seq)
accuracy
# Out:
# 0.8958158995815899

# %% [markdown]
# **Observation** - The accuracy of the Vanilla Veterbi algorithm is 89.83%. We will modify the Veterbi algorithm and compare its performance

# %% [markdown]
# ### Creating a dataframe for accuracy of different modifications of Viterbi

# %%
columns = ['Algorithm','Accuracy']
Accuracy_df = pd.DataFrame(columns = columns)
new_row = {'Algorithm':' Vannila Viterbi', 'Accuracy':accuracy}
Accuracy_df = Accuracy_df.append(new_row, ignore_index=True)
Accuracy_df
# Out:
#           Algorithm  Accuracy
# 0   Vannila Viterbi  0.895816

# %% [markdown]
# #### Incorrect tags
# j - contains the tags assigned by Vanilla Viterbi Algorithm and by humans.

# %%
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[('$', '.'), (('55-a-share', 'PRON'), ('55-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('bid', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [(',', '.'), (('steps', 'NOUN'), ('steps', 'VERB'))],
#  [('.', '.'), (('Already', 'PRON'), ('Already', 'ADV'))],
#  [('various', 'ADJ'), (('swaps', 'PRON'), ('swaps', 'NOUN'))],
#  [(',', '.'), (('Old-House', 'PRON'), ('Old-House', 'NOUN'))],
#  [('her', 'PRON'), (('publishing', 'VERB'), ('publishing', 'NOUN'))],
#  [('all', 'DET'), (('126,000', 'PRON'), ('126,000', 'NUM'))],
#  [('a', 'DET'), (('worst-case', 'PRON'), ('worst-case', 'ADJ'))],
#  [('bold', 'ADJ'), (('palace', 'PRON'), ('palace', 'NOUN'))],
#  [('palace', 'NOUN'), (('revolt', 'PRON'), ('revolt', 'NOUN'))],
#  [('to', 'PRT'), (('telephone', 'NOUN'), ('telephone', 'VERB'))],
#  [('them', 'PRON'), (('pressure', 'NOUN'), ('pressure', 'VERB'))],
#  [('to', 'PRT'), (('ban', 'NOUN'), ('ban', 'VERB'))],
#  [('traders', 'NOUN'), (('answer', 'NOUN'), ('answer', 'VERB'))],
#  [('reform', 'NOUN'), (('instituted', 'PRON'), ('instituted', 'VERB'))],
#  [('Great', 'NOUN'), (('Crash', 'PRON'), ('Crash', 'NOUN'))],
#  [('1929', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-1', 'X'), (('protects', 'PRON'), ('protects', 'VERB'))],
#  [('being', 'VERB'), (('relentlessly', 'PRON'), ('relentlessly', 'ADV'))],
#  [('*-2', 'X'), (('downward', 'ADJ'), ('downward', 'ADV'))],
#  [('to', 'PRT'), (('profit', 'NOUN'), ('profit', 'VERB'))],
#  [('of', 'ADP'), (('Clarence', 'PRON'), ('Clarence', 'NOUN'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('``', '.'), (('qualified', 'VERB'), ('qualified', 'ADJ'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('who', 'PRON'), (('*T*-127', 'PRON'), ('*T*-127', 'X'))],
#  [('their', 'PRON'), (('identities', 'PRON'), ('identities', 'NOUN'))],
#  [('that', 'ADP'), (('durable-goods', 'PRON'), ('durable-goods', 'NOUN'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('debt', 'NOUN'), (('swaps', 'PRON'), ('swaps', 'NOUN'))],
#  [('of', 'ADP'), (('3,250,000', 'PRON'), ('3,250,000', 'NUM'))],
#  [('which', 'DET'), (('3,040,000', 'PRON'), ('3,040,000', 'NUM'))],
#  [('and', 'CONJ'), (('210,000', 'PRON'), ('210,000', 'NUM'))],
#  [('Capital', 'NOUN'), (('Funding', 'PRON'), ('Funding', 'NOUN'))],
#  [('and', 'CONJ'), (('Hanifen', 'PRON'), ('Hanifen', 'NOUN'))],
#  [(',', '.'), (('Imhoff', 'PRON'), ('Imhoff', 'NOUN'))],
#  [("'s", 'PRT'), (('calculations', 'PRON'), ('calculations', 'NOUN'))],
#  [('far', 'ADV'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('Florio', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('goes', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [("'s", 'PRT'), (('land', 'VERB'), ('land', 'NOUN'))],
#  [('was', 'VERB'), (('cleaned', 'PRON'), ('cleaned', 'VERB'))],
#  [('no', 'DET'), (('pollution', 'PRON'), ('pollution', 'NOUN'))],
#  [('with', 'ADP'), (('combined', 'ADJ'), ('combined', 'VERB'))],
#  [('*', 'X'), (('labeling', 'PRON'), ('labeling', 'VERB'))],
#  [("''", '.'), (('McDermott', 'PRON'), ('McDermott', 'NOUN'))],
#  [('its', 'PRON'), (('Babcock', 'PRON'), ('Babcock', 'NOUN'))],
#  [('&', 'CONJ'), (('Wilcox', 'PRON'), ('Wilcox', 'NOUN'))],
#  [('Controls', 'NOUN'), (('Operations', 'PRON'), ('Operations', 'NOUN'))],
#  [('Finmeccanica', 'NOUN'), (('S.p', 'PRON'), ('S.p', 'NOUN'))],
#  [('$', '.'), (('295', 'PRON'), ('295', 'NUM'))],
#  [('*T*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('leaders', 'NOUN'), (('rebuked', 'PRON'), ('rebuked', 'VERB'))],
#  [('and', 'CONJ'), (('fretted', 'PRON'), ('fretted', 'VERB'))],
#  [('In', 'ADP'), (('1973', 'PRON'), ('1973', 'NUM'))],
#  [(',', '.'), (('Wells', 'PRON'), ('Wells', 'NOUN'))],
#  [('Wells', 'NOUN'), (('Fargo', 'PRON'), ('Fargo', 'NOUN'))],
#  [('which', 'DET'), (('*T*-198', 'PRON'), ('*T*-198', 'X'))],
#  [(',', '.'), (('safe-deposit', 'PRON'), ('safe-deposit', 'ADJ'))],
#  [('and', 'CONJ'), (('travelers', 'PRON'), ('travelers', 'NOUN'))],
#  [('hurt', 'VERB'), (('U.S.-Japan', 'PRON'), ('U.S.-Japan', 'ADJ'))],
#  [('a', 'DET'), (('minus', 'PRON'), ('minus', 'NOUN'))],
#  [('expanded', 'VERB'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('the', 'DET'), (('Overseas', 'PRON'), ('Overseas', 'NOUN'))],
#  [('Overseas', 'NOUN'), (('Private', 'ADJ'), ('Private', 'NOUN'))],
#  [('which', 'DET'), (('*T*-139', 'PRON'), ('*T*-139', 'X'))],
#  [('a', 'DET'), (('tie-breaking', 'PRON'), ('tie-breaking', 'ADJ'))],
#  [('Oct.', 'NOUN'), (('2-8', 'PRON'), ('2-8', 'NUM'))],
#  [('year', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('to', 'PRT'), (('A.C.', 'PRON'), ('A.C.', 'NOUN'))],
#  [('A.C.', 'NOUN'), (('Nielsen', 'PRON'), ('Nielsen', 'NOUN'))],
#  [('and', 'CONJ'), (('uncompensated', 'PRON'), ('uncompensated', 'ADJ'))],
#  [('uncompensated', 'ADJ'), (('takings', 'PRON'), ('takings', 'NOUN'))],
#  [('might', 'VERB'), (('gyrate', 'PRON'), ('gyrate', 'VERB'))],
#  [('exporters', 'NOUN'), (('scrounge', 'PRON'), ('scrounge', 'VERB'))],
#  [('Still', 'ADV'), (('unresolved', 'PRON'), ('unresolved', 'ADJ'))],
#  [('producers', 'NOUN'), (('Jon', 'PRON'), ('Jon', 'NOUN'))],
#  [('Jon', 'NOUN'), (('Peters', 'PRON'), ('Peters', 'NOUN'))],
#  [('Peter', 'NOUN'), (('Guber', 'PRON'), ('Guber', 'NOUN'))],
#  [('thrift', 'NOUN'), (('till', 'PRON'), ('till', 'ADP'))],
#  [('the', 'DET'), (('issuer', 'PRON'), ('issuer', 'NOUN'))],
#  [('goes', 'VERB'), (('bust', 'PRON'), ('bust', 'NOUN'))],
#  [('or', 'CONJ'), (('restructures', 'PRON'), ('restructures', 'VERB'))],
#  [('do', 'VERB'), (('all', 'DET'), ('all', 'ADV'))],
#  [('all', 'ADV'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('been', 'VERB'), (('aiming', 'PRON'), ('aiming', 'VERB'))],
#  [('the', 'DET'), (('elderly', 'PRON'), ('elderly', 'ADJ'))],
#  [(',', '.'), (('depends', 'PRON'), ('depends', 'VERB'))],
#  [('could', 'VERB'), (('intimidate', 'PRON'), ('intimidate', 'VERB'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('*-1', 'X'), (('uttering', 'PRON'), ('uttering', 'VERB'))],
#  [('``', '.'), (('Provided', 'PRON'), ('Provided', 'VERB'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('your', 'PRON'), (('support', 'VERB'), ('support', 'NOUN'))],
#  [('institution', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-208', 'PRON'), ('*T*-208', 'X'))],
#  [('bad', 'ADJ'), (('rap', 'PRON'), ('rap', 'NOUN'))],
#  [('its', 'PRON'), (('bottom', 'NOUN'), ('bottom', 'ADJ'))],
#  [('would', 'VERB'), (('junk', 'NOUN'), ('junk', 'VERB'))],
#  [('an', 'DET'), (('innovative', 'PRON'), ('innovative', 'ADJ'))],
#  [('innovative', 'ADJ'), (('market-based', 'PRON'), ('market-based', 'ADJ'))],
#  [('*', 'X'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [('among', 'ADP'), (('polluters', 'PRON'), ('polluters', 'NOUN'))],
#  [(':', '.'), (('Financially', 'PRON'), ('Financially', 'ADV'))],
#  [('its', 'PRON'), (('moments', 'PRON'), ('moments', 'NOUN'))],
#  [('.', '.'), (('Fears', 'PRON'), ('Fears', 'NOUN'))],
#  [('buying', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('have', 'VERB'), (('escalated', 'PRON'), ('escalated', 'VERB'))],
#  [('from', 'ADP'), (('Coca-Cola', 'PRON'), ('Coca-Cola', 'NOUN'))],
#  [('%', 'NOUN'), (('holding', 'VERB'), ('holding', 'NOUN'))],
#  [('of', 'ADP'), (('midtown', 'PRON'), ('midtown', 'NOUN'))],
#  [("'s", 'PRT'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('The', 'DET'), (('location', 'PRON'), ('location', 'NOUN'))],
#  [('Dec.', 'NOUN'), (('2-3', 'PRON'), ('2-3', 'NUM'))],
#  [('2-3', 'NUM'), (('tete-a-tete', 'PRON'), ('tete-a-tete', 'NOUN'))],
#  [('was', 'VERB'), (('116.9', 'PRON'), ('116.9', 'NUM'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('of', 'ADP'), (('112.9', 'PRON'), ('112.9', 'NUM'))],
#  [('of', 'ADP'), (('120.7', 'PRON'), ('120.7', 'NUM'))],
#  [('auctioned', 'VERB'), (('*-109', 'PRON'), ('*-109', 'X'))],
#  [('yield', 'VERB'), (('7.65', 'PRON'), ('7.65', 'NUM'))],
#  [('drifted', 'VERB'), (('lower', 'ADJ'), ('lower', 'ADV'))],
#  [('lower', 'ADV'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('U.S.', 'NOUN'), (('purchasing', 'VERB'), ('purchasing', 'NOUN'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('*-2', 'X'), (('successfully', 'PRON'), ('successfully', 'ADV'))],
#  [('successfully', 'ADV'), (('mobilizing', 'PRON'), ('mobilizing', 'VERB'))],
#  [('to', 'PRT'), (('bludgeon', 'PRON'), ('bludgeon', 'VERB'))],
#  [('their', 'PRON'), (('tormentors', 'PRON'), ('tormentors', 'NOUN'))],
#  [('said', 'VERB'), (('repeatedly', 'PRON'), ('repeatedly', 'ADV'))],
#  [('stay', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('issue', 'NOUN'), (('trades', 'NOUN'), ('trades', 'VERB'))],
#  [('its', 'PRON'), (('face', 'VERB'), ('face', 'NOUN'))],
#  [('rate', 'NOUN'), (('indications', 'PRON'), ('indications', 'NOUN'))],
#  [('by', 'ADP'), (('location', 'PRON'), ('location', 'NOUN'))],
#  [(',', '.'), (('Pennview', 'PRON'), ('Pennview', 'NOUN'))],
#  [('Association', 'NOUN'), (('leapt', 'PRON'), ('leapt', 'VERB'))],
#  [('has', 'VERB'), (('instituted', 'PRON'), ('instituted', 'VERB'))],
#  [('effective', 'ADJ'),
#   (('search-and-seizure', 'PRON'), ('search-and-seizure', 'ADJ'))],
#  [('to', 'PRT'), (('aid', 'NOUN'), ('aid', 'VERB'))],
#  [('system', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('soared', 'VERB'), (('higher', 'ADJ'), ('higher', 'ADV'))],
#  [('.', '.'), (('Cataracts', 'PRON'), ('Cataracts', 'NOUN'))],
#  [('Cataracts', 'NOUN'), (('refer', 'PRON'), ('refer', 'VERB'))],
#  [('a', 'DET'), (('clouding', 'PRON'), ('clouding', 'NOUN'))],
#  [('a', 'DET'), (('needy', 'PRON'), ('needy', 'ADJ'))],
#  [('loan', 'NOUN'), (('solvent', 'PRON'), ('solvent', 'ADJ'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('almost', 'ADV'), (('over', 'ADP'), ('over', 'ADJ'))],
#  [('by', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('to', 'PRT'), (('8.75', 'PRON'), ('8.75', 'NUM'))],
#  [('has', 'VERB'), (('shown', 'PRON'), ('shown', 'VERB'))],
#  [('shown', 'VERB'), (('no', 'ADV'), ('no', 'DET'))],
#  [('no', 'DET'), (('sign', 'VERB'), ('sign', 'NOUN'))],
#  [('default', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('expected', 'VERB'), (('*-129', 'PRON'), ('*-129', 'X'))],
#  [('a', 'DET'), (('disadvantage', 'PRON'), ('disadvantage', 'NOUN'))],
#  [('Street', 'NOUN'), (('rivals', 'PRON'), ('rivals', 'NOUN'))],
#  [('a', 'DET'), (('richer', 'PRON'), ('richer', 'ADJ'))],
#  [('the', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('profitable', 'ADJ'), (('pipe', 'PRON'), ('pipe', 'NOUN'))],
#  [('and', 'CONJ'), (('galvanized', 'PRON'), ('galvanized', 'ADJ'))],
#  [('galvanized', 'ADJ'), (('coated', 'PRON'), ('coated', 'VERB'))],
#  [('than', 'ADP'), (('lower-priced', 'PRON'), ('lower-priced', 'ADJ'))],
#  [('lower-priced', 'ADJ'), (('structural', 'PRON'), ('structural', 'ADJ'))],
#  [('.', '.'), (('PHOTOGRAPH', 'PRON'), ('PHOTOGRAPH', 'NOUN'))],
#  [('PHOTOGRAPH', 'NOUN'), (('COLLECTING', 'PRON'), ('COLLECTING', 'NOUN'))],
#  [('COLLECTING', 'NOUN'), (('gains', 'NOUN'), ('gains', 'VERB'))],
#  [('the', 'DET'), (('electorate', 'PRON'), ('electorate', 'NOUN'))],
#  [('a', 'DET'), (('valuable', 'PRON'), ('valuable', 'ADJ'))],
#  [('valuable', 'ADJ'), (('civics', 'PRON'), ('civics', 'NOUN'))],
#  [('powers', 'NOUN'), (('works', 'NOUN'), ('works', 'VERB'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('*-1', 'X'), (('Concerned', 'PRON'), ('Concerned', 'VERB'))],
#  [('about', 'ADP'), (('shrinking', 'PRON'), ('shrinking', 'VERB'))],
#  [('shrinking', 'VERB'), (('landfills', 'PRON'), ('landfills', 'NOUN'))],
#  [('in', 'ADP'), (('super-absorbent', 'PRON'), ('super-absorbent', 'ADJ'))],
#  [('super-absorbent', 'ADJ'),
#   (('disposables', 'PRON'), ('disposables', 'NOUN'))],
#  [('some', 'DET'), (('light', 'ADJ'), ('light', 'NOUN'))],
#  [('the', 'DET'), (('dark', 'PRON'), ('dark', 'ADJ'))],
#  [('where', 'ADV'), (('high-stakes', 'PRON'), ('high-stakes', 'ADJ'))],
#  [('has', 'VERB'), (('enhanced', 'PRON'), ('enhanced', 'VERB'))],
#  [('to', 'PRT'), (('cheat', 'PRON'), ('cheat', 'VERB'))],
#  [('in', 'ADP'), (('jeopardy', 'PRON'), ('jeopardy', 'NOUN'))],
#  [('is', 'VERB'), (('wrestling', 'PRON'), ('wrestling', 'VERB'))],
#  [('especially', 'ADV'), (('intelligent', 'PRON'), ('intelligent', 'ADJ'))],
#  [('temporarily', 'ADV'), (('insane', 'PRON'), ('insane', 'ADJ'))],
#  [('movie', 'NOUN'), (('ends', 'NOUN'), ('ends', 'VERB'))],
#  [('anything', 'NOUN'), (('whimsical', 'PRON'), ('whimsical', 'ADJ'))],
#  [('or', 'CONJ'), (('enviable', 'PRON'), ('enviable', 'ADJ'))],
#  [(',', '.'), (('beaten', 'VERB'), ('beaten', 'ADJ'))],
#  [("'s", 'PRT'), (('Kingsbridge', 'PRON'), ('Kingsbridge', 'NOUN'))],
#  [('Cara', 'NOUN'), (('Operations', 'PRON'), ('Operations', 'NOUN'))],
#  [('$', '.'), (('45-a-share', 'PRON'), ('45-a-share', 'ADJ'))],
#  [('45-a-share', 'ADJ'), (('offer', 'VERB'), ('offer', 'NOUN'))],
#  [("Dunkin'", 'NOUN'), (('Donuts', 'PRON'), ('Donuts', 'NOUN'))],
#  [('its', 'PRON'), (('Eveready', 'PRON'), ('Eveready', 'NOUN'))],
#  [('A', 'DET'), (('painting', 'PRON'), ('painting', 'NOUN'))],
#  [('August', 'NOUN'), (('Strindberg', 'PRON'), ('Strindberg', 'NOUN'))],
#  [('a', 'DET'), (('Scandinavian', 'PRON'), ('Scandinavian', 'ADJ'))],
#  [('$', '.'), (('2.44', 'PRON'), ('2.44', 'NUM'))],
#  [('``', '.'), (('Little', 'ADV'), ('Little', 'ADJ'))],
#  [('*-1', 'X'), (('wanting', 'PRON'), ('wanting', 'VERB'))],
#  [('.', '.'), (('Troubled', 'PRON'), ('Troubled', 'NOUN'))],
#  [('fired', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('its', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('is', 'VERB'), (('discontinuing', 'PRON'), ('discontinuing', 'VERB'))],
#  [('which', 'DET'), (('there', 'ADV'), ('there', 'DET'))],
#  [('economic', 'ADJ'), (('slowdowns', 'PRON'), ('slowdowns', 'NOUN'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'ADJ'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'ADJ'))],
#  [('Thomas', 'NOUN'), (('Doerflinger', 'PRON'), ('Doerflinger', 'NOUN'))],
#  [('-LRB-', '.'), (('Fewer', 'PRON'), ('Fewer', 'ADJ'))],
#  [('``', '.'), (('Ideas', 'PRON'), ('Ideas', 'NOUN'))],
#  [('over', 'ADP'), (('borders', 'PRON'), ('borders', 'NOUN'))],
#  [('no', 'DET'), (('SDI', 'PRON'), ('SDI', 'NOUN'))],
#  [('ideological', 'ADJ'), (('weapon', 'PRON'), ('weapon', 'NOUN'))],
#  [('weapon', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-245', 'PRON'), ('*T*-245', 'X'))],
#  [('can', 'VERB'), (('shoot', 'PRON'), ('shoot', 'VERB'))],
#  [('them', 'PRON'), (('down', 'ADV'), ('down', 'ADP'))],
#  [('.', '.'), (('Tray', 'PRON'), ('Tray', 'NOUN'))],
#  [('Tray', 'NOUN'), (('Bon', 'PRON'), ('Bon', 'NOUN'))],
#  [("'s", 'VERB'), (('imaginative', 'PRON'), ('imaginative', 'ADJ'))],
#  [('were', 'VERB'), (('granted', 'PRON'), ('granted', 'VERB'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('*ICH*-1', 'X'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('export', 'NOUN'), (('licenses', 'PRON'), ('licenses', 'NOUN'))],
#  [('.', '.'), (('Cartoonist', 'PRON'), ('Cartoonist', 'NOUN'))],
#  [('Cartoonist', 'NOUN'), (('Garry', 'PRON'), ('Garry', 'NOUN'))],
#  [('and', 'CONJ'), (('punish', 'PRON'), ('punish', 'VERB'))],
#  [('a', 'DET'), (('screenwriters', 'PRON'), ('screenwriters', 'NOUN'))],
#  [('which', 'DET'), (('*T*-147', 'PRON'), ('*T*-147', 'X'))],
#  [('*T*-147', 'X'), (('measures', 'NOUN'), ('measures', 'VERB'))],
#  [('the', 'DET'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('of', 'ADP'), (('45.3', 'PRON'), ('45.3', 'NUM'))],
#  [('a', 'DET'), (('stark', 'PRON'), ('stark', 'ADJ'))],
#  [('traditional', 'ADJ'),
#   (('policy-making', 'PRON'), ('policy-making', 'ADJ'))],
#  [('the', 'DET'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('to', 'PRT'), (('debate', 'NOUN'), ('debate', 'VERB'))],
#  [('and', 'CONJ'), (('innovation', 'PRON'), ('innovation', 'NOUN'))],
#  [('Rick', 'NOUN'), (('Wamre', 'PRON'), ('Wamre', 'NOUN'))],
#  [('a', 'DET'), (('31-year-old', 'PRON'), ('31-year-old', 'ADJ'))],
#  [('would', 'VERB'), (('like', 'ADP'), ('like', 'VERB'))],
#  [('trading', 'NOUN'), (('disappear', 'PRON'), ('disappear', 'VERB'))],
#  [('The', 'DET'), (('Austin', 'PRON'), ('Austin', 'NOUN'))],
#  [(',', '.'), (('Texas-based', 'PRON'), ('Texas-based', 'ADJ'))],
#  [('System', 'NOUN'), (('210', 'PRON'), ('210', 'NUM'))],
#  [('with', 'ADP'), (('512', 'PRON'), ('512', 'NUM'))],
#  [('512', 'NUM'), (('kilobytes', 'PRON'), ('kilobytes', 'NOUN'))],
#  [('a', 'DET'), (('40-megabyte', 'PRON'), ('40-megabyte', 'ADJ'))],
#  [('a', 'DET'), (('color', 'VERB'), ('color', 'NOUN'))],
#  [('color', 'NOUN'), (('monitor', 'PRON'), ('monitor', 'NOUN'))],
#  [('are', 'VERB'), (('stretching', 'PRON'), ('stretching', 'VERB'))],
#  [('their', 'PRON'), (('nets', 'PRON'), ('nets', 'NOUN'))],
#  [('and', 'CONJ'), (('wide', 'ADJ'), ('wide', 'ADV'))],
#  [('a', 'DET'), (('fledgling', 'PRON'), ('fledgling', 'NOUN'))],
#  [('to', 'PRT'), (('depend', 'PRON'), ('depend', 'VERB'))],
#  [('and', 'CONJ'), (('longevity', 'PRON'), ('longevity', 'NOUN'))],
#  [('has', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('have', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('much', 'ADJ'), (('sympathy', 'PRON'), ('sympathy', 'NOUN'))],
#  [('.', '.'), (('Second', 'NOUN'), ('Second', 'ADJ'))],
#  [('they', 'PRON'), (('channel', 'PRON'), ('channel', 'VERB'))],
#  [('Mitsubishi', 'NOUN'), (('Pencil', 'PRON'), ('Pencil', 'NOUN'))],
#  [('That', 'DET'), (('attracts', 'PRON'), ('attracts', 'VERB'))],
#  [('was', 'VERB'), (('kind', 'NOUN'), ('kind', 'ADJ'))],
#  [('and', 'CONJ'), (('playful', 'PRON'), ('playful', 'ADJ'))],
#  [('was', 'VERB'), (('dreadful', 'PRON'), ('dreadful', 'ADJ'))],
#  [('her', 'PRON'), (('war-damaged', 'PRON'), ('war-damaged', 'ADJ'))],
#  [('her', 'PRON'), (('lover', 'PRON'), ('lover', 'NOUN'))],
#  [('called', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('to', 'PRT'), (('arrest', 'PRON'), ('arrest', 'VERB'))],
#  [('were', 'VERB'), (('occupying', 'PRON'), ('occupying', 'VERB'))],
#  [('Japanese', 'ADJ'), (('contribution', 'PRON'), ('contribution', 'NOUN'))],
#  [('.', '.'), (('Back', 'PRON'), ('Back', 'ADV'))],
#  [('the', 'DET'), (('execs', 'PRON'), ('execs', 'NOUN'))],
#  [('squeezed', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('*-1', 'X'), (('boarding', 'PRON'), ('boarding', 'VERB'))],
#  [('scientists', 'NOUN'), (('breathed', 'PRON'), ('breathed', 'VERB'))],
#  [('a', 'DET'), (('collective', 'PRON'), ('collective', 'ADJ'))],
#  [('collective', 'ADJ'), (('sigh', 'PRON'), ('sigh', 'NOUN'))],
#  [('it', 'PRON'), (('demonstrates', 'PRON'), ('demonstrates', 'VERB'))],
#  [('``', '.'), (('flux', 'PRON'), ('flux', 'NOUN'))],
#  [('flux', 'NOUN'), (('pinning', 'PRON'), ('pinning', 'NOUN'))],
#  [('*T*-1', 'X'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('*', 'X'), (('undercutting', 'PRON'), ('undercutting', 'VERB'))],
#  [("'", 'PRT'), (('potential', 'ADJ'), ('potential', 'NOUN'))],
#  [('.', '.'), (('b', 'PRON'), ('b', 'X'))],
#  [('.', '.'), (('Dreyfus', 'PRON'), ('Dreyfus', 'NOUN'))],
#  [('Dreyfus', 'NOUN'), (('World-Wide', 'PRON'), ('World-Wide', 'NOUN'))],
#  [('the', 'DET'), (('top-yielding', 'PRON'), ('top-yielding', 'ADJ'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('of', 'ADP'), (('9.37', 'PRON'), ('9.37', 'NUM'))],
#  [('from', 'ADP'), (('9.45', 'PRON'), ('9.45', 'NUM'))],
#  [('Israel', 'NOUN'), (('Silverman', 'PRON'), ('Silverman', 'NOUN'))],
#  [('an', 'DET'),
#   (('insurance-company', 'PRON'), ('insurance-company', 'NOUN'))],
#  [(',', '.'), (('comments', 'NOUN'), ('comments', 'VERB'))],
#  [('``', '.'), (('increases', 'NOUN'), ('increases', 'VERB'))],
#  [('will', 'VERB'), (('oversee', 'PRON'), ('oversee', 'VERB'))],
#  [('get', 'VERB'), (('across', 'ADP'), ('across', 'PRT'))],
#  [('the', 'DET'), (('onus', 'PRON'), ('onus', 'NOUN'))],
#  [('a', 'DET'), (('razor-thin', 'PRON'), ('razor-thin', 'ADJ'))],
#  [('go', 'VERB'), (('through', 'ADP'), ('through', 'PRT'))],
#  [('Beijing', 'NOUN'), (('food-shop', 'PRON'), ('food-shop', 'ADJ'))],
#  [('food-shop', 'ADJ'), (('assistant', 'ADJ'), ('assistant', 'NOUN'))],
#  [('first', 'ADJ'), (('mainland', 'PRON'), ('mainland', 'NOUN'))],
#  [('mainland', 'NOUN'), (('Chinese', 'ADJ'), ('Chinese', 'NOUN'))],
#  [('*-1', 'X'), (('sketching', 'PRON'), ('sketching', 'VERB'))],
#  [('sketching', 'VERB'), (('passers-by', 'PRON'), ('passers-by', 'NOUN'))],
#  [('Too', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('give', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('Paul', 'NOUN'), (('Sandifer', 'PRON'), ('Sandifer', 'NOUN'))],
#  [('are', 'VERB'), (('purely', 'PRON'), ('purely', 'ADV'))],
#  [('without', 'ADP'), (('foundation', 'PRON'), ('foundation', 'NOUN'))],
#  [('unfair', 'ADJ'), (('inferences', 'PRON'), ('inferences', 'NOUN'))],
#  [('*', 'X'), (('Being', 'PRON'), ('Being', 'VERB'))],
#  [('the', 'DET'), (('37-year-old', 'PRON'), ('37-year-old', 'ADJ'))],
#  [('her', 'PRON'), (('dismissal', 'PRON'), ('dismissal', 'NOUN'))],
#  [('its', 'PRON'), (('centennial', 'PRON'), ('centennial', 'NOUN'))],
#  [(',', '.'), (('The', 'DET'), ('The', 'NOUN'))],
#  [('will', 'VERB'), (('report', 'NOUN'), ('report', 'VERB'))],
#  [('century', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('as', 'ADP'), (('milestones', 'PRON'), ('milestones', 'NOUN'))],
#  [('has', 'VERB'), (('hunted', 'PRON'), ('hunted', 'VERB'))],
#  [('other', 'ADJ'), (('bargains', 'PRON'), ('bargains', 'NOUN'))],
#  [('ran', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('*T*-14', 'X'), (('matters', 'NOUN'), ('matters', 'VERB'))],
#  [('doing', 'VERB'), (('fine', 'NOUN'), ('fine', 'ADV'))],
#  [('not', 'ADV'), (('unethical', 'PRON'), ('unethical', 'ADJ'))],
#  [('a', 'DET'), (('higher-salaried', 'PRON'), ('higher-salaried', 'ADJ'))],
#  [('with', 'ADP'), (('Premier', 'PRON'), ('Premier', 'NOUN'))],
#  [('Li', 'NOUN'), (('Peng', 'PRON'), ('Peng', 'NOUN'))],
#  [('he', 'PRON'), (('hoped', 'PRON'), ('hoped', 'VERB'))],
#  [("n't", 'ADV'), (('encounter', 'PRON'), ('encounter', 'VERB'))],
#  [('machine', 'NOUN'), (('guns', 'PRON'), ('guns', 'NOUN'))],
#  [('that', 'ADP'), (('non-farm', 'PRON'), ('non-farm', 'ADJ'))],
#  [('by', 'ADP'), (('152,000', 'PRON'), ('152,000', 'NUM'))],
#  [('.', '.'), (('EVERYONE', 'PRON'), ('EVERYONE', 'NOUN'))],
#  [('EVERYONE', 'NOUN'), (('AGREES', 'PRON'), ('AGREES', 'VERB'))],
#  [('be', 'VERB'), (('repaired', 'PRON'), ('repaired', 'VERB'))],
#  [('with', 'ADP'),
#   (('yttrium-containing', 'PRON'), ('yttrium-containing', 'ADJ'))],
#  [('to', 'PRT'), (('liquid-nitrogen', 'PRON'), ('liquid-nitrogen', 'NOUN'))],
#  [('liquid-nitrogen', 'NOUN'),
#   (('temperature', 'PRON'), ('temperature', 'NOUN'))],
#  [('or', 'CONJ'), (('minus', 'PRON'), ('minus', 'CONJ'))],
#  [('minus', 'CONJ'), (('321', 'PRON'), ('321', 'NUM'))],
#  [('degrees', 'NOUN'), (('Fahrenheit', 'PRON'), ('Fahrenheit', 'NOUN'))],
#  [('.', '.'), (('Bears', 'PRON'), ('Bears', 'NOUN'))],
#  [('the', 'DET'), (('shaky', 'PRON'), ('shaky', 'ADJ'))],
#  [('.', '.'), (('Pressures', 'PRON'), ('Pressures', 'NOUN'))],
#  [('.', '.'), (('Signs', 'PRON'), ('Signs', 'NOUN'))],
#  [('a', 'DET'), (('slowing', 'NOUN'), ('slowing', 'VERB'))],
#  [(':', '.'), (('day-care', 'PRON'), ('day-care', 'ADJ'))],
#  [('day-care', 'ADJ'), (('centers', 'VERB'), ('centers', 'NOUN'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('previously', 'ADV'), (('spurned', 'PRON'), ('spurned', 'VERB'))],
#  [('.', '.'), (('Mortgage-Backed', 'PRON'), ('Mortgage-Backed', 'NOUN'))],
#  [('is', 'VERB'), (('conducted', 'PRON'), ('conducted', 'VERB'))],
#  [('Family', 'NOUN'), (('Opinion', 'PRON'), ('Opinion', 'NOUN'))],
#  [('or', 'CONJ'), (('early', 'ADJ'), ('early', 'ADV'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('this', 'DET'), (('minute', 'ADJ'), ('minute', 'NOUN'))],
#  [('said', 'VERB'), (('universally', 'PRON'), ('universally', 'ADV'))],
#  [('its', 'PRON'), (('Fax', 'PRON'), ('Fax', 'NOUN'))],
#  [('to', 'PRT'), (('Ogilvy', 'PRON'), ('Ogilvy', 'NOUN'))],
#  [('&', 'CONJ'), (('Mather', 'PRON'), ('Mather', 'NOUN'))],
#  [('a', 'DET'), (('WPP', 'PRON'), ('WPP', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-84', 'PRON'), ('*T*-84', 'X'))],
#  [('for', 'ADP'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [(',', '.'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('will', 'VERB'), (('worsen', 'PRON'), ('worsen', 'VERB'))],
#  [('specialized', 'VERB'), (('boilers', 'PRON'), ('boilers', 'NOUN'))],
#  [('and', 'CONJ'), (('pipes', 'PRON'), ('pipes', 'NOUN'))],
#  [('own', 'ADJ'), (('Lurgi', 'PRON'), ('Lurgi', 'NOUN'))],
#  [('Lurgi', 'NOUN'), (('G.m.b', 'PRON'), ('G.m.b', 'NOUN'))],
#  [('plant', 'NOUN'), (('engineering', 'NOUN'), ('engineering', 'VERB'))],
#  [('The', 'DET'), (('Contra', 'PRON'), ('Contra', 'NOUN'))],
#  [('military', 'ADJ'), (('command', 'VERB'), ('command', 'NOUN'))],
#  [('from', 'ADP'), (('Honduras', 'PRON'), ('Honduras', 'NOUN'))],
#  [('0', 'X'), (('Sandinista', 'PRON'), ('Sandinista', 'NOUN'))],
#  [('major', 'ADJ'), (('offensive', 'PRON'), ('offensive', 'NOUN'))],
#  [('the', 'DET'), (('rebel', 'PRON'), ('rebel', 'NOUN'))],
#  [('rebel', 'NOUN'), (('forces', 'VERB'), ('forces', 'NOUN'))],
#  [('$', '.'), (('12.52', 'PRON'), ('12.52', 'NUM'))],
#  [('$', '.'), (('11.95', 'PRON'), ('11.95', 'NUM'))],
#  [('Iowa', 'NOUN'), (('Cos.', 'PRON'), ('Cos.', 'NOUN'))],
#  [('the', 'DET'), (('36-store', 'PRON'), ('36-store', 'ADJ'))],
#  [('to', 'PRT'), (('free', 'ADJ'), ('free', 'VERB'))],
#  [('the', 'DET'), (('1990s', 'NUM'), ('1990s', 'NOUN'))],
#  [('into', 'ADP'), (('multinationals', 'PRON'), ('multinationals', 'NOUN'))],
#  [('the', 'DET'), (('smallest', 'PRON'), ('smallest', 'ADJ'))],
#  [('which', 'DET'), (('*T*-162', 'PRON'), ('*T*-162', 'X'))],
#  [('*T*-162', 'X'), (('costs', 'NOUN'), ('costs', 'VERB'))],
#  [('costs', 'VERB'), (('around', 'ADP'), ('around', 'ADV'))],
#  [('the', 'DET'), (('YMCA', 'PRON'), ('YMCA', 'NOUN'))],
#  [('the', 'DET'), (('YWCA', 'PRON'), ('YWCA', 'NOUN'))],
#  [('or', 'CONJ'), (('Catholic', 'PRON'), ('Catholic', 'NOUN'))],
#  [('Charities', 'NOUN'), (('USA', 'PRON'), ('USA', 'NOUN'))],
#  [('organizations', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-17', 'X'), (('participated', 'PRON'), ('participated', 'VERB'))],
#  [('.', '.'), (('Heiwado', 'PRON'), ('Heiwado', 'NOUN'))],
#  [('Since', 'ADP'), (('chalk', 'PRON'), ('chalk', 'NOUN'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('first', 'ADV'), (('touched', 'PRON'), ('touched', 'VERB'))],
#  [('touched', 'VERB'), (('slate', 'PRON'), ('slate', 'NOUN'))],
#  [(',', '.'), (('schoolchildren', 'PRON'), ('schoolchildren', 'NOUN'))],
#  [('?', '.'), (('Preliminary', 'PRON'), ('Preliminary', 'ADJ'))],
#  [('Preliminary', 'ADJ'), (('tallies', 'PRON'), ('tallies', 'NOUN'))],
#  [('a', 'DET'), (('cloud', 'PRON'), ('cloud', 'NOUN'))],
#  [("'s", 'PRT'), (('export-oriented', 'PRON'), ('export-oriented', 'ADJ'))],
#  [('will', 'VERB'), (('likely', 'ADJ'), ('likely', 'ADV'))],
#  [('likely', 'ADV'), (('trim', 'PRON'), ('trim', 'VERB'))],
#  [('about', 'ADP'), (('275', 'PRON'), ('275', 'NUM'))],
#  [('to', 'PRT'), (('350', 'PRON'), ('350', 'NUM'))],
#  [('than', 'ADP'), (('21,000', 'PRON'), ('21,000', 'NUM'))],
#  [('insist', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('*-5', 'X'), (('jumping', 'PRON'), ('jumping', 'VERB'))],
#  [('jumping', 'VERB'), (('in', 'ADP'), ('in', 'ADV'))],
#  [('The', 'DET'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('only', 'ADJ'), (('advice', 'PRON'), ('advice', 'NOUN'))],
#  [('party', 'NOUN'), (('late', 'ADJ'), ('late', 'ADV'))],
#  [('be', 'VERB'), (('ready', 'PRON'), ('ready', 'ADJ'))],
#  [('The', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('total', 'NOUN'), (('marks', 'NOUN'), ('marks', 'VERB'))],
#  [('company', 'NOUN'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'PRON'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'PRON'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'PRON'), ('suitors', 'NOUN'))],
#  [('my', 'PRON'), (('wine-making', 'PRON'), ('wine-making', 'NOUN'))],
#  [('to', 'PRT'), (('single', 'ADJ'), ('single', 'VERB'))],
#  [('out', 'PRT'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('to', 'PRT'), (('slip', 'PRON'), ('slip', 'VERB'))],
#  [('oldest', 'ADJ'), (('bell-ringing', 'PRON'), ('bell-ringing', 'ADJ'))],
#  [('the', 'DET'), (('Ancient', 'PRON'), ('Ancient', 'NOUN'))],
#  [('College', 'NOUN'), (('Youths', 'PRON'), ('Youths', 'NOUN'))],
#  [('in', 'ADP'), (('1637', 'PRON'), ('1637', 'NUM'))],
#  [('remains', 'VERB'), (('male-only', 'PRON'), ('male-only', 'ADJ'))],
#  [('fact', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-230', 'PRON'), ('*T*-230', 'X'))],
#  [('particularly', 'ADV'), (('galling', 'PRON'), ('galling', 'ADJ'))],
#  [('the', 'DET'), (('sole', 'PRON'), ('sole', 'ADJ'))],
#  [("'s", 'PRT'), (('Cathedral', 'PRON'), ('Cathedral', 'NOUN'))],
#  [('and', 'CONJ'), (('Westminster', 'PRON'), ('Westminster', 'NOUN'))],
#  [('Westminster', 'NOUN'), (('Abbey', 'PRON'), ('Abbey', 'NOUN'))],
#  [('Mr.', 'NOUN'), (('Gartner', 'PRON'), ('Gartner', 'NOUN'))],
#  [('Daily', 'NOUN'), (('Tribune', 'PRON'), ('Tribune', 'NOUN'))],
#  [('in', 'ADP'), (('Ames', 'PRON'), ('Ames', 'NOUN'))],
#  [('lobbyists', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [("n't", 'ADV'), (('segmenting', 'PRON'), ('segmenting', 'VERB'))],
#  [('Enterprise', 'NOUN'), (('Rent-A-Car', 'PRON'), ('Rent-A-Car', 'NOUN'))],
#  [('*', 'X'), (('Judging', 'PRON'), ('Judging', 'VERB'))],
#  [('in', 'ADP'), (('Haruki', 'PRON'), ('Haruki', 'NOUN'))],
#  [(',', '.'), (('320', 'PRON'), ('320', 'NUM'))],
#  [('$', '.'), (('18.95', 'PRON'), ('18.95', 'NUM'))],
#  [(',', '.'), (('baby', 'PRON'), ('baby', 'NOUN'))],
#  [('baby', 'NOUN'), (('boomers', 'PRON'), ('boomers', 'NOUN'))],
#  [('in', 'ADP'), (('common', 'ADJ'), ('common', 'NOUN'))],
#  [('Hammond', 'NOUN'), (('worries', 'NOUN'), ('worries', 'VERB'))],
#  [('the', 'DET'), (('flightiness', 'PRON'), ('flightiness', 'NOUN'))],
#  [('will', 'VERB'), (('diminish', 'PRON'), ('diminish', 'VERB'))],
#  [('the', 'DET'), (('East', 'NOUN'), ('East', 'ADJ'))],
#  [('East', 'ADJ'), (('Anglian', 'PRON'), ('Anglian', 'ADJ'))],
#  [('group', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-223', 'PRON'), ('*T*-223', 'X'))],
#  [('bells', 'NOUN'), (('pealing', 'PRON'), ('pealing', 'VERB'))],
#  [('$', '.'), (('130.7', 'PRON'), ('130.7', 'NUM'))],
#  [('for', 'ADP'), (('AC-130U', 'PRON'), ('AC-130U', 'NOUN'))],
#  [('*T*-1', 'X'), (('worries', 'NOUN'), ('worries', 'VERB'))],
#  [('worries', 'VERB'), (('credit-rating', 'PRON'), ('credit-rating', 'NOUN'))],
#  [('to', 'PRT'), (('investigate', 'PRON'), ('investigate', 'VERB'))],
#  [('U.S.', 'NOUN'), (('sweater', 'PRON'), ('sweater', 'NOUN'))],
#  [('.', '.'), (('Continuing', 'PRON'), ('Continuing', 'VERB'))],
#  [('.', '.'), (('Traditionally', 'PRON'), ('Traditionally', 'ADV'))],
#  [('used', 'VERB'), (('*-66', 'PRON'), ('*-66', 'X'))],
#  [('and', 'CONJ'), (('entertainment', 'PRON'), ('entertainment', 'NOUN'))],
#  [('*ICH*-1', 'X'), (('Gayle', 'PRON'), ('Gayle', 'NOUN'))],
#  [('incentive', 'NOUN'), (('pay', 'VERB'), ('pay', 'NOUN'))],
#  [('opened', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('a', 'DET'), (('can', 'VERB'), ('can', 'NOUN'))],
#  [('of', 'ADP'), (('worms', 'PRON'), ('worms', 'NOUN'))],
#  [('.', '.'), (('NEW', 'PRON'), ('NEW', 'NOUN'))],
#  [('NEW', 'NOUN'), (('ACCOUNT', 'PRON'), ('ACCOUNT', 'NOUN'))],
#  [('are', 'VERB'), (('betting', 'PRON'), ('betting', 'VERB'))],
#  [('``', '.'), (('evolved', 'PRON'), ('evolved', 'VERB'))],
#  [('evolved', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('with', 'ADP'), (('Si', 'PRON'), ('Si', 'NOUN'))],
#  [('$', '.'), (('415', 'PRON'), ('415', 'NUM'))],
#  [('*U*', 'X'), (('charge', 'VERB'), ('charge', 'NOUN'))],
#  [('for', 'ADP'), (('underperforming', 'PRON'), ('underperforming', 'VERB'))],
#  [('end', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('been', 'VERB'), (('obsessed', 'PRON'), ('obsessed', 'VERB'))],
#  [('*', 'X'), (('refitting', 'PRON'), ('refitting', 'VERB'))],
#  [('antitrust', 'ADJ'), (('staffs', 'PRON'), ('staffs', 'NOUN'))],
#  [('*-87', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('off', 'PRT'), (('drastically', 'PRON'), ('drastically', 'ADV'))]]

# %% [markdown]
# **Observation**
# ('85.7', 'X'), ('85.7', 'NUM') - Shows that the Viterbi algorithm assigned the tag 'X' for 85.7 whereas 'NUM' has been assigned as '85.7'by humans.

# %% [markdown]
# ### Solve the problem of unknown words

# %% [markdown]
# ### Viterbi Modification - 1

# %% [markdown]
# For Unknown words, find the most commonly used tags from the train dataset and tag it.

# %% [markdown]
# ***Finding the most commonly used tag from the 'train_tagged_words_list'***

# %%
tag_fd = nltk.FreqDist(tag for (word, tag) in train_tagged_words_list)
max(tag_fd.most_common(),key=itemgetter(1))[0]
# Out:
# 'NOUN'

# %% [markdown]
# **Observation** - Most commonly used tag from 'train_tagged_words_list' is 'NOUN'.

# %% [markdown]
# **Viterbi_modification_1** <br>
# Step 1: Tag the words using Vanilla Veterbi Algorithm<br>
# Step 2: From the taggged sequence, check whether the word is present in the training data set. If the word is not present tag it as 'NOUN' ('NOUN' is the most commonly found tag in the training data)

# %%
# Viterbi Heuristic
def Viterbi_modification_1(test_words, train_tagged_words_list = train_tagged_words_list):
    tagged_seq = Viterbi(test_words)
    
    V = list(set([i[0] for i in train_tagged_words_list]))
             
    viterbi_words = [i[0] for i in tagged_seq]
    viterbi_tags = [i[1] for i in tagged_seq]
            
    for key,word in enumerate(viterbi_words):
             if word not in V:
                 viterbi_tags[key] = 'NOUN'
    #print(list(zip(viterbi_words,viterbi_tags)))
    return list(zip(viterbi_words,viterbi_tags))

# %% [markdown]
# ### Tagging the words using Viterbi_modification_1

# %%
#Calling our user-defined Viterbi_modification_1 to tag words for test data
modified_viterbi_1 = Viterbi_modification_1(test_tagged_words)

# %% [markdown]
# ### Checking the accuracy of Viterbi_modification_1

# %%
# Finding the tags that has been matched with the tags given by humans.
Matched_tags_Viterbi_modified_1 = [i for i, j in zip(modified_viterbi_1, test_run_base) if i == j] 
Matched_tags_Viterbi_modified_1
# Out:
# [('The', 'DET'),
#  ('offer', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-2', 'X'),
#  ('follows', 'VERB'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('*U*', 'X'),
#  ('*T*-3', 'X'),
#  ('was', 'VERB'),
#  ('rejected', 'VERB'),
#  ('*-1', 'X'),
#  ('in', 'ADP'),
#  ('September', 'NOUN'),
#  (',', '.'),
#  ('up', 'PRT'),
#  ('pressure', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('chemicals', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('.', '.'),
#  (',', '.'),
#  ('10', 'NUM'),
#  ('local', 'ADJ'),
#  ('councils', 'NOUN'),
#  ('have', 'VERB'),
#  ('refused', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('honor', 'VERB'),
#  ('fees', 'NOUN'),
#  ('and', 'CONJ'),
#  ('payments', 'NOUN'),
#  ('to', 'PRT'),
#  ('banks', 'NOUN'),
#  ('incurred', 'VERB'),
#  ('*', 'X'),
#  ('during', 'ADP'),
#  ('various', 'ADJ'),
#  ('swaps', 'NOUN'),
#  ('dealings', 'NOUN'),
#  ('.', '.'),
#  ('According', 'VERB'),
#  ('to', 'PRT'),
#  ('Ms.', 'NOUN'),
#  ('Poore', 'NOUN'),
#  (',', '.'),
#  ('Old-House', 'NOUN'),
#  ('Journal', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  (',', '.'),
#  ('her', 'PRON'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('printed', 'VERB'),
#  ('and', 'CONJ'),
#  ('sold', 'VERB'),
#  ('all', 'DET'),
#  ('copies', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('premiere', 'NOUN'),
#  ('issue', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('Mr.', 'NOUN'),
#  ('Barnum', 'NOUN'),
#  ('called', 'VERB'),
#  ('that', 'ADP'),
#  ('``', '.'),
#  ('a', 'DET'),
#  ("''", '.'),
#  ('scenario', 'NOUN'),
#  ('.', '.'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('specialists', 'NOUN'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('bold', 'ADJ'),
#  ('palace', 'NOUN'),
#  ('revolt', 'NOUN'),
#  (',', '.'),
#  ('began', 'VERB'),
#  ('shortly', 'ADV'),
#  ('after', 'ADP'),
#  ('Oct.', 'NOUN'),
#  ('13', 'NUM'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('corporate', 'ADJ'),
#  ('executives', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('companies', 'NOUN'),
#  ('whose', 'PRON'),
#  ('stock', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('is', 'VERB'),
#  ('listed', 'VERB'),
#  ('*-71', 'X'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('them', 'PRON'),
#  ('the', 'DET'),
#  ('exchange', 'NOUN'),
#  ('to', 'PRT'),
#  ('program', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('.', '.'),
#  ('Another', 'DET'),
#  ('proposed', 'VERB'),
#  ('reform', 'NOUN'),
#  ('is', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('program', 'NOUN'),
#  ('traders', 'NOUN'),
#  ('to', 'PRT'),
#  ('an', 'DET'),
#  ('``', '.'),
#  ('uptick', 'NOUN'),
#  ('rule', 'NOUN'),
#  ("''", '.'),
#  ('a', 'DET'),
#  ('reform', 'NOUN'),
#  ('*', 'X'),
#  ('after', 'ADP'),
#  ('the', 'DET'),
#  ('Great', 'NOUN'),
#  ('Crash', 'NOUN'),
#  ('of', 'ADP'),
#  ('1929', 'NUM'),
#  ('*T*-1', 'X'),
#  ('against', 'ADP'),
#  ('stocks', 'NOUN'),
#  ('being', 'VERB'),
#  ('beaten', 'VERB'),
#  ('*-2', 'X'),
#  ('by', 'ADP'),
#  ('those', 'DET'),
#  ('seeking', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('from', 'ADP'),
#  ('lower', 'ADJ'),
#  ('prices', 'NOUN'),
#  (',', '.'),
#  ('namely', 'ADV'),
#  ('short', 'ADJ'),
#  ('sellers', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('Bush', 'NOUN'),
#  ('administration', 'NOUN'),
#  ("'s", 'PRT'),
#  ('nomination', 'NOUN'),
#  ('of', 'ADP'),
#  ('Clarence', 'NOUN'),
#  ('Thomas', 'NOUN'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('seat', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('federal', 'ADJ'),
#  ('appeals', 'NOUN'),
#  ('court', 'NOUN'),
#  ('here', 'ADV'),
#  ('received', 'VERB'),
#  ('a', 'DET'),
#  ('blow', 'NOUN'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('when', 'ADV'),
#  ('the', 'DET'),
#  ('Bar', 'NOUN'),
#  ('Association', 'NOUN'),
#  ('gave', 'VERB'),
#  ('Mr.', 'NOUN'),
#  ('Thomas', 'NOUN'),
#  ('only', 'ADV'),
#  ('a', 'DET'),
#  ('``', '.'),
#  ("''", '.'),
#  ('rating', 'NOUN'),
#  (',', '.'),
#  ('rather', 'ADV'),
#  ('than', 'ADP'),
#  ('``', '.'),
#  ('well', 'ADV'),
#  ('qualified', 'VERB'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Attorneys', 'NOUN'),
#  ('have', 'VERB'),
#  ('argued', 'VERB'),
#  ('since', 'ADP'),
#  ('1985', 'NUM'),
#  (',', '.'),
#  ('when', 'ADV'),
#  ('the', 'DET'),
#  ('law', 'NOUN'),
#  ('took', 'VERB'),
#  ('effect', 'NOUN'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('they', 'PRON'),
#  ('can', 'VERB'),
#  ('not', 'ADV'),
#  ('provide', 'VERB'),
#  ('information', 'NOUN'),
#  ('about', 'ADP'),
#  ('clients', 'NOUN'),
#  ('who', 'PRON'),
#  ('do', 'VERB'),
#  ("n't", 'ADV'),
#  ('wish', 'VERB'),
#  ('their', 'PRON'),
#  ('identities', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('known', 'VERB'),
#  ('*-3', 'X'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('the', 'DET'),
#  ('Army', 'NOUN'),
#  ('Corps', 'NOUN'),
#  ('of', 'ADP'),
#  ('Engineers', 'NOUN'),
#  ('expects', 'VERB'),
#  ('the', 'DET'),
#  ('river', 'NOUN'),
#  ('level', 'NOUN'),
#  ('to', 'PRT'),
#  ('continue', 'VERB'),
#  ('*-1', 'X'),
#  ('falling', 'VERB'),
#  ('this', 'DET'),
#  ('month', 'NOUN'),
#  ('.', '.'),
#  ('Virginia', 'NOUN'),
#  (':', '.'),
#  ('The', 'DET'),
#  ('department', 'NOUN'),
#  ('previously', 'ADV'),
#  ('estimated', 'VERB'),
#  ('that', 'ADP'),
#  ('durable-goods', 'NOUN'),
#  ('orders', 'NOUN'),
#  ('fell', 'VERB'),
#  ('0.1', 'NUM'),
#  ('%', 'NOUN'),
#  ('in', 'ADP'),
#  ('September', 'NOUN'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('next', 'ADJ'),
#  ('step', 'NOUN'),
#  (',', '.'),
#  ('I', 'PRON'),
#  ('suspect', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('is', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('try', 'VERB'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('get', 'VERB'),
#  ('the', 'DET'),
#  ('law', 'NOUN'),
#  ('changed', 'VERB'),
#  ('.', '.'),
#  ('Thus', 'ADV'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('institution', 'NOUN'),
#  ('obligated', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('make', 'VERB'),
#  ('fixed-rate', 'ADJ'),
#  ('interest', 'NOUN'),
#  ('payments', 'NOUN'),
#  ('on', 'ADP'),
#  ('debt', 'NOUN'),
#  ('swaps', 'NOUN'),
#  ('the', 'DET'),
#  ('payments', 'NOUN'),
#  ('with', 'ADP'),
#  ('another', 'DET'),
#  ('making', 'VERB'),
#  ('floating-rate', 'ADJ'),
#  ('payments', 'NOUN'),
#  ('.', '.'),
#  ('Western', 'NOUN'),
#  ('Gas', 'NOUN'),
#  ('Resources', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  (',', '.'),
#  ('initial', 'ADJ'),
#  ('offering', 'NOUN'),
#  ('of', 'ADP'),
#  ('shares', 'NOUN'),
#  ('of', 'ADP'),
#  ('common', 'ADJ'),
#  ('stock', 'NOUN'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('which', 'DET'),
#  ('shares', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('sold', 'VERB'),
#  ('*-1', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('and', 'CONJ'),
#  ('shares', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('by', 'ADP'),
#  ('a', 'DET'),
#  ('holder', 'NOUN'),
#  (',', '.'),
#  ('via', 'ADP'),
#  ('Prudential-Bache', 'NOUN'),
#  ('Capital', 'NOUN'),
#  ('Funding', 'NOUN'),
#  (',', '.'),
#  ('Smith', 'NOUN'),
#  ('Barney', 'NOUN'),
#  (',', '.'),
#  ('Harris', 'NOUN'),
#  ('Upham', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('Hanifen', 'NOUN'),
#  (',', '.'),
#  ('Imhoff', 'NOUN'),
#  ('Inc', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('his', 'PRON'),
#  ('ruling', 'NOUN'),
#  (',', '.'),
#  ('Judge', 'NOUN'),
#  ('Curry', 'NOUN'),
#  ('added', 'VERB'),
#  ('an', 'DET'),
#  ('additional', 'ADJ'),
#  ('$', '.'),
#  ('55', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('commission', 'NOUN'),
#  ("'s", 'PRT'),
#  ('calculations', 'NOUN'),
#  ('.', '.'),
#  ('Moreover', 'ADV'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Japanese', 'ADJ'),
#  ('government', 'NOUN'),
#  (',', '.'),
#  ('now', 'ADV'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ("'s", 'PRT'),
#  ('largest', 'ADJ'),
#  ('aid', 'NOUN'),
#  ('donor', 'NOUN'),
#  (',', '.'),
#  ('is', 'VERB'),
#  ('pumping', 'VERB'),
#  ('far', 'ADV'),
#  ('assistance', 'NOUN'),
#  ('*ICH*-2', 'X'),
#  ('into', 'ADP'),
#  ('the', 'DET'),
#  ('region', 'NOUN'),
#  ('than', 'ADP'),
#  ('the', 'DET'),
#  ('U.S.', 'NOUN'),
#  ('is', 'VERB'),
#  ('*?*', 'X'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Florio', 'NOUN'),
#  ('lying', 'VERB'),
#  (',', '.'),
#  ("''", '.'),
#  ('the', 'DET'),
#  ('voice', 'NOUN'),
#  ('goes', 'VERB'),
#  (',', '.'),
#  ('because', 'ADP'),
#  ('``', '.'),
#  ('the', 'DET'),
#  ('barrel', 'NOUN'),
#  ('on', 'ADP'),
#  ('Courter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('...', '.'),
#  ('contained', 'VERB'),
#  ('heating', 'NOUN'),
#  ('oil', 'NOUN'),
#  (',', '.'),
#  ('was', 'VERB'),
#  ('*-1', 'X'),
#  ('up', 'PRT'),
#  ('and', 'CONJ'),
#  ('caused', 'VERB'),
#  ('no', 'DET'),
#  ('pollution', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('resulting', 'VERB'),
#  ('company', 'NOUN'),
#  ('would', 'VERB'),
#  ('be', 'VERB'),
#  ('the', 'DET'),
#  ('largest', 'ADJ'),
#  ('forest-products', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ('with', 'ADP'),
#  ('sales', 'NOUN'),
#  ('of', 'ADP'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('$', '.'),
#  ('13', 'NUM'),
#  ('billion', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('Stadium', 'NOUN'),
#  ('boosters', 'NOUN'),
#  ('claim', 'VERB'),
#  ('that', 'ADP'),
#  ('without', 'ADP'),
#  ('public', 'ADJ'),
#  ('money', 'NOUN'),
#  ('they', 'PRON'),
#  ('would', 'VERB'),
#  ('never', 'ADV'),
#  ('be', 'VERB'),
#  ('built', 'VERB'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ('We', 'PRON'),
#  ('must', 'VERB'),
#  ('be', 'VERB'),
#  ('very', 'ADV'),
#  ('cautious', 'ADJ'),
#  ('about', 'ADP'),
#  ('*', 'X'),
#  ('investors', 'NOUN'),
#  ('as', 'ADP'),
#  ('``', '.'),
#  ('long-term', 'ADJ'),
#  ("''", '.'),
#  ('or', 'CONJ'),
#  ('``', '.'),
#  ('short-term', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('McDermott', 'NOUN'),
#  ('International', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('its', 'PRON'),
#  ('Babcock', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Wilcox', 'NOUN'),
#  ('unit', 'NOUN'),
#  ('completed', 'VERB'),
#  ('the', 'DET'),
#  ('sale', 'NOUN'),
#  ('of', 'ADP'),
#  ('its', 'PRON'),
#  ('Bailey', 'NOUN'),
#  ('Controls', 'NOUN'),
#  ('Operations', 'NOUN'),
#  ('to', 'PRT'),
#  ('Finmeccanica', 'NOUN'),
#  ('S.p', 'NOUN'),
#  ('.', '.'),
#  ('A.', 'NOUN'),
#  ('for', 'ADP'),
#  ('$', '.'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Who', 'PRON'),
#  ('*T*-1', 'X'),
#  ('really', 'ADV'),
#  ('lying', 'VERB'),
#  ('?', '.'),
#  ("''", '.'),
#  ('asks', 'VERB'),
#  ('*T*-2', 'X'),
#  ('a', 'DET'),
#  ('female', 'ADJ'),
#  ('voice', 'NOUN'),
#  ('.', '.'),
#  ('Meanwhile', 'ADV'),
#  (',', '.'),
#  ('business', 'NOUN'),
#  ('and', 'CONJ'),
#  ('government', 'NOUN'),
#  ('leaders', 'NOUN'),
#  ('the', 'DET'),
#  ('computer', 'NOUN'),
#  ('makers', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('about', 'ADP'),
#  ('the', 'DET'),
#  ('broader', 'ADJ'),
#  ('statement', 'NOUN'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('companies', 'NOUN'),
#  ("'", 'PRT'),
#  ('actions', 'NOUN'),
#  ('make', 'VERB'),
#  ('*T*-1', 'X'),
#  ('about', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('cutthroat', 'ADJ'),
#  ('pricing', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  (',', '.'),
#  ('Wells', 'NOUN'),
#  ('Fargo', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  ('of', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('launched', 'VERB'),
#  ('the', 'DET'),
#  ('Gold', 'NOUN'),
#  ('Account', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('included', 'VERB'),
#  ('free', 'ADJ'),
#  ('checking', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('credit', 'NOUN'),
#  ('card', 'NOUN'),
#  (',', '.'),
#  ('box', 'NOUN'),
#  ('and', 'CONJ'),
#  ('travelers', 'NOUN'),
#  ('checks', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('3', 'NUM'),
#  ('*U*', 'X'),
#  ('monthly', 'ADJ'),
#  ('fee', 'NOUN'),
#  ('.', '.'),
#  ('*-1', 'X'),
#  ('Asked', 'VERB'),
#  ('*-2', 'X'),
#  ('whether', 'ADP'),
#  ('the', 'DET'),
#  ('bidding', 'NOUN'),
#  ('flap', 'NOUN'),
#  ('would', 'VERB'),
#  ('hurt', 'VERB'),
#  ('relations', 'NOUN'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Yamamoto', 'NOUN'),
#  ('said', 'VERB'),
#  (',', '.'),
#  ('``', '.'),
#  ('this', 'DET'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('a', 'DET'),
#  ('minus', 'NOUN'),
#  ('factor', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('For', 'ADP'),
#  ('the', 'DET'),
#  ('Agency', 'NOUN'),
#  ('for', 'ADP'),
#  ('International', 'NOUN'),
#  ('Development', 'NOUN'),
#  (',', '.'),
#  ('appropriators', 'NOUN'),
#  ('approved', 'VERB'),
#  ('$', '.'),
#  ('200', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('secondary', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('under', 'ADP'),
#  ('an', 'DET'),
#  ('expanded', 'VERB'),
#  ('credit', 'NOUN'),
#  ('insurance', 'NOUN'),
#  ('program', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('total', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('Overseas', 'NOUN'),
#  ('Investment', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('are', 'VERB'),
#  ('increased', 'VERB'),
#  ('*-3', 'X'),
#  ('by', 'ADP'),
#  ('$', '.'),
#  ('40', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('over', 'ADP'),
#  ('fiscal', 'ADJ'),
#  ('1989', 'NUM'),
#  ('as', 'ADP'),
#  ('part', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('Poland', 'NOUN'),
#  ('package', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('both', 'DET'),
#  ('cases', 'NOUN'),
#  (',', '.'),
#  ('NEC', 'NOUN'),
#  ('lost', 'VERB'),
#  ('the', 'DET'),
#  ('contract', 'NOUN'),
#  ('to', 'PRT'),
#  ('Fujitsu', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('made', 'VERB'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('bid', 'NOUN'),
#  ('and', 'CONJ'),
#  ('won', 'VERB'),
#  ('a', 'DET'),
#  ('lottery', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Cosby', 'NOUN'),
#  ("''", '.'),
#  ('is', 'VERB'),
#  ('down', 'ADV'),
#  ('a', 'DET'),
#  ('full', 'ADJ'),
#  ('ratings', 'NOUN'),
#  ('point', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('week', 'NOUN'),
#  ('of', 'ADP'),
#  ('Oct.', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('week', 'NOUN'),
#  ('a', 'DET'),
#  ('year', 'NOUN'),
#  (',', '.'),
#  ('according', 'VERB'),
#  ('to', 'PRT'),
#  ('A.C.', 'NOUN'),
#  ('Nielsen', 'NOUN'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('Despite', 'ADP'),
#  ('the', 'DET'),
#  ('Supreme', 'NOUN'),
#  ('Court', 'NOUN'),
#  ("'s", 'PRT'),
#  ('refusal', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('hear', 'VERB'),
#  ('the', 'DET'),
#  ('case', 'NOUN'),
#  (',', '.'),
#  ('there', 'DET'),
#  ('are', 'VERB'),
#  ('serious', 'ADJ'),
#  ('constitutional', 'ADJ'),
#  ('issues', 'NOUN'),
#  ('of', 'ADP'),
#  ('due', 'ADJ'),
#  ('process', 'NOUN'),
#  ('and', 'CONJ'),
#  ('takings', 'NOUN'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('defendants', 'NOUN'),
#  ('.', '.'),
#  ('And', 'CONJ'),
#  ('some', 'DET'),
#  ('grain', 'NOUN'),
#  ('analysts', 'NOUN'),
#  ('are', 'VERB'),
#  ('predicting', 'VERB'),
#  ('that', 'ADP'),
#  ('corn', 'NOUN'),
#  ('prices', 'NOUN'),
#  ('might', 'VERB'),
#  ('this', 'DET'),
#  ('month', 'NOUN'),
#  ('as', 'ADP'),
#  ('exporters', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('find', 'VERB'),
#  ('enough', 'ADV'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('crop', 'NOUN'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('to', 'PRT'),
#  ('meet', 'VERB'),
#  ('their', 'PRON'),
#  ('obligations', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('Soviets', 'NOUN'),
#  ('.', '.'),
#  ('Still', 'ADV'),
#  ('is', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Sony', 'NOUN'),
#  ("'s", 'PRT'),
#  ('effort', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('hire', 'VERB'),
#  ('producers', 'NOUN'),
#  ('Jon', 'NOUN'),
#  ('Peters', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Peter', 'NOUN'),
#  ('Guber', 'NOUN'),
#  ('to', 'PRT'),
#  ('run', 'VERB'),
#  ('the', 'DET'),
#  ('studio', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('if', 'ADP'),
#  ('Columbia', 'NOUN'),
#  ('could', 'VERB'),
#  ('keep', 'VERB'),
#  ('its', 'PRON'),
#  ('junk', 'NOUN'),
#  ('bonds', 'NOUN'),
#  ('separate', 'ADJ'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('thrift', 'NOUN'),
#  ('they', 'PRON'),
#  ('mature', 'VERB'),
#  ('--', '.'),
#  ('at', 'ADP'),
#  ('full', 'ADJ'),
#  ('value', 'NOUN'),
#  (',', '.'),
#  ('unless', 'ADP'),
#  ('the', 'DET'),
#  ('issuer', 'NOUN'),
#  ('goes', 'VERB'),
#  ('bust', 'NOUN'),
#  ('or', 'CONJ'),
#  ('--', '.'),
#  ('the', 'DET'),
#  ('junk', 'NOUN'),
#  ('portfolio', 'NOUN'),
#  ('might', 'VERB'),
#  ('do', 'VERB'),
#  ('.', '.'),
#  ('For', 'ADP'),
#  ('some', 'DET'),
#  ('time', 'NOUN'),
#  (',', '.'),
#  ('banks', 'NOUN'),
#  ('have', 'VERB'),
#  ('been', 'VERB'),
#  ('packages', 'NOUN'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('demographic', 'ADJ'),
#  ('segment', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('highest', 'ADJ'),
#  ('savings', 'NOUN'),
#  ('.', '.'),
#  ('Cray', 'NOUN'),
#  ('Research', 'NOUN'),
#  ('indicated', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('survival', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('spinoff', 'NOUN'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-1', 'X'),
#  ('is', 'VERB'),
#  ('developing', 'VERB'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('supercomputer', 'NOUN'),
#  (',', '.'),
#  ('heavily', 'ADV'),
#  ('on', 'ADP'),
#  ('its', 'PRON'),
#  ('chairman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('chief', 'NOUN'),
#  ('designer', 'NOUN'),
#  (',', '.'),
#  ('Seymour', 'NOUN'),
#  ('Cray', 'NOUN'),
#  ('.', '.'),
#  ('Congress', 'NOUN'),
#  ('learned', 'VERB'),
#  ('during', 'ADP'),
#  ('the', 'DET'),
#  ('Reagan', 'NOUN'),
#  ('administration', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('could', 'VERB'),
#  ('the', 'DET'),
#  ('branch', 'NOUN'),
#  ('by', 'ADP'),
#  ('*-1', 'X'),
#  ('again', 'ADV'),
#  ('and', 'CONJ'),
#  ('again', 'ADV'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('seven', 'NUM'),
#  ('words', 'NOUN'),
#  (':', '.'),
#  ('``', '.'),
#  (',', '.'),
#  ('no', 'DET'),
#  ('funds', 'NOUN'),
#  ('shall', 'VERB'),
#  ('be', 'VERB'),
#  ('spent', 'VERB'),
#  ('*-48', 'X'),
#  ('...', '.'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Then', 'ADV'),
#  ('*', 'X'),
#  ('send', 'VERB'),
#  ('your', 'PRON'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('savings', 'NOUN'),
#  ('institution', 'NOUN'),
#  ('has', 'VERB'),
#  ('taken', 'VERB'),
#  ('a', 'DET'),
#  ('bad', 'ADJ'),
#  ('rap', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('press', 'NOUN'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('its', 'PRON'),
#  ('line', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('other', 'ADJ'),
#  ('concern', 'NOUN'),
#  ('was', 'VERB'),
#  ("n't", 'ADV'),
#  ('identified', 'VERB'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('Stronach', 'NOUN'),
#  (',', '.'),
#  ('founder', 'NOUN'),
#  ('and', 'CONJ'),
#  ('controlling', 'VERB'),
#  ('shareholder', 'NOUN'),
#  ('of', 'ADP'),
#  ('Magna', 'NOUN'),
#  (',', '.'),
#  ('resigned', 'VERB'),
#  ('as', 'ADP'),
#  ('chief', 'NOUN'),
#  ('executive', 'NOUN'),
#  ('officer', 'NOUN'),
#  ('last', 'ADJ'),
#  ('year', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('seek', 'VERB'),
#  (',', '.'),
#  ('unsuccessfully', 'ADV'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('seat', 'NOUN'),
#  ('in', 'ADP'),
#  ('Canada', 'NOUN'),
#  ("'s", 'PRT'),
#  ('Parliament', 'NOUN'),
#  ('.', '.'),
#  ('60', 'NUM'),
#  ('million', 'NUM'),
#  ('Swiss', 'ADJ'),
#  ('francs', 'NOUN'),
#  ('of', 'ADP'),
#  ('privately', 'ADV'),
#  ('placed', 'VERB'),
#  ('convertible', 'ADJ'),
#  ('notes', 'NOUN'),
#  ('due', 'ADJ'),
#  ('Dec.', 'NOUN'),
#  ('31', 'NUM'),
#  (',', '.'),
#  ('1993', 'NUM'),
#  (',', '.'),
#  ('with', 'ADP'),
#  ('a', 'DET'),
#  ('fixed', 'VERB'),
#  ('0.25', 'NUM'),
#  ('%', 'NOUN'),
#  ('coupon', 'NOUN'),
#  ('at', 'ADP'),
#  ('par', 'NOUN'),
#  ('via', 'ADP'),
#  ('Union', 'NOUN'),
#  ('Bank', 'NOUN'),
#  ('of', 'ADP'),
#  ('Switzerland', 'NOUN'),
#  ('.', '.'),
#  ('It', 'PRON'),
#  ('also', 'ADV'),
#  ('would', 'VERB'),
#  ('an', 'DET'),
#  ('system', 'NOUN'),
#  ...]

# %%
accuracy = len(Matched_tags_Viterbi_modified_1)/len(modified_viterbi_1)
accuracy
# Out:
# 0.9309623430962343

# %% [markdown]
# **Observation** - The accuracy of the Viterbi_modification_1 algorithm is 93.07%. After tagging it with most common tag ('Noun' in this case) the accuracy has improved from 89.83% to 93.07%. We will modify the Veterbi algorithm using rules and compare its performance.

# %% [markdown]
# ### Updating the Accuracy_df with the accuracy of Viterbi_modification_1

# %%
new_row = {'Algorithm':' Viterbi_modification_1(commonly used tag)', 'Accuracy':accuracy}
Accuracy_df = Accuracy_df.append(new_row, ignore_index=True)
Accuracy_df
# Out:
#                                     Algorithm  Accuracy
# 0                             Vannila Viterbi  0.895816
# 1   Viterbi_modification_1(commonly used tag)  0.930962

# %% [markdown]
# ### Words that have incorrect tags

# %%
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(modified_viterbi_1, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[('$', '.'), (('55-a-share', 'NOUN'), ('55-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('bid', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [(',', '.'), (('steps', 'NOUN'), ('steps', 'VERB'))],
#  [('.', '.'), (('Already', 'NOUN'), ('Already', 'ADV'))],
#  [('her', 'PRON'), (('publishing', 'VERB'), ('publishing', 'NOUN'))],
#  [('all', 'DET'), (('126,000', 'NOUN'), ('126,000', 'NUM'))],
#  [('a', 'DET'), (('worst-case', 'NOUN'), ('worst-case', 'ADJ'))],
#  [('to', 'PRT'), (('telephone', 'NOUN'), ('telephone', 'VERB'))],
#  [('them', 'PRON'), (('pressure', 'NOUN'), ('pressure', 'VERB'))],
#  [('to', 'PRT'), (('ban', 'NOUN'), ('ban', 'VERB'))],
#  [('traders', 'NOUN'), (('answer', 'NOUN'), ('answer', 'VERB'))],
#  [('reform', 'NOUN'), (('instituted', 'NOUN'), ('instituted', 'VERB'))],
#  [('1929', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-1', 'X'), (('protects', 'NOUN'), ('protects', 'VERB'))],
#  [('being', 'VERB'), (('relentlessly', 'NOUN'), ('relentlessly', 'ADV'))],
#  [('*-2', 'X'), (('downward', 'ADJ'), ('downward', 'ADV'))],
#  [('to', 'PRT'), (('profit', 'NOUN'), ('profit', 'VERB'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('``', '.'), (('qualified', 'VERB'), ('qualified', 'ADJ'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('who', 'PRON'), (('*T*-127', 'NOUN'), ('*T*-127', 'X'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('of', 'ADP'), (('3,250,000', 'NOUN'), ('3,250,000', 'NUM'))],
#  [('which', 'DET'), (('3,040,000', 'NOUN'), ('3,040,000', 'NUM'))],
#  [('and', 'CONJ'), (('210,000', 'NOUN'), ('210,000', 'NUM'))],
#  [('far', 'ADV'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('Florio', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('goes', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [("'s", 'PRT'), (('land', 'VERB'), ('land', 'NOUN'))],
#  [('was', 'VERB'), (('cleaned', 'NOUN'), ('cleaned', 'VERB'))],
#  [('with', 'ADP'), (('combined', 'ADJ'), ('combined', 'VERB'))],
#  [('*', 'X'), (('labeling', 'NOUN'), ('labeling', 'VERB'))],
#  [('$', '.'), (('295', 'NOUN'), ('295', 'NUM'))],
#  [('*T*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('leaders', 'NOUN'), (('rebuked', 'NOUN'), ('rebuked', 'VERB'))],
#  [('and', 'CONJ'), (('fretted', 'NOUN'), ('fretted', 'VERB'))],
#  [('In', 'ADP'), (('1973', 'NOUN'), ('1973', 'NUM'))],
#  [('which', 'DET'), (('*T*-198', 'NOUN'), ('*T*-198', 'X'))],
#  [(',', '.'), (('safe-deposit', 'NOUN'), ('safe-deposit', 'ADJ'))],
#  [('hurt', 'VERB'), (('U.S.-Japan', 'NOUN'), ('U.S.-Japan', 'ADJ'))],
#  [('expanded', 'VERB'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('Overseas', 'NOUN'), (('Private', 'ADJ'), ('Private', 'NOUN'))],
#  [('which', 'DET'), (('*T*-139', 'NOUN'), ('*T*-139', 'X'))],
#  [('a', 'DET'), (('tie-breaking', 'NOUN'), ('tie-breaking', 'ADJ'))],
#  [('Oct.', 'NOUN'), (('2-8', 'NOUN'), ('2-8', 'NUM'))],
#  [('year', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('and', 'CONJ'), (('uncompensated', 'NOUN'), ('uncompensated', 'ADJ'))],
#  [('might', 'VERB'), (('gyrate', 'NOUN'), ('gyrate', 'VERB'))],
#  [('exporters', 'NOUN'), (('scrounge', 'NOUN'), ('scrounge', 'VERB'))],
#  [('Still', 'ADV'), (('unresolved', 'NOUN'), ('unresolved', 'ADJ'))],
#  [('thrift', 'NOUN'), (('till', 'NOUN'), ('till', 'ADP'))],
#  [('or', 'CONJ'), (('restructures', 'NOUN'), ('restructures', 'VERB'))],
#  [('do', 'VERB'), (('all', 'DET'), ('all', 'ADV'))],
#  [('all', 'ADV'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('been', 'VERB'), (('aiming', 'NOUN'), ('aiming', 'VERB'))],
#  [('the', 'DET'), (('elderly', 'NOUN'), ('elderly', 'ADJ'))],
#  [(',', '.'), (('depends', 'NOUN'), ('depends', 'VERB'))],
#  [('could', 'VERB'), (('intimidate', 'NOUN'), ('intimidate', 'VERB'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('*-1', 'X'), (('uttering', 'NOUN'), ('uttering', 'VERB'))],
#  [('``', '.'), (('Provided', 'NOUN'), ('Provided', 'VERB'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('your', 'PRON'), (('support', 'VERB'), ('support', 'NOUN'))],
#  [('institution', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-208', 'NOUN'), ('*T*-208', 'X'))],
#  [('its', 'PRON'), (('bottom', 'NOUN'), ('bottom', 'ADJ'))],
#  [('would', 'VERB'), (('junk', 'NOUN'), ('junk', 'VERB'))],
#  [('an', 'DET'), (('innovative', 'NOUN'), ('innovative', 'ADJ'))],
#  [('innovative', 'ADJ'), (('market-based', 'NOUN'), ('market-based', 'ADJ'))],
#  [('*', 'X'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [(':', '.'), (('Financially', 'NOUN'), ('Financially', 'ADV'))],
#  [('buying', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('have', 'VERB'), (('escalated', 'NOUN'), ('escalated', 'VERB'))],
#  [('%', 'NOUN'), (('holding', 'VERB'), ('holding', 'NOUN'))],
#  [("'s", 'PRT'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('Dec.', 'NOUN'), (('2-3', 'NOUN'), ('2-3', 'NUM'))],
#  [('was', 'VERB'), (('116.9', 'NOUN'), ('116.9', 'NUM'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('of', 'ADP'), (('112.9', 'NOUN'), ('112.9', 'NUM'))],
#  [('of', 'ADP'), (('120.7', 'NOUN'), ('120.7', 'NUM'))],
#  [('auctioned', 'VERB'), (('*-109', 'NOUN'), ('*-109', 'X'))],
#  [('yield', 'VERB'), (('7.65', 'NOUN'), ('7.65', 'NUM'))],
#  [('drifted', 'VERB'), (('lower', 'ADJ'), ('lower', 'ADV'))],
#  [('lower', 'ADV'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('U.S.', 'NOUN'), (('purchasing', 'VERB'), ('purchasing', 'NOUN'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('*-2', 'X'), (('successfully', 'NOUN'), ('successfully', 'ADV'))],
#  [('successfully', 'ADV'), (('mobilizing', 'NOUN'), ('mobilizing', 'VERB'))],
#  [('to', 'PRT'), (('bludgeon', 'NOUN'), ('bludgeon', 'VERB'))],
#  [('said', 'VERB'), (('repeatedly', 'NOUN'), ('repeatedly', 'ADV'))],
#  [('stay', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('issue', 'NOUN'), (('trades', 'NOUN'), ('trades', 'VERB'))],
#  [('its', 'PRON'), (('face', 'VERB'), ('face', 'NOUN'))],
#  [('Association', 'NOUN'), (('leapt', 'NOUN'), ('leapt', 'VERB'))],
#  [('has', 'VERB'), (('instituted', 'NOUN'), ('instituted', 'VERB'))],
#  [('effective', 'ADJ'),
#   (('search-and-seizure', 'NOUN'), ('search-and-seizure', 'ADJ'))],
#  [('to', 'PRT'), (('aid', 'NOUN'), ('aid', 'VERB'))],
#  [('system', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('soared', 'VERB'), (('higher', 'ADJ'), ('higher', 'ADV'))],
#  [('Cataracts', 'NOUN'), (('refer', 'NOUN'), ('refer', 'VERB'))],
#  [('a', 'DET'), (('needy', 'NOUN'), ('needy', 'ADJ'))],
#  [('loan', 'NOUN'), (('solvent', 'NOUN'), ('solvent', 'ADJ'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('almost', 'ADV'), (('over', 'ADP'), ('over', 'ADJ'))],
#  [('by', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('to', 'PRT'), (('8.75', 'NOUN'), ('8.75', 'NUM'))],
#  [('has', 'VERB'), (('shown', 'NOUN'), ('shown', 'VERB'))],
#  [('shown', 'VERB'), (('no', 'ADV'), ('no', 'DET'))],
#  [('no', 'DET'), (('sign', 'VERB'), ('sign', 'NOUN'))],
#  [('default', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('expected', 'VERB'), (('*-129', 'NOUN'), ('*-129', 'X'))],
#  [('a', 'DET'), (('richer', 'NOUN'), ('richer', 'ADJ'))],
#  [('the', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('and', 'CONJ'), (('galvanized', 'NOUN'), ('galvanized', 'ADJ'))],
#  [('galvanized', 'ADJ'), (('coated', 'NOUN'), ('coated', 'VERB'))],
#  [('than', 'ADP'), (('lower-priced', 'NOUN'), ('lower-priced', 'ADJ'))],
#  [('lower-priced', 'ADJ'), (('structural', 'NOUN'), ('structural', 'ADJ'))],
#  [('COLLECTING', 'NOUN'), (('gains', 'NOUN'), ('gains', 'VERB'))],
#  [('a', 'DET'), (('valuable', 'NOUN'), ('valuable', 'ADJ'))],
#  [('powers', 'NOUN'), (('works', 'NOUN'), ('works', 'VERB'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('*-1', 'X'), (('Concerned', 'NOUN'), ('Concerned', 'VERB'))],
#  [('about', 'ADP'), (('shrinking', 'NOUN'), ('shrinking', 'VERB'))],
#  [('in', 'ADP'), (('super-absorbent', 'NOUN'), ('super-absorbent', 'ADJ'))],
#  [('some', 'DET'), (('light', 'ADJ'), ('light', 'NOUN'))],
#  [('the', 'DET'), (('dark', 'NOUN'), ('dark', 'ADJ'))],
#  [('where', 'ADV'), (('high-stakes', 'NOUN'), ('high-stakes', 'ADJ'))],
#  [('has', 'VERB'), (('enhanced', 'NOUN'), ('enhanced', 'VERB'))],
#  [('to', 'PRT'), (('cheat', 'NOUN'), ('cheat', 'VERB'))],
#  [('is', 'VERB'), (('wrestling', 'NOUN'), ('wrestling', 'VERB'))],
#  [('especially', 'ADV'), (('intelligent', 'NOUN'), ('intelligent', 'ADJ'))],
#  [('temporarily', 'ADV'), (('insane', 'NOUN'), ('insane', 'ADJ'))],
#  [('movie', 'NOUN'), (('ends', 'NOUN'), ('ends', 'VERB'))],
#  [('anything', 'NOUN'), (('whimsical', 'NOUN'), ('whimsical', 'ADJ'))],
#  [('or', 'CONJ'), (('enviable', 'NOUN'), ('enviable', 'ADJ'))],
#  [(',', '.'), (('beaten', 'VERB'), ('beaten', 'ADJ'))],
#  [('$', '.'), (('45-a-share', 'NOUN'), ('45-a-share', 'ADJ'))],
#  [('45-a-share', 'ADJ'), (('offer', 'VERB'), ('offer', 'NOUN'))],
#  [('a', 'DET'), (('Scandinavian', 'NOUN'), ('Scandinavian', 'ADJ'))],
#  [('$', '.'), (('2.44', 'NOUN'), ('2.44', 'NUM'))],
#  [('``', '.'), (('Little', 'ADV'), ('Little', 'ADJ'))],
#  [('*-1', 'X'), (('wanting', 'NOUN'), ('wanting', 'VERB'))],
#  [('fired', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('its', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('is', 'VERB'), (('discontinuing', 'NOUN'), ('discontinuing', 'VERB'))],
#  [('which', 'DET'), (('there', 'ADV'), ('there', 'DET'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'ADJ'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'ADJ'))],
#  [('-LRB-', '.'), (('Fewer', 'NOUN'), ('Fewer', 'ADJ'))],
#  [('weapon', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-245', 'NOUN'), ('*T*-245', 'X'))],
#  [('can', 'VERB'), (('shoot', 'NOUN'), ('shoot', 'VERB'))],
#  [('them', 'PRON'), (('down', 'ADV'), ('down', 'ADP'))],
#  [("'s", 'VERB'), (('imaginative', 'NOUN'), ('imaginative', 'ADJ'))],
#  [('were', 'VERB'), (('granted', 'NOUN'), ('granted', 'VERB'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('*ICH*-1', 'X'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('and', 'CONJ'), (('punish', 'NOUN'), ('punish', 'VERB'))],
#  [('which', 'DET'), (('*T*-147', 'NOUN'), ('*T*-147', 'X'))],
#  [('*T*-147', 'X'), (('measures', 'NOUN'), ('measures', 'VERB'))],
#  [('the', 'DET'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('of', 'ADP'), (('45.3', 'NOUN'), ('45.3', 'NUM'))],
#  [('a', 'DET'), (('stark', 'NOUN'), ('stark', 'ADJ'))],
#  [('traditional', 'ADJ'),
#   (('policy-making', 'NOUN'), ('policy-making', 'ADJ'))],
#  [('the', 'DET'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('to', 'PRT'), (('debate', 'NOUN'), ('debate', 'VERB'))],
#  [('a', 'DET'), (('31-year-old', 'NOUN'), ('31-year-old', 'ADJ'))],
#  [('would', 'VERB'), (('like', 'ADP'), ('like', 'VERB'))],
#  [('trading', 'NOUN'), (('disappear', 'NOUN'), ('disappear', 'VERB'))],
#  [(',', '.'), (('Texas-based', 'NOUN'), ('Texas-based', 'ADJ'))],
#  [('System', 'NOUN'), (('210', 'NOUN'), ('210', 'NUM'))],
#  [('with', 'ADP'), (('512', 'NOUN'), ('512', 'NUM'))],
#  [('a', 'DET'), (('40-megabyte', 'NOUN'), ('40-megabyte', 'ADJ'))],
#  [('a', 'DET'), (('color', 'VERB'), ('color', 'NOUN'))],
#  [('are', 'VERB'), (('stretching', 'NOUN'), ('stretching', 'VERB'))],
#  [('and', 'CONJ'), (('wide', 'ADJ'), ('wide', 'ADV'))],
#  [('to', 'PRT'), (('depend', 'NOUN'), ('depend', 'VERB'))],
#  [('has', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('have', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('.', '.'), (('Second', 'NOUN'), ('Second', 'ADJ'))],
#  [('they', 'PRON'), (('channel', 'NOUN'), ('channel', 'VERB'))],
#  [('That', 'DET'), (('attracts', 'NOUN'), ('attracts', 'VERB'))],
#  [('was', 'VERB'), (('kind', 'NOUN'), ('kind', 'ADJ'))],
#  [('and', 'CONJ'), (('playful', 'NOUN'), ('playful', 'ADJ'))],
#  [('was', 'VERB'), (('dreadful', 'NOUN'), ('dreadful', 'ADJ'))],
#  [('her', 'PRON'), (('war-damaged', 'NOUN'), ('war-damaged', 'ADJ'))],
#  [('called', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('to', 'PRT'), (('arrest', 'NOUN'), ('arrest', 'VERB'))],
#  [('were', 'VERB'), (('occupying', 'NOUN'), ('occupying', 'VERB'))],
#  [('.', '.'), (('Back', 'NOUN'), ('Back', 'ADV'))],
#  [('squeezed', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('*-1', 'X'), (('boarding', 'NOUN'), ('boarding', 'VERB'))],
#  [('scientists', 'NOUN'), (('breathed', 'NOUN'), ('breathed', 'VERB'))],
#  [('a', 'DET'), (('collective', 'NOUN'), ('collective', 'ADJ'))],
#  [('it', 'PRON'), (('demonstrates', 'NOUN'), ('demonstrates', 'VERB'))],
#  [('*T*-1', 'X'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('*', 'X'), (('undercutting', 'NOUN'), ('undercutting', 'VERB'))],
#  [("'", 'PRT'), (('potential', 'ADJ'), ('potential', 'NOUN'))],
#  [('.', '.'), (('b', 'NOUN'), ('b', 'X'))],
#  [('the', 'DET'), (('top-yielding', 'NOUN'), ('top-yielding', 'ADJ'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('of', 'ADP'), (('9.37', 'NOUN'), ('9.37', 'NUM'))],
#  [('from', 'ADP'), (('9.45', 'NOUN'), ('9.45', 'NUM'))],
#  [(',', '.'), (('comments', 'NOUN'), ('comments', 'VERB'))],
#  [('``', '.'), (('increases', 'NOUN'), ('increases', 'VERB'))],
#  [('will', 'VERB'), (('oversee', 'NOUN'), ('oversee', 'VERB'))],
#  [('get', 'VERB'), (('across', 'ADP'), ('across', 'PRT'))],
#  [('a', 'DET'), (('razor-thin', 'NOUN'), ('razor-thin', 'ADJ'))],
#  [('go', 'VERB'), (('through', 'ADP'), ('through', 'PRT'))],
#  [('Beijing', 'NOUN'), (('food-shop', 'NOUN'), ('food-shop', 'ADJ'))],
#  [('food-shop', 'ADJ'), (('assistant', 'ADJ'), ('assistant', 'NOUN'))],
#  [('mainland', 'NOUN'), (('Chinese', 'ADJ'), ('Chinese', 'NOUN'))],
#  [('*-1', 'X'), (('sketching', 'NOUN'), ('sketching', 'VERB'))],
#  [('Too', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('give', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('are', 'VERB'), (('purely', 'NOUN'), ('purely', 'ADV'))],
#  [('*', 'X'), (('Being', 'NOUN'), ('Being', 'VERB'))],
#  [('the', 'DET'), (('37-year-old', 'NOUN'), ('37-year-old', 'ADJ'))],
#  [(',', '.'), (('The', 'DET'), ('The', 'NOUN'))],
#  [('will', 'VERB'), (('report', 'NOUN'), ('report', 'VERB'))],
#  [('century', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('has', 'VERB'), (('hunted', 'NOUN'), ('hunted', 'VERB'))],
#  [('ran', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('*T*-14', 'X'), (('matters', 'NOUN'), ('matters', 'VERB'))],
#  [('doing', 'VERB'), (('fine', 'NOUN'), ('fine', 'ADV'))],
#  [('not', 'ADV'), (('unethical', 'NOUN'), ('unethical', 'ADJ'))],
#  [('a', 'DET'), (('higher-salaried', 'NOUN'), ('higher-salaried', 'ADJ'))],
#  [('he', 'PRON'), (('hoped', 'NOUN'), ('hoped', 'VERB'))],
#  [("n't", 'ADV'), (('encounter', 'NOUN'), ('encounter', 'VERB'))],
#  [('that', 'ADP'), (('non-farm', 'NOUN'), ('non-farm', 'ADJ'))],
#  [('by', 'ADP'), (('152,000', 'NOUN'), ('152,000', 'NUM'))],
#  [('EVERYONE', 'NOUN'), (('AGREES', 'NOUN'), ('AGREES', 'VERB'))],
#  [('be', 'VERB'), (('repaired', 'NOUN'), ('repaired', 'VERB'))],
#  [('with', 'ADP'),
#   (('yttrium-containing', 'NOUN'), ('yttrium-containing', 'ADJ'))],
#  [('or', 'CONJ'), (('minus', 'NOUN'), ('minus', 'CONJ'))],
#  [('minus', 'CONJ'), (('321', 'NOUN'), ('321', 'NUM'))],
#  [('the', 'DET'), (('shaky', 'NOUN'), ('shaky', 'ADJ'))],
#  [('a', 'DET'), (('slowing', 'NOUN'), ('slowing', 'VERB'))],
#  [(':', '.'), (('day-care', 'NOUN'), ('day-care', 'ADJ'))],
#  [('day-care', 'ADJ'), (('centers', 'VERB'), ('centers', 'NOUN'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('previously', 'ADV'), (('spurned', 'NOUN'), ('spurned', 'VERB'))],
#  [('is', 'VERB'), (('conducted', 'NOUN'), ('conducted', 'VERB'))],
#  [('or', 'CONJ'), (('early', 'ADJ'), ('early', 'ADV'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('this', 'DET'), (('minute', 'ADJ'), ('minute', 'NOUN'))],
#  [('said', 'VERB'), (('universally', 'NOUN'), ('universally', 'ADV'))],
#  [('who', 'PRON'), (('*T*-84', 'NOUN'), ('*T*-84', 'X'))],
#  [('for', 'ADP'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [(',', '.'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('will', 'VERB'), (('worsen', 'NOUN'), ('worsen', 'VERB'))],
#  [('plant', 'NOUN'), (('engineering', 'NOUN'), ('engineering', 'VERB'))],
#  [('military', 'ADJ'), (('command', 'VERB'), ('command', 'NOUN'))],
#  [('rebel', 'NOUN'), (('forces', 'VERB'), ('forces', 'NOUN'))],
#  [('$', '.'), (('12.52', 'NOUN'), ('12.52', 'NUM'))],
#  [('$', '.'), (('11.95', 'NOUN'), ('11.95', 'NUM'))],
#  [('the', 'DET'), (('36-store', 'NOUN'), ('36-store', 'ADJ'))],
#  [('to', 'PRT'), (('free', 'ADJ'), ('free', 'VERB'))],
#  [('the', 'DET'), (('1990s', 'NUM'), ('1990s', 'NOUN'))],
#  [('the', 'DET'), (('smallest', 'NOUN'), ('smallest', 'ADJ'))],
#  [('which', 'DET'), (('*T*-162', 'NOUN'), ('*T*-162', 'X'))],
#  [('*T*-162', 'X'), (('costs', 'NOUN'), ('costs', 'VERB'))],
#  [('costs', 'VERB'), (('around', 'ADP'), ('around', 'ADV'))],
#  [('organizations', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-17', 'X'), (('participated', 'NOUN'), ('participated', 'VERB'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('first', 'ADV'), (('touched', 'NOUN'), ('touched', 'VERB'))],
#  [('?', '.'), (('Preliminary', 'NOUN'), ('Preliminary', 'ADJ'))],
#  [("'s", 'PRT'), (('export-oriented', 'NOUN'), ('export-oriented', 'ADJ'))],
#  [('will', 'VERB'), (('likely', 'ADJ'), ('likely', 'ADV'))],
#  [('likely', 'ADV'), (('trim', 'NOUN'), ('trim', 'VERB'))],
#  [('about', 'ADP'), (('275', 'NOUN'), ('275', 'NUM'))],
#  [('to', 'PRT'), (('350', 'NOUN'), ('350', 'NUM'))],
#  [('than', 'ADP'), (('21,000', 'NOUN'), ('21,000', 'NUM'))],
#  [('insist', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('*-5', 'X'), (('jumping', 'NOUN'), ('jumping', 'VERB'))],
#  [('jumping', 'VERB'), (('in', 'ADP'), ('in', 'ADV'))],
#  [('The', 'DET'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('party', 'NOUN'), (('late', 'ADJ'), ('late', 'ADV'))],
#  [('be', 'VERB'), (('ready', 'NOUN'), ('ready', 'ADJ'))],
#  [('The', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('total', 'NOUN'), (('marks', 'NOUN'), ('marks', 'VERB'))],
#  [('company', 'NOUN'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'NOUN'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'NOUN'), ('unwanted', 'ADJ'))],
#  [('to', 'PRT'), (('single', 'ADJ'), ('single', 'VERB'))],
#  [('out', 'PRT'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('to', 'PRT'), (('slip', 'NOUN'), ('slip', 'VERB'))],
#  [('oldest', 'ADJ'), (('bell-ringing', 'NOUN'), ('bell-ringing', 'ADJ'))],
#  [('in', 'ADP'), (('1637', 'NOUN'), ('1637', 'NUM'))],
#  [('remains', 'VERB'), (('male-only', 'NOUN'), ('male-only', 'ADJ'))],
#  [('fact', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-230', 'NOUN'), ('*T*-230', 'X'))],
#  [('particularly', 'ADV'), (('galling', 'NOUN'), ('galling', 'ADJ'))],
#  [('the', 'DET'), (('sole', 'NOUN'), ('sole', 'ADJ'))],
#  [('lobbyists', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [("n't", 'ADV'), (('segmenting', 'NOUN'), ('segmenting', 'VERB'))],
#  [('*', 'X'), (('Judging', 'NOUN'), ('Judging', 'VERB'))],
#  [(',', '.'), (('320', 'NOUN'), ('320', 'NUM'))],
#  [('$', '.'), (('18.95', 'NOUN'), ('18.95', 'NUM'))],
#  [('in', 'ADP'), (('common', 'ADJ'), ('common', 'NOUN'))],
#  [('Hammond', 'NOUN'), (('worries', 'NOUN'), ('worries', 'VERB'))],
#  [('will', 'VERB'), (('diminish', 'NOUN'), ('diminish', 'VERB'))],
#  [('the', 'DET'), (('East', 'NOUN'), ('East', 'ADJ'))],
#  [('East', 'ADJ'), (('Anglian', 'NOUN'), ('Anglian', 'ADJ'))],
#  [('group', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-223', 'NOUN'), ('*T*-223', 'X'))],
#  [('bells', 'NOUN'), (('pealing', 'NOUN'), ('pealing', 'VERB'))],
#  [('$', '.'), (('130.7', 'NOUN'), ('130.7', 'NUM'))],
#  [('*T*-1', 'X'), (('worries', 'NOUN'), ('worries', 'VERB'))],
#  [('to', 'PRT'), (('investigate', 'NOUN'), ('investigate', 'VERB'))],
#  [('.', '.'), (('Continuing', 'NOUN'), ('Continuing', 'VERB'))],
#  [('.', '.'), (('Traditionally', 'NOUN'), ('Traditionally', 'ADV'))],
#  [('used', 'VERB'), (('*-66', 'NOUN'), ('*-66', 'X'))],
#  [('incentive', 'NOUN'), (('pay', 'VERB'), ('pay', 'NOUN'))],
#  [('opened', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('a', 'DET'), (('can', 'VERB'), ('can', 'NOUN'))],
#  [('are', 'VERB'), (('betting', 'NOUN'), ('betting', 'VERB'))],
#  [('``', '.'), (('evolved', 'NOUN'), ('evolved', 'VERB'))],
#  [('evolved', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('$', '.'), (('415', 'NOUN'), ('415', 'NUM'))],
#  [('*U*', 'X'), (('charge', 'VERB'), ('charge', 'NOUN'))],
#  [('for', 'ADP'), (('underperforming', 'NOUN'), ('underperforming', 'VERB'))],
#  [('end', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('been', 'VERB'), (('obsessed', 'NOUN'), ('obsessed', 'VERB'))],
#  [('*', 'X'), (('refitting', 'NOUN'), ('refitting', 'VERB'))],
#  [('*-87', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('off', 'PRT'), (('drastically', 'NOUN'), ('drastically', 'ADV'))]]

# %% [markdown]
# ### Viterbi Modification 2

# %% [markdown]
# Step 1: Tag the words using Vanilla Veterbi Algorithm<br>
# Step 2: From the taggged sequence, check whether the word is present in the training data set. If the word is not present, then use some rules to tag it. Below are the rules defined for tagging <br>
#         1. If the word is a number, tag it as 'NUM'
#         2. If word has last three letters 'ous', tag it as 'ADJ'
#         3. If the word ends with 'ing' or 'ed', tag it as 'VERB'
#         4. If the word ends with 'ly', tag it as 'ADV'
#         5. If the previous word is 'has' or 'have' or 'had', tag the current word as 'VERB'
#         6. If the word is in uppercase, tag it as 'NOUN'

# %%
# Viterbi Heuristic
def Viterbi_modification_2(test_words, train_tagged_words_list = train_tagged_words_list):
    tagged_seq = Viterbi(test_words)
    
    V = list(set([i[0] for i in train_tagged_words_list]))             
    viterbi_words = [i[0] for i in tagged_seq]
    viterbi_tags = [i[1] for i in tagged_seq]
            
    for key,word in enumerate(viterbi_words):
        if word not in V:
            #if word.isdigit() == True or word[:-2].isdigit() == True or word.isnumeric()==True or word[-3] == '.':
            if word.isdigit() == True or word.isnumeric()==True or word[-3:] == '.':
                viterbi_tags[key] = 'NUM'                
            elif word[-3:] =='ous' or word[-3:] =='OUS':
                viterbi_tags[key] = 'ADJ'
            elif word[-2:] =='ing' or word[-2:] =='ING' or word[-2:] =='ed' or word[-2:] =='ED':
                viterbi_tags[key] = 'VERB'
            elif word[-2:] =='ly' or word[-2:] =='LY':
                viterbi_tags[key] = 'ADV'
            elif word[0].isupper() == True:
                viterbi_tags[key] = 'NOUN'
            elif viterbi_words[key-1] == 'has' or viterbi_words[key-1] == 'have' or viterbi_words[key-1] == 'had':
                viterbi_tags[key] = 'VERB'
            else:
                viterbi_tags[key] = 'NOUN' 
    #print(list(zip(viterbi_words,viterbi_tags)))
    return list(zip(viterbi_words,viterbi_tags))

# %% [markdown]
# ### Tagging the words using Viterbi_modification_2

# %%
#Calling our user-defined Viterbi_modification_2 to tag words for test data
modified_viterbi_2 = Viterbi_modification_2(test_tagged_words)

# %% [markdown]
# ### Checking the accuracy of Viterbi_modification_2

# %%
# Finding the tags that has been matched with the tags given by humans.
Matched_tags_Viterbi_modified_2 = [i for i, j in zip(modified_viterbi_2, test_run_base) if i == j] 
Matched_tags_Viterbi_modified_2
# Out:
# [('The', 'DET'),
#  ('offer', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-2', 'X'),
#  ('follows', 'VERB'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('*U*', 'X'),
#  ('*T*-3', 'X'),
#  ('was', 'VERB'),
#  ('rejected', 'VERB'),
#  ('*-1', 'X'),
#  ('in', 'ADP'),
#  ('September', 'NOUN'),
#  (',', '.'),
#  ('up', 'PRT'),
#  ('pressure', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('chemicals', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('.', '.'),
#  (',', '.'),
#  ('10', 'NUM'),
#  ('local', 'ADJ'),
#  ('councils', 'NOUN'),
#  ('have', 'VERB'),
#  ('refused', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('honor', 'VERB'),
#  ('fees', 'NOUN'),
#  ('and', 'CONJ'),
#  ('payments', 'NOUN'),
#  ('to', 'PRT'),
#  ('banks', 'NOUN'),
#  ('incurred', 'VERB'),
#  ('*', 'X'),
#  ('during', 'ADP'),
#  ('various', 'ADJ'),
#  ('swaps', 'NOUN'),
#  ('dealings', 'NOUN'),
#  ('.', '.'),
#  ('According', 'VERB'),
#  ('to', 'PRT'),
#  ('Ms.', 'NOUN'),
#  ('Poore', 'NOUN'),
#  (',', '.'),
#  ('Old-House', 'NOUN'),
#  ('Journal', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  (',', '.'),
#  ('her', 'PRON'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('printed', 'VERB'),
#  ('and', 'CONJ'),
#  ('sold', 'VERB'),
#  ('all', 'DET'),
#  ('copies', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('premiere', 'NOUN'),
#  ('issue', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('Mr.', 'NOUN'),
#  ('Barnum', 'NOUN'),
#  ('called', 'VERB'),
#  ('that', 'ADP'),
#  ('``', '.'),
#  ('a', 'DET'),
#  ("''", '.'),
#  ('scenario', 'NOUN'),
#  ('.', '.'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('specialists', 'NOUN'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('bold', 'ADJ'),
#  ('palace', 'NOUN'),
#  ('revolt', 'NOUN'),
#  (',', '.'),
#  ('began', 'VERB'),
#  ('shortly', 'ADV'),
#  ('after', 'ADP'),
#  ('Oct.', 'NOUN'),
#  ('13', 'NUM'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('corporate', 'ADJ'),
#  ('executives', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('companies', 'NOUN'),
#  ('whose', 'PRON'),
#  ('stock', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('is', 'VERB'),
#  ('listed', 'VERB'),
#  ('*-71', 'X'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('them', 'PRON'),
#  ('the', 'DET'),
#  ('exchange', 'NOUN'),
#  ('to', 'PRT'),
#  ('program', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('.', '.'),
#  ('Another', 'DET'),
#  ('proposed', 'VERB'),
#  ('reform', 'NOUN'),
#  ('is', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('program', 'NOUN'),
#  ('traders', 'NOUN'),
#  ('to', 'PRT'),
#  ('an', 'DET'),
#  ('``', '.'),
#  ('uptick', 'NOUN'),
#  ('rule', 'NOUN'),
#  ("''", '.'),
#  ('a', 'DET'),
#  ('reform', 'NOUN'),
#  ('instituted', 'VERB'),
#  ('*', 'X'),
#  ('after', 'ADP'),
#  ('the', 'DET'),
#  ('Great', 'NOUN'),
#  ('Crash', 'NOUN'),
#  ('of', 'ADP'),
#  ('1929', 'NUM'),
#  ('*T*-1', 'X'),
#  ('against', 'ADP'),
#  ('stocks', 'NOUN'),
#  ('being', 'VERB'),
#  ('relentlessly', 'ADV'),
#  ('beaten', 'VERB'),
#  ('*-2', 'X'),
#  ('by', 'ADP'),
#  ('those', 'DET'),
#  ('seeking', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('from', 'ADP'),
#  ('lower', 'ADJ'),
#  ('prices', 'NOUN'),
#  (',', '.'),
#  ('namely', 'ADV'),
#  ('short', 'ADJ'),
#  ('sellers', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('Bush', 'NOUN'),
#  ('administration', 'NOUN'),
#  ("'s", 'PRT'),
#  ('nomination', 'NOUN'),
#  ('of', 'ADP'),
#  ('Clarence', 'NOUN'),
#  ('Thomas', 'NOUN'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('seat', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('federal', 'ADJ'),
#  ('appeals', 'NOUN'),
#  ('court', 'NOUN'),
#  ('here', 'ADV'),
#  ('received', 'VERB'),
#  ('a', 'DET'),
#  ('blow', 'NOUN'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('when', 'ADV'),
#  ('the', 'DET'),
#  ('Bar', 'NOUN'),
#  ('Association', 'NOUN'),
#  ('gave', 'VERB'),
#  ('Mr.', 'NOUN'),
#  ('Thomas', 'NOUN'),
#  ('only', 'ADV'),
#  ('a', 'DET'),
#  ('``', '.'),
#  ("''", '.'),
#  ('rating', 'NOUN'),
#  (',', '.'),
#  ('rather', 'ADV'),
#  ('than', 'ADP'),
#  ('``', '.'),
#  ('well', 'ADV'),
#  ('qualified', 'VERB'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Attorneys', 'NOUN'),
#  ('have', 'VERB'),
#  ('argued', 'VERB'),
#  ('since', 'ADP'),
#  ('1985', 'NUM'),
#  (',', '.'),
#  ('when', 'ADV'),
#  ('the', 'DET'),
#  ('law', 'NOUN'),
#  ('took', 'VERB'),
#  ('effect', 'NOUN'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('they', 'PRON'),
#  ('can', 'VERB'),
#  ('not', 'ADV'),
#  ('provide', 'VERB'),
#  ('information', 'NOUN'),
#  ('about', 'ADP'),
#  ('clients', 'NOUN'),
#  ('who', 'PRON'),
#  ('do', 'VERB'),
#  ("n't", 'ADV'),
#  ('wish', 'VERB'),
#  ('their', 'PRON'),
#  ('identities', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('known', 'VERB'),
#  ('*-3', 'X'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('the', 'DET'),
#  ('Army', 'NOUN'),
#  ('Corps', 'NOUN'),
#  ('of', 'ADP'),
#  ('Engineers', 'NOUN'),
#  ('expects', 'VERB'),
#  ('the', 'DET'),
#  ('river', 'NOUN'),
#  ('level', 'NOUN'),
#  ('to', 'PRT'),
#  ('continue', 'VERB'),
#  ('*-1', 'X'),
#  ('falling', 'VERB'),
#  ('this', 'DET'),
#  ('month', 'NOUN'),
#  ('.', '.'),
#  ('Virginia', 'NOUN'),
#  (':', '.'),
#  ('The', 'DET'),
#  ('department', 'NOUN'),
#  ('previously', 'ADV'),
#  ('estimated', 'VERB'),
#  ('that', 'ADP'),
#  ('durable-goods', 'NOUN'),
#  ('orders', 'NOUN'),
#  ('fell', 'VERB'),
#  ('0.1', 'NUM'),
#  ('%', 'NOUN'),
#  ('in', 'ADP'),
#  ('September', 'NOUN'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('next', 'ADJ'),
#  ('step', 'NOUN'),
#  (',', '.'),
#  ('I', 'PRON'),
#  ('suspect', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('is', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('try', 'VERB'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('get', 'VERB'),
#  ('the', 'DET'),
#  ('law', 'NOUN'),
#  ('changed', 'VERB'),
#  ('.', '.'),
#  ('Thus', 'ADV'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('institution', 'NOUN'),
#  ('obligated', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('make', 'VERB'),
#  ('fixed-rate', 'ADJ'),
#  ('interest', 'NOUN'),
#  ('payments', 'NOUN'),
#  ('on', 'ADP'),
#  ('debt', 'NOUN'),
#  ('swaps', 'NOUN'),
#  ('the', 'DET'),
#  ('payments', 'NOUN'),
#  ('with', 'ADP'),
#  ('another', 'DET'),
#  ('making', 'VERB'),
#  ('floating-rate', 'ADJ'),
#  ('payments', 'NOUN'),
#  ('.', '.'),
#  ('Western', 'NOUN'),
#  ('Gas', 'NOUN'),
#  ('Resources', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  (',', '.'),
#  ('initial', 'ADJ'),
#  ('offering', 'NOUN'),
#  ('of', 'ADP'),
#  ('shares', 'NOUN'),
#  ('of', 'ADP'),
#  ('common', 'ADJ'),
#  ('stock', 'NOUN'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('which', 'DET'),
#  ('shares', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('sold', 'VERB'),
#  ('*-1', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('and', 'CONJ'),
#  ('shares', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('by', 'ADP'),
#  ('a', 'DET'),
#  ('holder', 'NOUN'),
#  (',', '.'),
#  ('via', 'ADP'),
#  ('Prudential-Bache', 'NOUN'),
#  ('Capital', 'NOUN'),
#  ('Funding', 'NOUN'),
#  (',', '.'),
#  ('Smith', 'NOUN'),
#  ('Barney', 'NOUN'),
#  (',', '.'),
#  ('Harris', 'NOUN'),
#  ('Upham', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('Hanifen', 'NOUN'),
#  (',', '.'),
#  ('Imhoff', 'NOUN'),
#  ('Inc', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('his', 'PRON'),
#  ('ruling', 'NOUN'),
#  (',', '.'),
#  ('Judge', 'NOUN'),
#  ('Curry', 'NOUN'),
#  ('added', 'VERB'),
#  ('an', 'DET'),
#  ('additional', 'ADJ'),
#  ('$', '.'),
#  ('55', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('commission', 'NOUN'),
#  ("'s", 'PRT'),
#  ('calculations', 'NOUN'),
#  ('.', '.'),
#  ('Moreover', 'ADV'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Japanese', 'ADJ'),
#  ('government', 'NOUN'),
#  (',', '.'),
#  ('now', 'ADV'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ("'s", 'PRT'),
#  ('largest', 'ADJ'),
#  ('aid', 'NOUN'),
#  ('donor', 'NOUN'),
#  (',', '.'),
#  ('is', 'VERB'),
#  ('pumping', 'VERB'),
#  ('far', 'ADV'),
#  ('assistance', 'NOUN'),
#  ('*ICH*-2', 'X'),
#  ('into', 'ADP'),
#  ('the', 'DET'),
#  ('region', 'NOUN'),
#  ('than', 'ADP'),
#  ('the', 'DET'),
#  ('U.S.', 'NOUN'),
#  ('is', 'VERB'),
#  ('*?*', 'X'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Florio', 'NOUN'),
#  ('lying', 'VERB'),
#  (',', '.'),
#  ("''", '.'),
#  ('the', 'DET'),
#  ('voice', 'NOUN'),
#  ('goes', 'VERB'),
#  (',', '.'),
#  ('because', 'ADP'),
#  ('``', '.'),
#  ('the', 'DET'),
#  ('barrel', 'NOUN'),
#  ('on', 'ADP'),
#  ('Courter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('...', '.'),
#  ('contained', 'VERB'),
#  ('heating', 'NOUN'),
#  ('oil', 'NOUN'),
#  (',', '.'),
#  ('was', 'VERB'),
#  ('cleaned', 'VERB'),
#  ('*-1', 'X'),
#  ('up', 'PRT'),
#  ('and', 'CONJ'),
#  ('caused', 'VERB'),
#  ('no', 'DET'),
#  ('pollution', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('resulting', 'VERB'),
#  ('company', 'NOUN'),
#  ('would', 'VERB'),
#  ('be', 'VERB'),
#  ('the', 'DET'),
#  ('largest', 'ADJ'),
#  ('forest-products', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ('with', 'ADP'),
#  ('sales', 'NOUN'),
#  ('of', 'ADP'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('$', '.'),
#  ('13', 'NUM'),
#  ('billion', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('Stadium', 'NOUN'),
#  ('boosters', 'NOUN'),
#  ('claim', 'VERB'),
#  ('that', 'ADP'),
#  ('without', 'ADP'),
#  ('public', 'ADJ'),
#  ('money', 'NOUN'),
#  ('they', 'PRON'),
#  ('would', 'VERB'),
#  ('never', 'ADV'),
#  ('be', 'VERB'),
#  ('built', 'VERB'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ('We', 'PRON'),
#  ('must', 'VERB'),
#  ('be', 'VERB'),
#  ('very', 'ADV'),
#  ('cautious', 'ADJ'),
#  ('about', 'ADP'),
#  ('*', 'X'),
#  ('investors', 'NOUN'),
#  ('as', 'ADP'),
#  ('``', '.'),
#  ('long-term', 'ADJ'),
#  ("''", '.'),
#  ('or', 'CONJ'),
#  ('``', '.'),
#  ('short-term', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('McDermott', 'NOUN'),
#  ('International', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('its', 'PRON'),
#  ('Babcock', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Wilcox', 'NOUN'),
#  ('unit', 'NOUN'),
#  ('completed', 'VERB'),
#  ('the', 'DET'),
#  ('sale', 'NOUN'),
#  ('of', 'ADP'),
#  ('its', 'PRON'),
#  ('Bailey', 'NOUN'),
#  ('Controls', 'NOUN'),
#  ('Operations', 'NOUN'),
#  ('to', 'PRT'),
#  ('Finmeccanica', 'NOUN'),
#  ('S.p', 'NOUN'),
#  ('.', '.'),
#  ('A.', 'NOUN'),
#  ('for', 'ADP'),
#  ('$', '.'),
#  ('295', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Who', 'PRON'),
#  ('*T*-1', 'X'),
#  ('really', 'ADV'),
#  ('lying', 'VERB'),
#  ('?', '.'),
#  ("''", '.'),
#  ('asks', 'VERB'),
#  ('*T*-2', 'X'),
#  ('a', 'DET'),
#  ('female', 'ADJ'),
#  ('voice', 'NOUN'),
#  ('.', '.'),
#  ('Meanwhile', 'ADV'),
#  (',', '.'),
#  ('business', 'NOUN'),
#  ('and', 'CONJ'),
#  ('government', 'NOUN'),
#  ('leaders', 'NOUN'),
#  ('rebuked', 'VERB'),
#  ('the', 'DET'),
#  ('computer', 'NOUN'),
#  ('makers', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('fretted', 'VERB'),
#  ('about', 'ADP'),
#  ('the', 'DET'),
#  ('broader', 'ADJ'),
#  ('statement', 'NOUN'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('companies', 'NOUN'),
#  ("'", 'PRT'),
#  ('actions', 'NOUN'),
#  ('make', 'VERB'),
#  ('*T*-1', 'X'),
#  ('about', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('cutthroat', 'ADJ'),
#  ('pricing', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('1973', 'NUM'),
#  (',', '.'),
#  ('Wells', 'NOUN'),
#  ('Fargo', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  ('of', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('launched', 'VERB'),
#  ('the', 'DET'),
#  ('Gold', 'NOUN'),
#  ('Account', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('included', 'VERB'),
#  ('free', 'ADJ'),
#  ('checking', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('credit', 'NOUN'),
#  ('card', 'NOUN'),
#  (',', '.'),
#  ('box', 'NOUN'),
#  ('and', 'CONJ'),
#  ('travelers', 'NOUN'),
#  ('checks', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('3', 'NUM'),
#  ('*U*', 'X'),
#  ('monthly', 'ADJ'),
#  ('fee', 'NOUN'),
#  ('.', '.'),
#  ('*-1', 'X'),
#  ('Asked', 'VERB'),
#  ('*-2', 'X'),
#  ('whether', 'ADP'),
#  ('the', 'DET'),
#  ('bidding', 'NOUN'),
#  ('flap', 'NOUN'),
#  ('would', 'VERB'),
#  ('hurt', 'VERB'),
#  ('relations', 'NOUN'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Yamamoto', 'NOUN'),
#  ('said', 'VERB'),
#  (',', '.'),
#  ('``', '.'),
#  ('this', 'DET'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('a', 'DET'),
#  ('minus', 'NOUN'),
#  ('factor', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('For', 'ADP'),
#  ('the', 'DET'),
#  ('Agency', 'NOUN'),
#  ('for', 'ADP'),
#  ('International', 'NOUN'),
#  ('Development', 'NOUN'),
#  (',', '.'),
#  ('appropriators', 'NOUN'),
#  ('approved', 'VERB'),
#  ('$', '.'),
#  ('200', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('secondary', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('under', 'ADP'),
#  ('an', 'DET'),
#  ('expanded', 'VERB'),
#  ('credit', 'NOUN'),
#  ('insurance', 'NOUN'),
#  ('program', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('total', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('Overseas', 'NOUN'),
#  ('Investment', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('are', 'VERB'),
#  ('increased', 'VERB'),
#  ('*-3', 'X'),
#  ('by', 'ADP'),
#  ('$', '.'),
#  ('40', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('over', 'ADP'),
#  ('fiscal', 'ADJ'),
#  ('1989', 'NUM'),
#  ('as', 'ADP'),
#  ('part', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('Poland', 'NOUN'),
#  ('package', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('both', 'DET'),
#  ('cases', 'NOUN'),
#  (',', '.'),
#  ('NEC', 'NOUN'),
#  ('lost', 'VERB'),
#  ('the', 'DET'),
#  ('contract', 'NOUN'),
#  ('to', 'PRT'),
#  ('Fujitsu', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('made', 'VERB'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('bid', 'NOUN'),
#  ('and', 'CONJ'),
#  ('won', 'VERB'),
#  ('a', 'DET'),
#  ('lottery', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Cosby', 'NOUN'),
#  ("''", '.'),
#  ('is', 'VERB'),
#  ('down', 'ADV'),
#  ('a', 'DET'),
#  ('full', 'ADJ'),
#  ('ratings', 'NOUN'),
#  ('point', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('week', 'NOUN'),
#  ('of', 'ADP'),
#  ('Oct.', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('week', 'NOUN'),
#  ('a', 'DET'),
#  ('year', 'NOUN'),
#  (',', '.'),
#  ('according', 'VERB'),
#  ('to', 'PRT'),
#  ('A.C.', 'NOUN'),
#  ('Nielsen', 'NOUN'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('Despite', 'ADP'),
#  ('the', 'DET'),
#  ('Supreme', 'NOUN'),
#  ('Court', 'NOUN'),
#  ("'s", 'PRT'),
#  ('refusal', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('hear', 'VERB'),
#  ('the', 'DET'),
#  ('case', 'NOUN'),
#  (',', '.'),
#  ('there', 'DET'),
#  ('are', 'VERB'),
#  ('serious', 'ADJ'),
#  ('constitutional', 'ADJ'),
#  ('issues', 'NOUN'),
#  ('of', 'ADP'),
#  ('due', 'ADJ'),
#  ('process', 'NOUN'),
#  ('and', 'CONJ'),
#  ('takings', 'NOUN'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('defendants', 'NOUN'),
#  ('.', '.'),
#  ('And', 'CONJ'),
#  ('some', 'DET'),
#  ('grain', 'NOUN'),
#  ('analysts', 'NOUN'),
#  ('are', 'VERB'),
#  ('predicting', 'VERB'),
#  ('that', 'ADP'),
#  ('corn', 'NOUN'),
#  ('prices', 'NOUN'),
#  ('might', 'VERB'),
#  ('this', 'DET'),
#  ('month', 'NOUN'),
#  ('as', 'ADP'),
#  ('exporters', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('find', 'VERB'),
#  ('enough', 'ADV'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('crop', 'NOUN'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('to', 'PRT'),
#  ('meet', 'VERB'),
#  ('their', 'PRON'),
#  ('obligations', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('Soviets', 'NOUN'),
#  ('.', '.'),
#  ('Still', 'ADV'),
#  ('is', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Sony', 'NOUN'),
#  ("'s", 'PRT'),
#  ('effort', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('hire', 'VERB'),
#  ('producers', 'NOUN'),
#  ('Jon', 'NOUN'),
#  ('Peters', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Peter', 'NOUN'),
#  ('Guber', 'NOUN'),
#  ('to', 'PRT'),
#  ('run', 'VERB'),
#  ('the', 'DET'),
#  ('studio', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('if', 'ADP'),
#  ('Columbia', 'NOUN'),
#  ('could', 'VERB'),
#  ('keep', 'VERB'),
#  ('its', 'PRON'),
#  ('junk', 'NOUN'),
#  ('bonds', 'NOUN'),
#  ('separate', 'ADJ'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('thrift', 'NOUN'),
#  ('they', 'PRON'),
#  ('mature', 'VERB'),
#  ('--', '.'),
#  ('at', 'ADP'),
#  ('full', 'ADJ'),
#  ('value', 'NOUN'),
#  (',', '.'),
#  ('unless', 'ADP'),
#  ('the', 'DET'),
#  ('issuer', 'NOUN'),
#  ('goes', 'VERB'),
#  ('bust', 'NOUN'),
#  ('or', 'CONJ'),
#  ('--', '.'),
#  ('the', 'DET'),
#  ('junk', 'NOUN'),
#  ('portfolio', 'NOUN'),
#  ('might', 'VERB'),
#  ('do', 'VERB'),
#  ('.', '.'),
#  ('For', 'ADP'),
#  ('some', 'DET'),
#  ('time', 'NOUN'),
#  (',', '.'),
#  ('banks', 'NOUN'),
#  ('have', 'VERB'),
#  ('been', 'VERB'),
#  ('packages', 'NOUN'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('demographic', 'ADJ'),
#  ('segment', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('highest', 'ADJ'),
#  ('savings', 'NOUN'),
#  ('.', '.'),
#  ('Cray', 'NOUN'),
#  ('Research', 'NOUN'),
#  ('indicated', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('survival', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('spinoff', 'NOUN'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-1', 'X'),
#  ('is', 'VERB'),
#  ('developing', 'VERB'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('supercomputer', 'NOUN'),
#  (',', '.'),
#  ('heavily', 'ADV'),
#  ('on', 'ADP'),
#  ('its', 'PRON'),
#  ('chairman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('chief', 'NOUN'),
#  ('designer', 'NOUN'),
#  (',', '.'),
#  ('Seymour', 'NOUN'),
#  ('Cray', 'NOUN'),
#  ('.', '.'),
#  ('Congress', 'NOUN'),
#  ('learned', 'VERB'),
#  ('during', 'ADP'),
#  ('the', 'DET'),
#  ('Reagan', 'NOUN'),
#  ('administration', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('could', 'VERB'),
#  ('the', 'DET'),
#  ('branch', 'NOUN'),
#  ('by', 'ADP'),
#  ('*-1', 'X'),
#  ('again', 'ADV'),
#  ('and', 'CONJ'),
#  ('again', 'ADV'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('seven', 'NUM'),
#  ('words', 'NOUN'),
#  (':', '.'),
#  ('``', '.'),
#  ('Provided', 'VERB'),
#  (',', '.'),
#  ('no', 'DET'),
#  ('funds', 'NOUN'),
#  ('shall', 'VERB'),
#  ('be', 'VERB'),
#  ('spent', 'VERB'),
#  ('*-48', 'X'),
#  ('...', '.'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Then', 'ADV'),
#  ('*', 'X'),
#  ('send', 'VERB'),
#  ('your', 'PRON'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('savings', 'NOUN'),
#  ('institution', 'NOUN'),
#  ('has', 'VERB'),
#  ('taken', 'VERB'),
#  ('a', 'DET'),
#  ('bad', 'ADJ'),
#  ('rap', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('press', 'NOUN'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('its', 'PRON'),
#  ('line', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('other', 'ADJ'),
#  ('concern', 'NOUN'),
#  ('was', 'VERB'),
#  ("n't", 'ADV'),
#  ('identified', 'VERB'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('Stronach', 'NOUN'),
#  (',', '.'),
#  ('founder', 'NOUN'),
#  ('and', 'CONJ'),
#  ('controlling', 'VERB'),
#  ('shareholder', 'NOUN'),
#  ('of', 'ADP'),
#  ('Magna', 'NOUN'),
#  (',', '.'),
#  ('resigned', 'VERB'),
#  ('as', 'ADP'),
#  ('chief', 'NOUN'),
#  ('executive', 'NOUN'),
#  ('officer', 'NOUN'),
#  ('last', 'ADJ'),
#  ('year', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('seek', 'VERB'),
#  (',', '.'),
#  ('unsuccessfully', 'ADV'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('seat', 'NOUN'),
#  ('in', 'ADP'),
#  ('Canada', 'NOUN'),
#  ("'s", 'PRT'),
#  ('Parliament', 'NOUN'),
#  ('.', '.'),
#  ('60', 'NUM'),
#  ('million', 'NUM'),
#  ('Swiss', 'ADJ'),
#  ('francs', 'NOUN'),
#  ('of', 'ADP'),
#  ('privately', 'ADV'),
#  ('placed', 'VERB'),
#  ('convertible', 'ADJ'),
#  ('notes', 'NOUN'),
#  ('due', 'ADJ'),
#  ('Dec.', 'NOUN'),
#  ('31', 'NUM'),
#  (',', '.'),
#  ('1993', 'NUM'),
#  (',', '.'),
#  ('with', 'ADP'),
#  ('a', 'DET'),
#  ('fixed', 'VERB'),
#  ('0.25', 'NUM'),
#  ('%', 'NOUN'),
#  ('coupon', 'NOUN'),
#  ('at', 'ADP'),
#  ('par', 'NOUN'),
#  ('via', 'ADP'),
#  ('Union', 'NOUN'),
#  ('Bank', 'NOUN'),
#  ...]

# %%
accuracy = len(Matched_tags_Viterbi_modified_2)/len(modified_viterbi_2)
accuracy
# Out:
# 0.9389121338912134

# %% [markdown]
# **Observation** - The accuracy has improved from 93.07% to 93.76% in rule based tagger. Rule-based tagger shows a good performance compared to Vanilla Viterbi and Viterbi_modification_1 (most commonly used tag).

# %%
new_row = {'Algorithm':' Viterbi_modification_2(rule-based)', 'Accuracy':accuracy}
Accuracy_df = Accuracy_df.append(new_row, ignore_index=True)
Accuracy_df
# Out:
#                                     Algorithm  Accuracy
# 0                             Vannila Viterbi  0.895816
# 1   Viterbi_modification_1(commonly used tag)  0.930962
# 2          Viterbi_modification_2(rule-based)  0.938912

# %% [markdown]
# ### Words that have incorrect tags

# %%
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(modified_viterbi_2, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[('$', '.'), (('55-a-share', 'NOUN'), ('55-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('bid', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [(',', '.'), (('steps', 'NOUN'), ('steps', 'VERB'))],
#  [('.', '.'), (('Already', 'NOUN'), ('Already', 'ADV'))],
#  [('her', 'PRON'), (('publishing', 'VERB'), ('publishing', 'NOUN'))],
#  [('all', 'DET'), (('126,000', 'NOUN'), ('126,000', 'NUM'))],
#  [('a', 'DET'), (('worst-case', 'NOUN'), ('worst-case', 'ADJ'))],
#  [('to', 'PRT'), (('telephone', 'NOUN'), ('telephone', 'VERB'))],
#  [('them', 'PRON'), (('pressure', 'NOUN'), ('pressure', 'VERB'))],
#  [('to', 'PRT'), (('ban', 'NOUN'), ('ban', 'VERB'))],
#  [('traders', 'NOUN'), (('answer', 'NOUN'), ('answer', 'VERB'))],
#  [('1929', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-1', 'X'), (('protects', 'NOUN'), ('protects', 'VERB'))],
#  [('*-2', 'X'), (('downward', 'ADJ'), ('downward', 'ADV'))],
#  [('to', 'PRT'), (('profit', 'NOUN'), ('profit', 'VERB'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('``', '.'), (('qualified', 'VERB'), ('qualified', 'ADJ'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('who', 'PRON'), (('*T*-127', 'NOUN'), ('*T*-127', 'X'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('of', 'ADP'), (('3,250,000', 'NOUN'), ('3,250,000', 'NUM'))],
#  [('which', 'DET'), (('3,040,000', 'NOUN'), ('3,040,000', 'NUM'))],
#  [('and', 'CONJ'), (('210,000', 'NOUN'), ('210,000', 'NUM'))],
#  [('far', 'ADV'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('Florio', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('goes', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [("'s", 'PRT'), (('land', 'VERB'), ('land', 'NOUN'))],
#  [('with', 'ADP'), (('combined', 'ADJ'), ('combined', 'VERB'))],
#  [('*', 'X'), (('labeling', 'NOUN'), ('labeling', 'VERB'))],
#  [('*T*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('which', 'DET'), (('*T*-198', 'NOUN'), ('*T*-198', 'X'))],
#  [(',', '.'), (('safe-deposit', 'NOUN'), ('safe-deposit', 'ADJ'))],
#  [('hurt', 'VERB'), (('U.S.-Japan', 'NOUN'), ('U.S.-Japan', 'ADJ'))],
#  [('expanded', 'VERB'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('Overseas', 'NOUN'), (('Private', 'ADJ'), ('Private', 'NOUN'))],
#  [('which', 'DET'), (('*T*-139', 'NOUN'), ('*T*-139', 'X'))],
#  [('a', 'DET'), (('tie-breaking', 'NOUN'), ('tie-breaking', 'ADJ'))],
#  [('Oct.', 'NOUN'), (('2-8', 'NOUN'), ('2-8', 'NUM'))],
#  [('year', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('and', 'CONJ'), (('uncompensated', 'VERB'), ('uncompensated', 'ADJ'))],
#  [('might', 'VERB'), (('gyrate', 'NOUN'), ('gyrate', 'VERB'))],
#  [('exporters', 'NOUN'), (('scrounge', 'NOUN'), ('scrounge', 'VERB'))],
#  [('Still', 'ADV'), (('unresolved', 'VERB'), ('unresolved', 'ADJ'))],
#  [('thrift', 'NOUN'), (('till', 'NOUN'), ('till', 'ADP'))],
#  [('or', 'CONJ'), (('restructures', 'NOUN'), ('restructures', 'VERB'))],
#  [('do', 'VERB'), (('all', 'DET'), ('all', 'ADV'))],
#  [('all', 'ADV'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('been', 'VERB'), (('aiming', 'NOUN'), ('aiming', 'VERB'))],
#  [('the', 'DET'), (('elderly', 'ADV'), ('elderly', 'ADJ'))],
#  [(',', '.'), (('depends', 'NOUN'), ('depends', 'VERB'))],
#  [('could', 'VERB'), (('intimidate', 'NOUN'), ('intimidate', 'VERB'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('*-1', 'X'), (('uttering', 'NOUN'), ('uttering', 'VERB'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('your', 'PRON'), (('support', 'VERB'), ('support', 'NOUN'))],
#  [('institution', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-208', 'NOUN'), ('*T*-208', 'X'))],
#  [('its', 'PRON'), (('bottom', 'NOUN'), ('bottom', 'ADJ'))],
#  [('would', 'VERB'), (('junk', 'NOUN'), ('junk', 'VERB'))],
#  [('an', 'DET'), (('innovative', 'NOUN'), ('innovative', 'ADJ'))],
#  [('innovative', 'ADJ'), (('market-based', 'VERB'), ('market-based', 'ADJ'))],
#  [('*', 'X'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [('buying', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('%', 'NOUN'), (('holding', 'VERB'), ('holding', 'NOUN'))],
#  [("'s", 'PRT'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('Dec.', 'NOUN'), (('2-3', 'NOUN'), ('2-3', 'NUM'))],
#  [('was', 'VERB'), (('116.9', 'NOUN'), ('116.9', 'NUM'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('of', 'ADP'), (('112.9', 'NOUN'), ('112.9', 'NUM'))],
#  [('of', 'ADP'), (('120.7', 'NOUN'), ('120.7', 'NUM'))],
#  [('auctioned', 'VERB'), (('*-109', 'NOUN'), ('*-109', 'X'))],
#  [('yield', 'VERB'), (('7.65', 'NOUN'), ('7.65', 'NUM'))],
#  [('drifted', 'VERB'), (('lower', 'ADJ'), ('lower', 'ADV'))],
#  [('lower', 'ADV'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('U.S.', 'NOUN'), (('purchasing', 'VERB'), ('purchasing', 'NOUN'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('successfully', 'ADV'), (('mobilizing', 'NOUN'), ('mobilizing', 'VERB'))],
#  [('to', 'PRT'), (('bludgeon', 'NOUN'), ('bludgeon', 'VERB'))],
#  [('stay', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('issue', 'NOUN'), (('trades', 'NOUN'), ('trades', 'VERB'))],
#  [('its', 'PRON'), (('face', 'VERB'), ('face', 'NOUN'))],
#  [('Association', 'NOUN'), (('leapt', 'NOUN'), ('leapt', 'VERB'))],
#  [('effective', 'ADJ'),
#   (('search-and-seizure', 'NOUN'), ('search-and-seizure', 'ADJ'))],
#  [('to', 'PRT'), (('aid', 'NOUN'), ('aid', 'VERB'))],
#  [('system', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('soared', 'VERB'), (('higher', 'ADJ'), ('higher', 'ADV'))],
#  [('Cataracts', 'NOUN'), (('refer', 'NOUN'), ('refer', 'VERB'))],
#  [('a', 'DET'), (('needy', 'NOUN'), ('needy', 'ADJ'))],
#  [('loan', 'NOUN'), (('solvent', 'NOUN'), ('solvent', 'ADJ'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('almost', 'ADV'), (('over', 'ADP'), ('over', 'ADJ'))],
#  [('by', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('to', 'PRT'), (('8.75', 'NOUN'), ('8.75', 'NUM'))],
#  [('shown', 'VERB'), (('no', 'ADV'), ('no', 'DET'))],
#  [('no', 'DET'), (('sign', 'VERB'), ('sign', 'NOUN'))],
#  [('default', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('expected', 'VERB'), (('*-129', 'NOUN'), ('*-129', 'X'))],
#  [('a', 'DET'), (('richer', 'NOUN'), ('richer', 'ADJ'))],
#  [('the', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('and', 'CONJ'), (('galvanized', 'VERB'), ('galvanized', 'ADJ'))],
#  [('than', 'ADP'), (('lower-priced', 'VERB'), ('lower-priced', 'ADJ'))],
#  [('lower-priced', 'ADJ'), (('structural', 'NOUN'), ('structural', 'ADJ'))],
#  [('COLLECTING', 'NOUN'), (('gains', 'NOUN'), ('gains', 'VERB'))],
#  [('a', 'DET'), (('valuable', 'NOUN'), ('valuable', 'ADJ'))],
#  [('powers', 'NOUN'), (('works', 'NOUN'), ('works', 'VERB'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('about', 'ADP'), (('shrinking', 'NOUN'), ('shrinking', 'VERB'))],
#  [('in', 'ADP'), (('super-absorbent', 'NOUN'), ('super-absorbent', 'ADJ'))],
#  [('some', 'DET'), (('light', 'ADJ'), ('light', 'NOUN'))],
#  [('the', 'DET'), (('dark', 'NOUN'), ('dark', 'ADJ'))],
#  [('where', 'ADV'), (('high-stakes', 'NOUN'), ('high-stakes', 'ADJ'))],
#  [('to', 'PRT'), (('cheat', 'NOUN'), ('cheat', 'VERB'))],
#  [('is', 'VERB'), (('wrestling', 'NOUN'), ('wrestling', 'VERB'))],
#  [('especially', 'ADV'), (('intelligent', 'NOUN'), ('intelligent', 'ADJ'))],
#  [('temporarily', 'ADV'), (('insane', 'NOUN'), ('insane', 'ADJ'))],
#  [('movie', 'NOUN'), (('ends', 'NOUN'), ('ends', 'VERB'))],
#  [('anything', 'NOUN'), (('whimsical', 'NOUN'), ('whimsical', 'ADJ'))],
#  [('or', 'CONJ'), (('enviable', 'NOUN'), ('enviable', 'ADJ'))],
#  [(',', '.'), (('beaten', 'VERB'), ('beaten', 'ADJ'))],
#  [('$', '.'), (('45-a-share', 'NOUN'), ('45-a-share', 'ADJ'))],
#  [('45-a-share', 'ADJ'), (('offer', 'VERB'), ('offer', 'NOUN'))],
#  [('a', 'DET'), (('Scandinavian', 'NOUN'), ('Scandinavian', 'ADJ'))],
#  [('$', '.'), (('2.44', 'NOUN'), ('2.44', 'NUM'))],
#  [('``', '.'), (('Little', 'ADV'), ('Little', 'ADJ'))],
#  [('*-1', 'X'), (('wanting', 'NOUN'), ('wanting', 'VERB'))],
#  [('.', '.'), (('Troubled', 'VERB'), ('Troubled', 'NOUN'))],
#  [('fired', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('its', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('is', 'VERB'), (('discontinuing', 'NOUN'), ('discontinuing', 'VERB'))],
#  [('which', 'DET'), (('there', 'ADV'), ('there', 'DET'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'ADJ'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'ADJ'))],
#  [('-LRB-', '.'), (('Fewer', 'NOUN'), ('Fewer', 'ADJ'))],
#  [('weapon', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-245', 'NOUN'), ('*T*-245', 'X'))],
#  [('can', 'VERB'), (('shoot', 'NOUN'), ('shoot', 'VERB'))],
#  [('them', 'PRON'), (('down', 'ADV'), ('down', 'ADP'))],
#  [("'s", 'VERB'), (('imaginative', 'NOUN'), ('imaginative', 'ADJ'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('*ICH*-1', 'X'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('and', 'CONJ'), (('punish', 'NOUN'), ('punish', 'VERB'))],
#  [('which', 'DET'), (('*T*-147', 'NOUN'), ('*T*-147', 'X'))],
#  [('*T*-147', 'X'), (('measures', 'NOUN'), ('measures', 'VERB'))],
#  [('the', 'DET'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('of', 'ADP'), (('45.3', 'NOUN'), ('45.3', 'NUM'))],
#  [('a', 'DET'), (('stark', 'NOUN'), ('stark', 'ADJ'))],
#  [('traditional', 'ADJ'),
#   (('policy-making', 'NOUN'), ('policy-making', 'ADJ'))],
#  [('the', 'DET'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('to', 'PRT'), (('debate', 'NOUN'), ('debate', 'VERB'))],
#  [('a', 'DET'), (('31-year-old', 'NOUN'), ('31-year-old', 'ADJ'))],
#  [('would', 'VERB'), (('like', 'ADP'), ('like', 'VERB'))],
#  [('trading', 'NOUN'), (('disappear', 'NOUN'), ('disappear', 'VERB'))],
#  [(',', '.'), (('Texas-based', 'VERB'), ('Texas-based', 'ADJ'))],
#  [('a', 'DET'), (('40-megabyte', 'NOUN'), ('40-megabyte', 'ADJ'))],
#  [('a', 'DET'), (('color', 'VERB'), ('color', 'NOUN'))],
#  [('are', 'VERB'), (('stretching', 'NOUN'), ('stretching', 'VERB'))],
#  [('and', 'CONJ'), (('wide', 'ADJ'), ('wide', 'ADV'))],
#  [('to', 'PRT'), (('depend', 'NOUN'), ('depend', 'VERB'))],
#  [('has', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('have', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('.', '.'), (('Second', 'NOUN'), ('Second', 'ADJ'))],
#  [('they', 'PRON'), (('channel', 'NOUN'), ('channel', 'VERB'))],
#  [('That', 'DET'), (('attracts', 'NOUN'), ('attracts', 'VERB'))],
#  [('was', 'VERB'), (('kind', 'NOUN'), ('kind', 'ADJ'))],
#  [('and', 'CONJ'), (('playful', 'NOUN'), ('playful', 'ADJ'))],
#  [('was', 'VERB'), (('dreadful', 'NOUN'), ('dreadful', 'ADJ'))],
#  [('her', 'PRON'), (('war-damaged', 'VERB'), ('war-damaged', 'ADJ'))],
#  [('called', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('to', 'PRT'), (('arrest', 'NOUN'), ('arrest', 'VERB'))],
#  [('were', 'VERB'), (('occupying', 'NOUN'), ('occupying', 'VERB'))],
#  [('.', '.'), (('Back', 'NOUN'), ('Back', 'ADV'))],
#  [('squeezed', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('*-1', 'X'), (('boarding', 'NOUN'), ('boarding', 'VERB'))],
#  [('a', 'DET'), (('collective', 'NOUN'), ('collective', 'ADJ'))],
#  [('it', 'PRON'), (('demonstrates', 'NOUN'), ('demonstrates', 'VERB'))],
#  [('*T*-1', 'X'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('*', 'X'), (('undercutting', 'NOUN'), ('undercutting', 'VERB'))],
#  [("'", 'PRT'), (('potential', 'ADJ'), ('potential', 'NOUN'))],
#  [('.', '.'), (('b', 'NOUN'), ('b', 'X'))],
#  [('the', 'DET'), (('top-yielding', 'NOUN'), ('top-yielding', 'ADJ'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('of', 'ADP'), (('9.37', 'NOUN'), ('9.37', 'NUM'))],
#  [('from', 'ADP'), (('9.45', 'NOUN'), ('9.45', 'NUM'))],
#  [(',', '.'), (('comments', 'NOUN'), ('comments', 'VERB'))],
#  [('``', '.'), (('increases', 'NOUN'), ('increases', 'VERB'))],
#  [('will', 'VERB'), (('oversee', 'NOUN'), ('oversee', 'VERB'))],
#  [('get', 'VERB'), (('across', 'ADP'), ('across', 'PRT'))],
#  [('a', 'DET'), (('razor-thin', 'NOUN'), ('razor-thin', 'ADJ'))],
#  [('go', 'VERB'), (('through', 'ADP'), ('through', 'PRT'))],
#  [('Beijing', 'NOUN'), (('food-shop', 'NOUN'), ('food-shop', 'ADJ'))],
#  [('food-shop', 'ADJ'), (('assistant', 'ADJ'), ('assistant', 'NOUN'))],
#  [('mainland', 'NOUN'), (('Chinese', 'ADJ'), ('Chinese', 'NOUN'))],
#  [('*-1', 'X'), (('sketching', 'NOUN'), ('sketching', 'VERB'))],
#  [('Too', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('give', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('*', 'X'), (('Being', 'NOUN'), ('Being', 'VERB'))],
#  [('the', 'DET'), (('37-year-old', 'NOUN'), ('37-year-old', 'ADJ'))],
#  [(',', '.'), (('The', 'DET'), ('The', 'NOUN'))],
#  [('will', 'VERB'), (('report', 'NOUN'), ('report', 'VERB'))],
#  [('century', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('ran', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('*T*-14', 'X'), (('matters', 'NOUN'), ('matters', 'VERB'))],
#  [('doing', 'VERB'), (('fine', 'NOUN'), ('fine', 'ADV'))],
#  [('not', 'ADV'), (('unethical', 'NOUN'), ('unethical', 'ADJ'))],
#  [('a', 'DET'), (('higher-salaried', 'VERB'), ('higher-salaried', 'ADJ'))],
#  [("n't", 'ADV'), (('encounter', 'NOUN'), ('encounter', 'VERB'))],
#  [('that', 'ADP'), (('non-farm', 'NOUN'), ('non-farm', 'ADJ'))],
#  [('by', 'ADP'), (('152,000', 'NOUN'), ('152,000', 'NUM'))],
#  [('EVERYONE', 'NOUN'), (('AGREES', 'NOUN'), ('AGREES', 'VERB'))],
#  [('with', 'ADP'),
#   (('yttrium-containing', 'NOUN'), ('yttrium-containing', 'ADJ'))],
#  [('or', 'CONJ'), (('minus', 'NOUN'), ('minus', 'CONJ'))],
#  [('the', 'DET'), (('shaky', 'NOUN'), ('shaky', 'ADJ'))],
#  [('a', 'DET'), (('slowing', 'NOUN'), ('slowing', 'VERB'))],
#  [(':', '.'), (('day-care', 'NOUN'), ('day-care', 'ADJ'))],
#  [('day-care', 'ADJ'), (('centers', 'VERB'), ('centers', 'NOUN'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('Mortgage-Backed', 'VERB'), ('Mortgage-Backed', 'NOUN'))],
#  [('or', 'CONJ'), (('early', 'ADJ'), ('early', 'ADV'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('this', 'DET'), (('minute', 'ADJ'), ('minute', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-84', 'NOUN'), ('*T*-84', 'X'))],
#  [('for', 'ADP'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [(',', '.'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('will', 'VERB'), (('worsen', 'NOUN'), ('worsen', 'VERB'))],
#  [('plant', 'NOUN'), (('engineering', 'NOUN'), ('engineering', 'VERB'))],
#  [('military', 'ADJ'), (('command', 'VERB'), ('command', 'NOUN'))],
#  [('rebel', 'NOUN'), (('forces', 'VERB'), ('forces', 'NOUN'))],
#  [('$', '.'), (('12.52', 'NOUN'), ('12.52', 'NUM'))],
#  [('$', '.'), (('11.95', 'NOUN'), ('11.95', 'NUM'))],
#  [('the', 'DET'), (('36-store', 'NOUN'), ('36-store', 'ADJ'))],
#  [('to', 'PRT'), (('free', 'ADJ'), ('free', 'VERB'))],
#  [('the', 'DET'), (('1990s', 'NUM'), ('1990s', 'NOUN'))],
#  [('the', 'DET'), (('smallest', 'NOUN'), ('smallest', 'ADJ'))],
#  [('which', 'DET'), (('*T*-162', 'NOUN'), ('*T*-162', 'X'))],
#  [('*T*-162', 'X'), (('costs', 'NOUN'), ('costs', 'VERB'))],
#  [('costs', 'VERB'), (('around', 'ADP'), ('around', 'ADV'))],
#  [('organizations', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('?', '.'), (('Preliminary', 'NOUN'), ('Preliminary', 'ADJ'))],
#  [("'s", 'PRT'), (('export-oriented', 'VERB'), ('export-oriented', 'ADJ'))],
#  [('will', 'VERB'), (('likely', 'ADJ'), ('likely', 'ADV'))],
#  [('likely', 'ADV'), (('trim', 'NOUN'), ('trim', 'VERB'))],
#  [('than', 'ADP'), (('21,000', 'NOUN'), ('21,000', 'NUM'))],
#  [('insist', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('*-5', 'X'), (('jumping', 'NOUN'), ('jumping', 'VERB'))],
#  [('jumping', 'VERB'), (('in', 'ADP'), ('in', 'ADV'))],
#  [('The', 'DET'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('party', 'NOUN'), (('late', 'ADJ'), ('late', 'ADV'))],
#  [('be', 'VERB'), (('ready', 'NOUN'), ('ready', 'ADJ'))],
#  [('The', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('total', 'NOUN'), (('marks', 'NOUN'), ('marks', 'VERB'))],
#  [('company', 'NOUN'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'NOUN'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'VERB'), ('unwanted', 'ADJ'))],
#  [('to', 'PRT'), (('single', 'ADJ'), ('single', 'VERB'))],
#  [('out', 'PRT'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('to', 'PRT'), (('slip', 'NOUN'), ('slip', 'VERB'))],
#  [('oldest', 'ADJ'), (('bell-ringing', 'NOUN'), ('bell-ringing', 'ADJ'))],
#  [('remains', 'VERB'), (('male-only', 'ADV'), ('male-only', 'ADJ'))],
#  [('fact', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-230', 'NOUN'), ('*T*-230', 'X'))],
#  [('particularly', 'ADV'), (('galling', 'NOUN'), ('galling', 'ADJ'))],
#  [('the', 'DET'), (('sole', 'NOUN'), ('sole', 'ADJ'))],
#  [('lobbyists', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [("n't", 'ADV'), (('segmenting', 'NOUN'), ('segmenting', 'VERB'))],
#  [('*', 'X'), (('Judging', 'NOUN'), ('Judging', 'VERB'))],
#  [('$', '.'), (('18.95', 'NOUN'), ('18.95', 'NUM'))],
#  [('in', 'ADP'), (('common', 'ADJ'), ('common', 'NOUN'))],
#  [('Hammond', 'NOUN'), (('worries', 'NOUN'), ('worries', 'VERB'))],
#  [('will', 'VERB'), (('diminish', 'NOUN'), ('diminish', 'VERB'))],
#  [('the', 'DET'), (('East', 'NOUN'), ('East', 'ADJ'))],
#  [('East', 'ADJ'), (('Anglian', 'NOUN'), ('Anglian', 'ADJ'))],
#  [('group', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-223', 'NOUN'), ('*T*-223', 'X'))],
#  [('bells', 'NOUN'), (('pealing', 'NOUN'), ('pealing', 'VERB'))],
#  [('$', '.'), (('130.7', 'NOUN'), ('130.7', 'NUM'))],
#  [('*T*-1', 'X'), (('worries', 'NOUN'), ('worries', 'VERB'))],
#  [('to', 'PRT'), (('investigate', 'NOUN'), ('investigate', 'VERB'))],
#  [('.', '.'), (('Continuing', 'NOUN'), ('Continuing', 'VERB'))],
#  [('used', 'VERB'), (('*-66', 'NOUN'), ('*-66', 'X'))],
#  [('incentive', 'NOUN'), (('pay', 'VERB'), ('pay', 'NOUN'))],
#  [('opened', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('a', 'DET'), (('can', 'VERB'), ('can', 'NOUN'))],
#  [('are', 'VERB'), (('betting', 'NOUN'), ('betting', 'VERB'))],
#  [('evolved', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('*U*', 'X'), (('charge', 'VERB'), ('charge', 'NOUN'))],
#  [('for', 'ADP'), (('underperforming', 'NOUN'), ('underperforming', 'VERB'))],
#  [('end', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('*', 'X'), (('refitting', 'NOUN'), ('refitting', 'VERB'))],
#  [('*-87', 'X'), (('more', 'ADV'), ('more', 'ADJ'))]]

# %% [markdown]
# ### Viterbi Modification 3

# %% [markdown]
# **Viterbi_modification_3** <br>
# State Probability = emission_p * transition_p <br>
# If the emission probability is '0' the state probability will become '0'. To overcome it, multiply the emission probability with least constant, so that the state probability will not become '0'.

# %%
# Viterbi Heuristic
def Viterbi_modification_3(words, train_tagged_words_list = train_tagged_words_list):
    #state  - list used to hold the state probabilities
    state = []
    
    #T - list contains all the Tags from train_bag
    T = list(set([pair[1] for pair in train_tagged_words_list]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = transition_probability_df.loc['.', tag] #"." - represents the start
            else:
                transition_p = transition_probability_df.loc[state[-1], tag]
                
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            if (emission_p == 0):
                state_probability = (emission_p+0.00001) * transition_p
            else: 
                state_probability = emission_p * transition_p  
            
            p.append(state_probability)
            
            
        pmax = max(p)
        state_max = T[p.index(pmax)]
        state.append(state_max)
        
    return list(zip(words, state))

# %% [markdown]
# ### Tagging the words using Viterbi_modification_3

# %%
#Calling our user-defined Viterbi_modification_3 to tag words for test data
modified_viterbi_3 = Viterbi_modification_3(test_tagged_words)

# %%
# Finding the tags that has been matched with the tags given by humans.
Matched_tags_Viterbi_modified_3 = [i for i, j in zip(modified_viterbi_3, test_run_base) if i == j] 
Matched_tags_Viterbi_modified_3
# Out:
# [('The', 'DET'),
#  ('offer', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-2', 'X'),
#  ('follows', 'VERB'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('*U*', 'X'),
#  ('*T*-3', 'X'),
#  ('was', 'VERB'),
#  ('rejected', 'VERB'),
#  ('*-1', 'X'),
#  ('in', 'ADP'),
#  ('September', 'NOUN'),
#  (',', '.'),
#  ('up', 'PRT'),
#  ('pressure', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('chemicals', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('.', '.'),
#  (',', '.'),
#  ('10', 'NUM'),
#  ('local', 'ADJ'),
#  ('councils', 'NOUN'),
#  ('have', 'VERB'),
#  ('refused', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('honor', 'VERB'),
#  ('fees', 'NOUN'),
#  ('and', 'CONJ'),
#  ('payments', 'NOUN'),
#  ('to', 'PRT'),
#  ('banks', 'NOUN'),
#  ('incurred', 'VERB'),
#  ('*', 'X'),
#  ('during', 'ADP'),
#  ('various', 'ADJ'),
#  ('swaps', 'NOUN'),
#  ('dealings', 'NOUN'),
#  ('.', '.'),
#  ('According', 'VERB'),
#  ('to', 'PRT'),
#  ('Ms.', 'NOUN'),
#  ('Poore', 'NOUN'),
#  (',', '.'),
#  ('Old-House', 'NOUN'),
#  ('Journal', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  (',', '.'),
#  ('her', 'PRON'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('printed', 'VERB'),
#  ('and', 'CONJ'),
#  ('sold', 'VERB'),
#  ('all', 'DET'),
#  ('copies', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('premiere', 'NOUN'),
#  ('issue', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('Mr.', 'NOUN'),
#  ('Barnum', 'NOUN'),
#  ('called', 'VERB'),
#  ('that', 'ADP'),
#  ('``', '.'),
#  ('a', 'DET'),
#  ("''", '.'),
#  ('scenario', 'NOUN'),
#  ('.', '.'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('specialists', 'NOUN'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('bold', 'ADJ'),
#  ('palace', 'NOUN'),
#  ('revolt', 'NOUN'),
#  (',', '.'),
#  ('began', 'VERB'),
#  ('shortly', 'ADV'),
#  ('after', 'ADP'),
#  ('Oct.', 'NOUN'),
#  ('13', 'NUM'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('corporate', 'ADJ'),
#  ('executives', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('companies', 'NOUN'),
#  ('whose', 'PRON'),
#  ('stock', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('is', 'VERB'),
#  ('listed', 'VERB'),
#  ('*-71', 'X'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('them', 'PRON'),
#  ('the', 'DET'),
#  ('exchange', 'NOUN'),
#  ('to', 'PRT'),
#  ('program', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('.', '.'),
#  ('Another', 'DET'),
#  ('proposed', 'VERB'),
#  ('reform', 'NOUN'),
#  ('is', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('program', 'NOUN'),
#  ('traders', 'NOUN'),
#  ('to', 'PRT'),
#  ('an', 'DET'),
#  ('``', '.'),
#  ('uptick', 'NOUN'),
#  ('rule', 'NOUN'),
#  ("''", '.'),
#  ('a', 'DET'),
#  ('reform', 'NOUN'),
#  ('*', 'X'),
#  ('after', 'ADP'),
#  ('the', 'DET'),
#  ('Great', 'NOUN'),
#  ('Crash', 'NOUN'),
#  ('of', 'ADP'),
#  ('1929', 'NUM'),
#  ('*T*-1', 'X'),
#  ('protects', 'VERB'),
#  ('against', 'ADP'),
#  ('stocks', 'NOUN'),
#  ('being', 'VERB'),
#  ('beaten', 'VERB'),
#  ('*-2', 'X'),
#  ('by', 'ADP'),
#  ('those', 'DET'),
#  ('seeking', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('from', 'ADP'),
#  ('lower', 'ADJ'),
#  ('prices', 'NOUN'),
#  (',', '.'),
#  ('namely', 'ADV'),
#  ('short', 'ADJ'),
#  ('sellers', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('Bush', 'NOUN'),
#  ('administration', 'NOUN'),
#  ("'s", 'PRT'),
#  ('nomination', 'NOUN'),
#  ('of', 'ADP'),
#  ('Clarence', 'NOUN'),
#  ('Thomas', 'NOUN'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('seat', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('federal', 'ADJ'),
#  ('appeals', 'NOUN'),
#  ('court', 'NOUN'),
#  ('here', 'ADV'),
#  ('received', 'VERB'),
#  ('a', 'DET'),
#  ('blow', 'NOUN'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('when', 'ADV'),
#  ('the', 'DET'),
#  ('Bar', 'NOUN'),
#  ('Association', 'NOUN'),
#  ('gave', 'VERB'),
#  ('Mr.', 'NOUN'),
#  ('Thomas', 'NOUN'),
#  ('only', 'ADV'),
#  ('a', 'DET'),
#  ('``', '.'),
#  ("''", '.'),
#  ('rating', 'NOUN'),
#  (',', '.'),
#  ('rather', 'ADV'),
#  ('than', 'ADP'),
#  ('``', '.'),
#  ('well', 'ADV'),
#  ('qualified', 'VERB'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Attorneys', 'NOUN'),
#  ('have', 'VERB'),
#  ('argued', 'VERB'),
#  ('since', 'ADP'),
#  ('1985', 'NUM'),
#  (',', '.'),
#  ('when', 'ADV'),
#  ('the', 'DET'),
#  ('law', 'NOUN'),
#  ('took', 'VERB'),
#  ('effect', 'NOUN'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('they', 'PRON'),
#  ('can', 'VERB'),
#  ('not', 'ADV'),
#  ('provide', 'VERB'),
#  ('information', 'NOUN'),
#  ('about', 'ADP'),
#  ('clients', 'NOUN'),
#  ('who', 'PRON'),
#  ('do', 'VERB'),
#  ("n't", 'ADV'),
#  ('wish', 'VERB'),
#  ('their', 'PRON'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('known', 'VERB'),
#  ('*-3', 'X'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('the', 'DET'),
#  ('Army', 'NOUN'),
#  ('Corps', 'NOUN'),
#  ('of', 'ADP'),
#  ('Engineers', 'NOUN'),
#  ('expects', 'VERB'),
#  ('the', 'DET'),
#  ('river', 'NOUN'),
#  ('level', 'NOUN'),
#  ('to', 'PRT'),
#  ('continue', 'VERB'),
#  ('*-1', 'X'),
#  ('falling', 'VERB'),
#  ('this', 'DET'),
#  ('month', 'NOUN'),
#  ('.', '.'),
#  ('Virginia', 'NOUN'),
#  (':', '.'),
#  ('The', 'DET'),
#  ('department', 'NOUN'),
#  ('previously', 'ADV'),
#  ('estimated', 'VERB'),
#  ('that', 'ADP'),
#  ('durable-goods', 'NOUN'),
#  ('orders', 'NOUN'),
#  ('fell', 'VERB'),
#  ('0.1', 'NUM'),
#  ('%', 'NOUN'),
#  ('in', 'ADP'),
#  ('September', 'NOUN'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('next', 'ADJ'),
#  ('step', 'NOUN'),
#  (',', '.'),
#  ('I', 'PRON'),
#  ('suspect', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('is', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('try', 'VERB'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('get', 'VERB'),
#  ('the', 'DET'),
#  ('law', 'NOUN'),
#  ('changed', 'VERB'),
#  ('.', '.'),
#  ('Thus', 'ADV'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('institution', 'NOUN'),
#  ('obligated', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('make', 'VERB'),
#  ('fixed-rate', 'ADJ'),
#  ('interest', 'NOUN'),
#  ('payments', 'NOUN'),
#  ('on', 'ADP'),
#  ('debt', 'NOUN'),
#  ('swaps', 'NOUN'),
#  ('the', 'DET'),
#  ('payments', 'NOUN'),
#  ('with', 'ADP'),
#  ('another', 'DET'),
#  ('making', 'VERB'),
#  ('floating-rate', 'ADJ'),
#  ('payments', 'NOUN'),
#  ('.', '.'),
#  ('Western', 'NOUN'),
#  ('Gas', 'NOUN'),
#  ('Resources', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  (',', '.'),
#  ('initial', 'ADJ'),
#  ('offering', 'NOUN'),
#  ('of', 'ADP'),
#  ('shares', 'NOUN'),
#  ('of', 'ADP'),
#  ('common', 'ADJ'),
#  ('stock', 'NOUN'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('which', 'DET'),
#  ('shares', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('sold', 'VERB'),
#  ('*-1', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('and', 'CONJ'),
#  ('shares', 'NOUN'),
#  ('*T*-2', 'X'),
#  ('by', 'ADP'),
#  ('a', 'DET'),
#  ('holder', 'NOUN'),
#  (',', '.'),
#  ('via', 'ADP'),
#  ('Prudential-Bache', 'NOUN'),
#  ('Capital', 'NOUN'),
#  ('Funding', 'NOUN'),
#  (',', '.'),
#  ('Smith', 'NOUN'),
#  ('Barney', 'NOUN'),
#  (',', '.'),
#  ('Harris', 'NOUN'),
#  ('Upham', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('Hanifen', 'NOUN'),
#  (',', '.'),
#  ('Imhoff', 'NOUN'),
#  ('Inc', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('his', 'PRON'),
#  ('ruling', 'NOUN'),
#  (',', '.'),
#  ('Judge', 'NOUN'),
#  ('Curry', 'NOUN'),
#  ('added', 'VERB'),
#  ('an', 'DET'),
#  ('additional', 'ADJ'),
#  ('$', '.'),
#  ('55', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('commission', 'NOUN'),
#  ("'s", 'PRT'),
#  ('.', '.'),
#  ('Moreover', 'ADV'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Japanese', 'ADJ'),
#  ('government', 'NOUN'),
#  (',', '.'),
#  ('now', 'ADV'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ("'s", 'PRT'),
#  ('largest', 'ADJ'),
#  ('aid', 'NOUN'),
#  ('donor', 'NOUN'),
#  (',', '.'),
#  ('is', 'VERB'),
#  ('pumping', 'VERB'),
#  ('far', 'ADV'),
#  ('assistance', 'NOUN'),
#  ('*ICH*-2', 'X'),
#  ('into', 'ADP'),
#  ('the', 'DET'),
#  ('region', 'NOUN'),
#  ('than', 'ADP'),
#  ('the', 'DET'),
#  ('U.S.', 'NOUN'),
#  ('is', 'VERB'),
#  ('*?*', 'X'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Florio', 'NOUN'),
#  ('lying', 'VERB'),
#  (',', '.'),
#  ("''", '.'),
#  ('the', 'DET'),
#  ('voice', 'NOUN'),
#  ('goes', 'VERB'),
#  (',', '.'),
#  ('because', 'ADP'),
#  ('``', '.'),
#  ('the', 'DET'),
#  ('barrel', 'NOUN'),
#  ('on', 'ADP'),
#  ('Courter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('...', '.'),
#  ('contained', 'VERB'),
#  ('heating', 'NOUN'),
#  ('oil', 'NOUN'),
#  (',', '.'),
#  ('was', 'VERB'),
#  ('*-1', 'X'),
#  ('up', 'PRT'),
#  ('and', 'CONJ'),
#  ('caused', 'VERB'),
#  ('no', 'DET'),
#  ('pollution', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('resulting', 'VERB'),
#  ('company', 'NOUN'),
#  ('would', 'VERB'),
#  ('be', 'VERB'),
#  ('the', 'DET'),
#  ('largest', 'ADJ'),
#  ('forest-products', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ('with', 'ADP'),
#  ('sales', 'NOUN'),
#  ('of', 'ADP'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('$', '.'),
#  ('13', 'NUM'),
#  ('billion', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('Stadium', 'NOUN'),
#  ('boosters', 'NOUN'),
#  ('claim', 'VERB'),
#  ('that', 'ADP'),
#  ('without', 'ADP'),
#  ('public', 'ADJ'),
#  ('money', 'NOUN'),
#  ('they', 'PRON'),
#  ('would', 'VERB'),
#  ('never', 'ADV'),
#  ('be', 'VERB'),
#  ('built', 'VERB'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ('We', 'PRON'),
#  ('must', 'VERB'),
#  ('be', 'VERB'),
#  ('very', 'ADV'),
#  ('cautious', 'ADJ'),
#  ('about', 'ADP'),
#  ('*', 'X'),
#  ('labeling', 'VERB'),
#  ('investors', 'NOUN'),
#  ('as', 'ADP'),
#  ('``', '.'),
#  ('long-term', 'ADJ'),
#  ("''", '.'),
#  ('or', 'CONJ'),
#  ('``', '.'),
#  ('short-term', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('McDermott', 'NOUN'),
#  ('International', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('its', 'PRON'),
#  ('&', 'CONJ'),
#  ('Wilcox', 'NOUN'),
#  ('unit', 'NOUN'),
#  ('completed', 'VERB'),
#  ('the', 'DET'),
#  ('sale', 'NOUN'),
#  ('of', 'ADP'),
#  ('its', 'PRON'),
#  ('Bailey', 'NOUN'),
#  ('Controls', 'NOUN'),
#  ('Operations', 'NOUN'),
#  ('to', 'PRT'),
#  ('Finmeccanica', 'NOUN'),
#  ('S.p', 'NOUN'),
#  ('.', '.'),
#  ('A.', 'NOUN'),
#  ('for', 'ADP'),
#  ('$', '.'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Who', 'PRON'),
#  ('*T*-1', 'X'),
#  ('really', 'ADV'),
#  ('lying', 'VERB'),
#  ('?', '.'),
#  ("''", '.'),
#  ('asks', 'VERB'),
#  ('*T*-2', 'X'),
#  ('a', 'DET'),
#  ('female', 'ADJ'),
#  ('voice', 'NOUN'),
#  ('.', '.'),
#  ('Meanwhile', 'ADV'),
#  (',', '.'),
#  ('business', 'NOUN'),
#  ('and', 'CONJ'),
#  ('government', 'NOUN'),
#  ('leaders', 'NOUN'),
#  ('the', 'DET'),
#  ('computer', 'NOUN'),
#  ('makers', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('about', 'ADP'),
#  ('the', 'DET'),
#  ('broader', 'ADJ'),
#  ('statement', 'NOUN'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('companies', 'NOUN'),
#  ("'", 'PRT'),
#  ('actions', 'NOUN'),
#  ('make', 'VERB'),
#  ('*T*-1', 'X'),
#  ('about', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('cutthroat', 'ADJ'),
#  ('pricing', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  (',', '.'),
#  ('Wells', 'NOUN'),
#  ('Fargo', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  ('of', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('launched', 'VERB'),
#  ('the', 'DET'),
#  ('Gold', 'NOUN'),
#  ('Account', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('included', 'VERB'),
#  ('free', 'ADJ'),
#  ('checking', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('credit', 'NOUN'),
#  ('card', 'NOUN'),
#  (',', '.'),
#  ('box', 'NOUN'),
#  ('and', 'CONJ'),
#  ('travelers', 'NOUN'),
#  ('checks', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('3', 'NUM'),
#  ('*U*', 'X'),
#  ('monthly', 'ADJ'),
#  ('fee', 'NOUN'),
#  ('.', '.'),
#  ('*-1', 'X'),
#  ('Asked', 'VERB'),
#  ('*-2', 'X'),
#  ('whether', 'ADP'),
#  ('the', 'DET'),
#  ('bidding', 'NOUN'),
#  ('flap', 'NOUN'),
#  ('would', 'VERB'),
#  ('hurt', 'VERB'),
#  ('relations', 'NOUN'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Yamamoto', 'NOUN'),
#  ('said', 'VERB'),
#  (',', '.'),
#  ('``', '.'),
#  ('this', 'DET'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('a', 'DET'),
#  ('minus', 'NOUN'),
#  ('factor', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('For', 'ADP'),
#  ('the', 'DET'),
#  ('Agency', 'NOUN'),
#  ('for', 'ADP'),
#  ('International', 'NOUN'),
#  ('Development', 'NOUN'),
#  (',', '.'),
#  ('appropriators', 'NOUN'),
#  ('approved', 'VERB'),
#  ('$', '.'),
#  ('200', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('secondary', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('under', 'ADP'),
#  ('an', 'DET'),
#  ('expanded', 'VERB'),
#  ('credit', 'NOUN'),
#  ('insurance', 'NOUN'),
#  ('program', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('total', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('Overseas', 'NOUN'),
#  ('Private', 'NOUN'),
#  ('Investment', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('are', 'VERB'),
#  ('increased', 'VERB'),
#  ('*-3', 'X'),
#  ('by', 'ADP'),
#  ('$', '.'),
#  ('40', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('over', 'ADP'),
#  ('fiscal', 'ADJ'),
#  ('1989', 'NUM'),
#  ('as', 'ADP'),
#  ('part', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('Poland', 'NOUN'),
#  ('package', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('both', 'DET'),
#  ('cases', 'NOUN'),
#  (',', '.'),
#  ('NEC', 'NOUN'),
#  ('lost', 'VERB'),
#  ('the', 'DET'),
#  ('contract', 'NOUN'),
#  ('to', 'PRT'),
#  ('Fujitsu', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('made', 'VERB'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('bid', 'NOUN'),
#  ('and', 'CONJ'),
#  ('won', 'VERB'),
#  ('a', 'DET'),
#  ('lottery', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Cosby', 'NOUN'),
#  ("''", '.'),
#  ('is', 'VERB'),
#  ('down', 'ADV'),
#  ('a', 'DET'),
#  ('full', 'ADJ'),
#  ('ratings', 'NOUN'),
#  ('point', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('week', 'NOUN'),
#  ('of', 'ADP'),
#  ('Oct.', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('week', 'NOUN'),
#  ('a', 'DET'),
#  ('year', 'NOUN'),
#  (',', '.'),
#  ('according', 'VERB'),
#  ('to', 'PRT'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('Despite', 'ADP'),
#  ('the', 'DET'),
#  ('Supreme', 'NOUN'),
#  ('Court', 'NOUN'),
#  ("'s", 'PRT'),
#  ('refusal', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('hear', 'VERB'),
#  ('the', 'DET'),
#  ('case', 'NOUN'),
#  (',', '.'),
#  ('there', 'DET'),
#  ('are', 'VERB'),
#  ('serious', 'ADJ'),
#  ('constitutional', 'ADJ'),
#  ('issues', 'NOUN'),
#  ('of', 'ADP'),
#  ('due', 'ADJ'),
#  ('process', 'NOUN'),
#  ('and', 'CONJ'),
#  ('takings', 'NOUN'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('defendants', 'NOUN'),
#  ('.', '.'),
#  ('And', 'CONJ'),
#  ('some', 'DET'),
#  ('grain', 'NOUN'),
#  ('analysts', 'NOUN'),
#  ('are', 'VERB'),
#  ('predicting', 'VERB'),
#  ('that', 'ADP'),
#  ('corn', 'NOUN'),
#  ('prices', 'NOUN'),
#  ('might', 'VERB'),
#  ('this', 'DET'),
#  ('month', 'NOUN'),
#  ('as', 'ADP'),
#  ('exporters', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('find', 'VERB'),
#  ('enough', 'ADV'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('crop', 'NOUN'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('to', 'PRT'),
#  ('meet', 'VERB'),
#  ('their', 'PRON'),
#  ('obligations', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('Soviets', 'NOUN'),
#  ('.', '.'),
#  ('Still', 'ADV'),
#  ('is', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Sony', 'NOUN'),
#  ("'s", 'PRT'),
#  ('effort', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('hire', 'VERB'),
#  ('producers', 'NOUN'),
#  ('Jon', 'NOUN'),
#  ('Peters', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Peter', 'NOUN'),
#  ('Guber', 'NOUN'),
#  ('to', 'PRT'),
#  ('run', 'VERB'),
#  ('the', 'DET'),
#  ('studio', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('if', 'ADP'),
#  ('Columbia', 'NOUN'),
#  ('could', 'VERB'),
#  ('keep', 'VERB'),
#  ('its', 'PRON'),
#  ('junk', 'NOUN'),
#  ('bonds', 'NOUN'),
#  ('separate', 'ADJ'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('thrift', 'NOUN'),
#  ('they', 'PRON'),
#  ('mature', 'VERB'),
#  ('--', '.'),
#  ('at', 'ADP'),
#  ('full', 'ADJ'),
#  ('value', 'NOUN'),
#  (',', '.'),
#  ('unless', 'ADP'),
#  ('the', 'DET'),
#  ('issuer', 'NOUN'),
#  ('goes', 'VERB'),
#  ('or', 'CONJ'),
#  ('--', '.'),
#  ('the', 'DET'),
#  ('junk', 'NOUN'),
#  ('portfolio', 'NOUN'),
#  ('might', 'VERB'),
#  ('do', 'VERB'),
#  ('.', '.'),
#  ('For', 'ADP'),
#  ('some', 'DET'),
#  ('time', 'NOUN'),
#  (',', '.'),
#  ('banks', 'NOUN'),
#  ('have', 'VERB'),
#  ('been', 'VERB'),
#  ('packages', 'NOUN'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('demographic', 'ADJ'),
#  ('segment', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('highest', 'ADJ'),
#  ('savings', 'NOUN'),
#  ('.', '.'),
#  ('Cray', 'NOUN'),
#  ('Research', 'NOUN'),
#  ('indicated', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('survival', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('spinoff', 'NOUN'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-1', 'X'),
#  ('is', 'VERB'),
#  ('developing', 'VERB'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('supercomputer', 'NOUN'),
#  (',', '.'),
#  ('heavily', 'ADV'),
#  ('on', 'ADP'),
#  ('its', 'PRON'),
#  ('chairman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('chief', 'NOUN'),
#  ('designer', 'NOUN'),
#  (',', '.'),
#  ('Seymour', 'NOUN'),
#  ('Cray', 'NOUN'),
#  ('.', '.'),
#  ('Congress', 'NOUN'),
#  ('learned', 'VERB'),
#  ('during', 'ADP'),
#  ('the', 'DET'),
#  ('Reagan', 'NOUN'),
#  ('administration', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('could', 'VERB'),
#  ('the', 'DET'),
#  ('branch', 'NOUN'),
#  ('by', 'ADP'),
#  ('*-1', 'X'),
#  ('uttering', 'VERB'),
#  ('again', 'ADV'),
#  ('and', 'CONJ'),
#  ('again', 'ADV'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('seven', 'NUM'),
#  ('words', 'NOUN'),
#  (':', '.'),
#  ('``', '.'),
#  (',', '.'),
#  ('no', 'DET'),
#  ('funds', 'NOUN'),
#  ('shall', 'VERB'),
#  ('be', 'VERB'),
#  ('spent', 'VERB'),
#  ('*-48', 'X'),
#  ('...', '.'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Then', 'ADV'),
#  ('*', 'X'),
#  ('send', 'VERB'),
#  ('your', 'PRON'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('savings', 'NOUN'),
#  ('institution', 'NOUN'),
#  ('has', 'VERB'),
#  ('taken', 'VERB'),
#  ('a', 'DET'),
#  ('bad', 'ADJ'),
#  ('rap', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('press', 'NOUN'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('its', 'PRON'),
#  ('line', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('other', 'ADJ'),
#  ('concern', 'NOUN'),
#  ('was', 'VERB'),
#  ("n't", 'ADV'),
#  ('identified', 'VERB'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('Stronach', 'NOUN'),
#  (',', '.'),
#  ('founder', 'NOUN'),
#  ('and', 'CONJ'),
#  ('controlling', 'VERB'),
#  ('shareholder', 'NOUN'),
#  ('of', 'ADP'),
#  ('Magna', 'NOUN'),
#  (',', '.'),
#  ('resigned', 'VERB'),
#  ('as', 'ADP'),
#  ('chief', 'NOUN'),
#  ('executive', 'NOUN'),
#  ('officer', 'NOUN'),
#  ('last', 'ADJ'),
#  ('year', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('seek', 'VERB'),
#  (',', '.'),
#  ('unsuccessfully', 'ADV'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('seat', 'NOUN'),
#  ('in', 'ADP'),
#  ('Canada', 'NOUN'),
#  ("'s", 'PRT'),
#  ('Parliament', 'NOUN'),
#  ('.', '.'),
#  ('60', 'NUM'),
#  ('million', 'NUM'),
#  ('Swiss', 'ADJ'),
#  ('francs', 'NOUN'),
#  ('of', 'ADP'),
#  ('privately', 'ADV'),
#  ('placed', 'VERB'),
#  ('convertible', 'ADJ'),
#  ('notes', 'NOUN'),
#  ('due', 'ADJ'),
#  ('Dec.', 'NOUN'),
#  ('31', 'NUM'),
#  (',', '.'),
#  ('1993', 'NUM'),
#  (',', '.'),
#  ('with', 'ADP'),
#  ('a', 'DET'),
#  ('fixed', 'VERB'),
#  ('0.25', 'NUM'),
#  ('%', 'NOUN'),
#  ('coupon', 'NOUN'),
#  ('at', 'ADP'),
#  ('par', 'NOUN'),
#  ('via', 'ADP'),
#  ('Union', 'NOUN'),
#  ('Bank', 'NOUN'),
#  ('of', 'ADP'),
#  ('Switzerland', 'NOUN'),
#  ('.', '.'),
#  ('It', 'PRON'),
#  ('also', 'ADV'),
#  ('would', 'VERB'),
#  ('an', 'DET'),
#  ('system', 'NOUN'),
#  ('for', 'ADP'),
#  ('*', 'X'),
#  ...]

# %% [markdown]
# ### Checking the accuracy of Viterbi_modification_3

# %%
accuracy = len(Matched_tags_Viterbi_modified_3)/len(modified_viterbi_3)
accuracy
# Out:
# 0.9315899581589958

# %% [markdown]
# **Observation** - The accuracy has not improved much in Viterbi_modification_3. It is 92.78% which is less than Viterbi_modification_1 and Viterbi_modification_2 and high than vanilla viterbi.

# %%
new_row = {'Algorithm':' Viterbi_modification_3(handling emission probability)', 'Accuracy':accuracy}
Accuracy_df = Accuracy_df.append(new_row, ignore_index=True)
Accuracy_df
# Out:
#                                            Algorithm  Accuracy
# 0                                    Vannila Viterbi  0.895816
# 1          Viterbi_modification_1(commonly used tag)  0.930962
# 2                 Viterbi_modification_2(rule-based)  0.938912
# 3   Viterbi_modification_3(handling emission prob...  0.931590

# %% [markdown]
# ### Words that have incorrect tags

# %%
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(modified_viterbi_3, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[('$', '.'), (('55-a-share', 'NOUN'), ('55-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('bid', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [(',', '.'), (('steps', 'NOUN'), ('steps', 'VERB'))],
#  [('.', '.'), (('Already', 'NOUN'), ('Already', 'ADV'))],
#  [('her', 'PRON'), (('publishing', 'VERB'), ('publishing', 'NOUN'))],
#  [('all', 'DET'), (('126,000', 'NOUN'), ('126,000', 'NUM'))],
#  [('a', 'DET'), (('worst-case', 'NOUN'), ('worst-case', 'ADJ'))],
#  [('to', 'PRT'), (('telephone', 'NOUN'), ('telephone', 'VERB'))],
#  [('them', 'PRON'), (('pressure', 'NOUN'), ('pressure', 'VERB'))],
#  [('to', 'PRT'), (('ban', 'NOUN'), ('ban', 'VERB'))],
#  [('traders', 'NOUN'), (('answer', 'NOUN'), ('answer', 'VERB'))],
#  [('reform', 'NOUN'), (('instituted', 'NOUN'), ('instituted', 'VERB'))],
#  [('1929', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('being', 'VERB'), (('relentlessly', 'X'), ('relentlessly', 'ADV'))],
#  [('*-2', 'X'), (('downward', 'ADJ'), ('downward', 'ADV'))],
#  [('to', 'PRT'), (('profit', 'NOUN'), ('profit', 'VERB'))],
#  [('the', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('``', '.'), (('qualified', 'VERB'), ('qualified', 'ADJ'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('who', 'PRON'), (('*T*-127', 'VERB'), ('*T*-127', 'X'))],
#  [('their', 'PRON'), (('identities', 'VERB'), ('identities', 'NOUN'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('of', 'ADP'), (('3,250,000', 'NOUN'), ('3,250,000', 'NUM'))],
#  [('which', 'DET'), (('3,040,000', 'NOUN'), ('3,040,000', 'NUM'))],
#  [('and', 'CONJ'), (('210,000', 'NOUN'), ('210,000', 'NUM'))],
#  [("'s", 'PRT'), (('calculations', 'VERB'), ('calculations', 'NOUN'))],
#  [('far', 'ADV'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('Florio', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('goes', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [("'s", 'PRT'), (('land', 'VERB'), ('land', 'NOUN'))],
#  [('was', 'VERB'), (('cleaned', 'X'), ('cleaned', 'VERB'))],
#  [('with', 'ADP'), (('combined', 'ADJ'), ('combined', 'VERB'))],
#  [('its', 'PRON'), (('Babcock', 'VERB'), ('Babcock', 'NOUN'))],
#  [('$', '.'), (('295', 'NOUN'), ('295', 'NUM'))],
#  [('*T*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('leaders', 'NOUN'), (('rebuked', 'NOUN'), ('rebuked', 'VERB'))],
#  [('and', 'CONJ'), (('fretted', 'NOUN'), ('fretted', 'VERB'))],
#  [('In', 'ADP'), (('1973', 'NOUN'), ('1973', 'NUM'))],
#  [('which', 'DET'), (('*T*-198', 'NOUN'), ('*T*-198', 'X'))],
#  [(',', '.'), (('safe-deposit', 'NOUN'), ('safe-deposit', 'ADJ'))],
#  [('hurt', 'VERB'), (('U.S.-Japan', 'X'), ('U.S.-Japan', 'ADJ'))],
#  [('expanded', 'VERB'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('which', 'DET'), (('*T*-139', 'NOUN'), ('*T*-139', 'X'))],
#  [('a', 'DET'), (('tie-breaking', 'NOUN'), ('tie-breaking', 'ADJ'))],
#  [('Oct.', 'NOUN'), (('2-8', 'NOUN'), ('2-8', 'NUM'))],
#  [('year', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('to', 'PRT'), (('A.C.', 'VERB'), ('A.C.', 'NOUN'))],
#  [('A.C.', 'NOUN'), (('Nielsen', 'X'), ('Nielsen', 'NOUN'))],
#  [('and', 'CONJ'), (('uncompensated', 'NOUN'), ('uncompensated', 'ADJ'))],
#  [('might', 'VERB'), (('gyrate', 'X'), ('gyrate', 'VERB'))],
#  [('exporters', 'NOUN'), (('scrounge', 'NOUN'), ('scrounge', 'VERB'))],
#  [('Still', 'ADV'), (('unresolved', 'VERB'), ('unresolved', 'ADJ'))],
#  [('thrift', 'NOUN'), (('till', 'NOUN'), ('till', 'ADP'))],
#  [('goes', 'VERB'), (('bust', 'X'), ('bust', 'NOUN'))],
#  [('or', 'CONJ'), (('restructures', 'NOUN'), ('restructures', 'VERB'))],
#  [('do', 'VERB'), (('all', 'DET'), ('all', 'ADV'))],
#  [('all', 'ADV'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('been', 'VERB'), (('aiming', 'X'), ('aiming', 'VERB'))],
#  [('the', 'DET'), (('elderly', 'NOUN'), ('elderly', 'ADJ'))],
#  [(',', '.'), (('depends', 'NOUN'), ('depends', 'VERB'))],
#  [('could', 'VERB'), (('intimidate', 'X'), ('intimidate', 'VERB'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('``', '.'), (('Provided', 'NOUN'), ('Provided', 'VERB'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('your', 'PRON'), (('support', 'VERB'), ('support', 'NOUN'))],
#  [('institution', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-208', 'NOUN'), ('*T*-208', 'X'))],
#  [('its', 'PRON'), (('bottom', 'NOUN'), ('bottom', 'ADJ'))],
#  [('would', 'VERB'), (('junk', 'NOUN'), ('junk', 'VERB'))],
#  [('an', 'DET'), (('innovative', 'NOUN'), ('innovative', 'ADJ'))],
#  [('innovative', 'ADJ'), (('market-based', 'NOUN'), ('market-based', 'ADJ'))],
#  [('*', 'X'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [(':', '.'), (('Financially', 'NOUN'), ('Financially', 'ADV'))],
#  [('its', 'PRON'), (('moments', 'VERB'), ('moments', 'NOUN'))],
#  [('buying', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('have', 'VERB'), (('escalated', 'X'), ('escalated', 'VERB'))],
#  [('%', 'NOUN'), (('holding', 'VERB'), ('holding', 'NOUN'))],
#  [("'s", 'PRT'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('Dec.', 'NOUN'), (('2-3', 'NOUN'), ('2-3', 'NUM'))],
#  [('was', 'VERB'), (('116.9', 'X'), ('116.9', 'NUM'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('of', 'ADP'), (('112.9', 'NOUN'), ('112.9', 'NUM'))],
#  [('of', 'ADP'), (('120.7', 'NOUN'), ('120.7', 'NUM'))],
#  [('yield', 'VERB'), (('7.65', 'X'), ('7.65', 'NUM'))],
#  [('drifted', 'VERB'), (('lower', 'ADJ'), ('lower', 'ADV'))],
#  [('lower', 'ADV'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('U.S.', 'NOUN'), (('purchasing', 'VERB'), ('purchasing', 'NOUN'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('*-2', 'X'), (('successfully', 'VERB'), ('successfully', 'ADV'))],
#  [('successfully', 'ADV'), (('mobilizing', 'X'), ('mobilizing', 'VERB'))],
#  [('their', 'PRON'), (('tormentors', 'VERB'), ('tormentors', 'NOUN'))],
#  [('said', 'VERB'), (('repeatedly', 'X'), ('repeatedly', 'ADV'))],
#  [('stay', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('issue', 'NOUN'), (('trades', 'NOUN'), ('trades', 'VERB'))],
#  [('its', 'PRON'), (('face', 'VERB'), ('face', 'NOUN'))],
#  [('Association', 'NOUN'), (('leapt', 'NOUN'), ('leapt', 'VERB'))],
#  [('leapt', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('has', 'VERB'), (('instituted', 'X'), ('instituted', 'VERB'))],
#  [('effective', 'ADJ'),
#   (('search-and-seizure', 'NOUN'), ('search-and-seizure', 'ADJ'))],
#  [('to', 'PRT'), (('aid', 'NOUN'), ('aid', 'VERB'))],
#  [('system', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('soared', 'VERB'), (('higher', 'ADJ'), ('higher', 'ADV'))],
#  [('Cataracts', 'NOUN'), (('refer', 'NOUN'), ('refer', 'VERB'))],
#  [('a', 'DET'), (('needy', 'NOUN'), ('needy', 'ADJ'))],
#  [('loan', 'NOUN'), (('solvent', 'NOUN'), ('solvent', 'ADJ'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('almost', 'ADV'), (('over', 'ADP'), ('over', 'ADJ'))],
#  [('by', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('to', 'PRT'), (('8.75', 'VERB'), ('8.75', 'NUM'))],
#  [('has', 'VERB'), (('shown', 'X'), ('shown', 'VERB'))],
#  [('default', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('a', 'DET'), (('richer', 'NOUN'), ('richer', 'ADJ'))],
#  [('the', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('and', 'CONJ'), (('galvanized', 'NOUN'), ('galvanized', 'ADJ'))],
#  [('galvanized', 'ADJ'), (('coated', 'NOUN'), ('coated', 'VERB'))],
#  [('than', 'ADP'), (('lower-priced', 'NOUN'), ('lower-priced', 'ADJ'))],
#  [('lower-priced', 'ADJ'), (('structural', 'NOUN'), ('structural', 'ADJ'))],
#  [('COLLECTING', 'NOUN'), (('gains', 'NOUN'), ('gains', 'VERB'))],
#  [('a', 'DET'), (('valuable', 'NOUN'), ('valuable', 'ADJ'))],
#  [('powers', 'NOUN'), (('works', 'NOUN'), ('works', 'VERB'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('about', 'ADP'), (('shrinking', 'NOUN'), ('shrinking', 'VERB'))],
#  [('in', 'ADP'), (('super-absorbent', 'NOUN'), ('super-absorbent', 'ADJ'))],
#  [('some', 'DET'), (('light', 'ADJ'), ('light', 'NOUN'))],
#  [('the', 'DET'), (('dark', 'NOUN'), ('dark', 'ADJ'))],
#  [('where', 'ADV'), (('high-stakes', 'VERB'), ('high-stakes', 'ADJ'))],
#  [('has', 'VERB'), (('enhanced', 'X'), ('enhanced', 'VERB'))],
#  [('is', 'VERB'), (('wrestling', 'X'), ('wrestling', 'VERB'))],
#  [('especially', 'ADV'), (('intelligent', 'VERB'), ('intelligent', 'ADJ'))],
#  [('temporarily', 'ADV'), (('insane', 'VERB'), ('insane', 'ADJ'))],
#  [('movie', 'NOUN'), (('ends', 'NOUN'), ('ends', 'VERB'))],
#  [('anything', 'NOUN'), (('whimsical', 'NOUN'), ('whimsical', 'ADJ'))],
#  [('or', 'CONJ'), (('enviable', 'NOUN'), ('enviable', 'ADJ'))],
#  [(',', '.'), (('beaten', 'VERB'), ('beaten', 'ADJ'))],
#  [("'s", 'PRT'), (('Kingsbridge', 'VERB'), ('Kingsbridge', 'NOUN'))],
#  [('$', '.'), (('45-a-share', 'NOUN'), ('45-a-share', 'ADJ'))],
#  [('its', 'PRON'), (('Eveready', 'VERB'), ('Eveready', 'NOUN'))],
#  [('a', 'DET'), (('Scandinavian', 'NOUN'), ('Scandinavian', 'ADJ'))],
#  [('$', '.'), (('2.44', 'NOUN'), ('2.44', 'NUM'))],
#  [('``', '.'), (('Little', 'ADV'), ('Little', 'ADJ'))],
#  [('Little', 'ADJ'), (('wonder', 'VERB'), ('wonder', 'NOUN'))],
#  [('fired', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('its', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('is', 'VERB'), (('discontinuing', 'X'), ('discontinuing', 'VERB'))],
#  [('which', 'DET'), (('there', 'ADV'), ('there', 'DET'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'ADJ'))],
#  [('--', '.'), (('the', 'DET'), ('the', 'ADJ'))],
#  [('-LRB-', '.'), (('Fewer', 'NOUN'), ('Fewer', 'ADJ'))],
#  [('SDI', 'NOUN'), (('ideological', 'NOUN'), ('ideological', 'ADJ'))],
#  [('weapon', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-245', 'NOUN'), ('*T*-245', 'X'))],
#  [('can', 'VERB'), (('shoot', 'X'), ('shoot', 'VERB'))],
#  [('them', 'PRON'), (('down', 'ADV'), ('down', 'ADP'))],
#  [("'s", 'VERB'), (('imaginative', 'X'), ('imaginative', 'ADJ'))],
#  [('were', 'VERB'), (('granted', 'X'), ('granted', 'VERB'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('*ICH*-1', 'X'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('and', 'CONJ'), (('punish', 'NOUN'), ('punish', 'VERB'))],
#  [('which', 'DET'), (('*T*-147', 'NOUN'), ('*T*-147', 'X'))],
#  [('*T*-147', 'X'), (('measures', 'NOUN'), ('measures', 'VERB'))],
#  [('the', 'DET'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('of', 'ADP'), (('45.3', 'NOUN'), ('45.3', 'NUM'))],
#  [('a', 'DET'), (('stark', 'NOUN'), ('stark', 'ADJ'))],
#  [('traditional', 'ADJ'),
#   (('policy-making', 'NOUN'), ('policy-making', 'ADJ'))],
#  [('the', 'DET'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('only', 'ADJ'), (('forum', 'VERB'), ('forum', 'NOUN'))],
#  [('to', 'PRT'), (('debate', 'NOUN'), ('debate', 'VERB'))],
#  [('a', 'DET'), (('31-year-old', 'NOUN'), ('31-year-old', 'ADJ'))],
#  [('would', 'VERB'), (('like', 'ADP'), ('like', 'VERB'))],
#  [('trading', 'NOUN'), (('disappear', 'NOUN'), ('disappear', 'VERB'))],
#  [(',', '.'), (('Texas-based', 'NOUN'), ('Texas-based', 'ADJ'))],
#  [('System', 'NOUN'), (('210', 'NOUN'), ('210', 'NUM'))],
#  [('with', 'ADP'), (('512', 'NOUN'), ('512', 'NUM'))],
#  [('a', 'DET'), (('40-megabyte', 'NOUN'), ('40-megabyte', 'ADJ'))],
#  [('40-megabyte', 'ADJ'), (('hard', 'ADV'), ('hard', 'ADJ'))],
#  [('hard', 'ADJ'), (('disk', 'VERB'), ('disk', 'NOUN'))],
#  [('are', 'VERB'), (('stretching', 'X'), ('stretching', 'VERB'))],
#  [('their', 'PRON'), (('nets', 'VERB'), ('nets', 'NOUN'))],
#  [('and', 'CONJ'), (('wide', 'ADJ'), ('wide', 'ADV'))],
#  [('has', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('have', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('much', 'ADJ'), (('sympathy', 'VERB'), ('sympathy', 'NOUN'))],
#  [('.', '.'), (('Second', 'NOUN'), ('Second', 'ADJ'))],
#  [('That', 'DET'), (('attracts', 'NOUN'), ('attracts', 'VERB'))],
#  [('was', 'VERB'), (('kind', 'NOUN'), ('kind', 'ADJ'))],
#  [('and', 'CONJ'), (('playful', 'NOUN'), ('playful', 'ADJ'))],
#  [('was', 'VERB'), (('dreadful', 'X'), ('dreadful', 'ADJ'))],
#  [('her', 'PRON'), (('war-damaged', 'VERB'), ('war-damaged', 'ADJ'))],
#  [('her', 'PRON'), (('lover', 'VERB'), ('lover', 'NOUN'))],
#  [('called', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('were', 'VERB'), (('occupying', 'X'), ('occupying', 'VERB'))],
#  [('.', '.'), (('Back', 'NOUN'), ('Back', 'ADV'))],
#  [('squeezed', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('scientists', 'NOUN'), (('breathed', 'NOUN'), ('breathed', 'VERB'))],
#  [('a', 'DET'), (('collective', 'NOUN'), ('collective', 'ADJ'))],
#  [('*T*-1', 'X'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [("'", 'PRT'), (('potential', 'ADJ'), ('potential', 'NOUN'))],
#  [('.', '.'), (('b', 'NOUN'), ('b', 'X'))],
#  [('the', 'DET'), (('top-yielding', 'NOUN'), ('top-yielding', 'ADJ'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('of', 'ADP'), (('9.37', 'NOUN'), ('9.37', 'NUM'))],
#  [('from', 'ADP'), (('9.45', 'NOUN'), ('9.45', 'NUM'))],
#  [(',', '.'), (('comments', 'NOUN'), ('comments', 'VERB'))],
#  [('``', '.'), (('increases', 'NOUN'), ('increases', 'VERB'))],
#  [('will', 'VERB'), (('oversee', 'X'), ('oversee', 'VERB'))],
#  [('get', 'VERB'), (('across', 'ADP'), ('across', 'PRT'))],
#  [('a', 'DET'), (('razor-thin', 'NOUN'), ('razor-thin', 'ADJ'))],
#  [('go', 'VERB'), (('through', 'ADP'), ('through', 'PRT'))],
#  [('Beijing', 'NOUN'), (('food-shop', 'NOUN'), ('food-shop', 'ADJ'))],
#  [('sketching', 'VERB'), (('passers-by', 'X'), ('passers-by', 'NOUN'))],
#  [('Too', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('give', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('are', 'VERB'), (('purely', 'X'), ('purely', 'ADV'))],
#  [('the', 'DET'), (('37-year-old', 'NOUN'), ('37-year-old', 'ADJ'))],
#  [('her', 'PRON'), (('dismissal', 'VERB'), ('dismissal', 'NOUN'))],
#  [('its', 'PRON'), (('centennial', 'VERB'), ('centennial', 'NOUN'))],
#  [(',', '.'), (('The', 'DET'), ('The', 'NOUN'))],
#  [('will', 'VERB'), (('report', 'NOUN'), ('report', 'VERB'))],
#  [('century', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('has', 'VERB'), (('hunted', 'X'), ('hunted', 'VERB'))],
#  [('ran', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('*T*-14', 'X'), (('matters', 'NOUN'), ('matters', 'VERB'))],
#  [('doing', 'VERB'), (('fine', 'NOUN'), ('fine', 'ADV'))],
#  [('not', 'ADV'), (('unethical', 'VERB'), ('unethical', 'ADJ'))],
#  [('a', 'DET'), (('higher-salaried', 'NOUN'), ('higher-salaried', 'ADJ'))],
#  [('that', 'ADP'), (('non-farm', 'NOUN'), ('non-farm', 'ADJ'))],
#  [('by', 'ADP'), (('152,000', 'NOUN'), ('152,000', 'NUM'))],
#  [('EVERYONE', 'NOUN'), (('AGREES', 'NOUN'), ('AGREES', 'VERB'))],
#  [('be', 'VERB'), (('repaired', 'X'), ('repaired', 'VERB'))],
#  [('with', 'ADP'),
#   (('yttrium-containing', 'NOUN'), ('yttrium-containing', 'ADJ'))],
#  [('to', 'PRT'), (('liquid-nitrogen', 'VERB'), ('liquid-nitrogen', 'NOUN'))],
#  [('liquid-nitrogen', 'NOUN'),
#   (('temperature', 'X'), ('temperature', 'NOUN'))],
#  [('or', 'CONJ'), (('minus', 'NOUN'), ('minus', 'CONJ'))],
#  [('minus', 'CONJ'), (('321', 'NOUN'), ('321', 'NUM'))],
#  [('the', 'DET'), (('shaky', 'NOUN'), ('shaky', 'ADJ'))],
#  [('a', 'DET'), (('slowing', 'NOUN'), ('slowing', 'VERB'))],
#  [(':', '.'), (('day-care', 'NOUN'), ('day-care', 'ADJ'))],
#  [('day-care', 'ADJ'), (('centers', 'VERB'), ('centers', 'NOUN'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('is', 'VERB'), (('conducted', 'X'), ('conducted', 'VERB'))],
#  [('or', 'CONJ'), (('early', 'ADJ'), ('early', 'ADV'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('this', 'DET'), (('minute', 'ADJ'), ('minute', 'NOUN'))],
#  [('said', 'VERB'), (('universally', 'X'), ('universally', 'ADV'))],
#  [('its', 'PRON'), (('Fax', 'VERB'), ('Fax', 'NOUN'))],
#  [('to', 'PRT'), (('Ogilvy', 'VERB'), ('Ogilvy', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-84', 'VERB'), ('*T*-84', 'X'))],
#  [('for', 'ADP'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [(',', '.'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('will', 'VERB'), (('worsen', 'X'), ('worsen', 'VERB'))],
#  [('of', 'ADP'), (('specialized', 'NOUN'), ('specialized', 'VERB'))],
#  [('plant', 'NOUN'), (('engineering', 'NOUN'), ('engineering', 'VERB'))],
#  [('0', 'X'), (('Sandinista', 'VERB'), ('Sandinista', 'NOUN'))],
#  [('$', '.'), (('12.52', 'NOUN'), ('12.52', 'NUM'))],
#  [('$', '.'), (('11.95', 'NOUN'), ('11.95', 'NUM'))],
#  [('the', 'DET'), (('36-store', 'NOUN'), ('36-store', 'ADJ'))],
#  [('to', 'PRT'), (('free', 'ADJ'), ('free', 'VERB'))],
#  [('the', 'DET'), (('1990s', 'NUM'), ('1990s', 'NOUN'))],
#  [('the', 'DET'), (('smallest', 'NOUN'), ('smallest', 'ADJ'))],
#  [('which', 'DET'), (('*T*-162', 'NOUN'), ('*T*-162', 'X'))],
#  [('*T*-162', 'X'), (('costs', 'NOUN'), ('costs', 'VERB'))],
#  [('costs', 'VERB'), (('around', 'ADP'), ('around', 'ADV'))],
#  [('organizations', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('first', 'ADV'), (('touched', 'NOUN'), ('touched', 'VERB'))],
#  [('?', '.'), (('Preliminary', 'NOUN'), ('Preliminary', 'ADJ'))],
#  [("'s", 'PRT'), (('export-oriented', 'VERB'), ('export-oriented', 'ADJ'))],
#  [('will', 'VERB'), (('likely', 'ADJ'), ('likely', 'ADV'))],
#  [('likely', 'ADV'), (('trim', 'NOUN'), ('trim', 'VERB'))],
#  [('about', 'ADP'), (('275', 'NOUN'), ('275', 'NUM'))],
#  [('to', 'PRT'), (('350', 'VERB'), ('350', 'NUM'))],
#  [('than', 'ADP'), (('21,000', 'NOUN'), ('21,000', 'NUM'))],
#  [('insist', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('jumping', 'VERB'), (('in', 'ADP'), ('in', 'ADV'))],
#  [('The', 'DET'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('only', 'ADJ'), (('advice', 'VERB'), ('advice', 'NOUN'))],
#  [('party', 'NOUN'), (('late', 'ADJ'), ('late', 'ADV'))],
#  [('be', 'VERB'), (('ready', 'X'), ('ready', 'ADJ'))],
#  [('The', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('total', 'NOUN'), (('marks', 'NOUN'), ('marks', 'VERB'))],
#  [('company', 'NOUN'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'NOUN'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'VERB'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'X'), ('suitors', 'NOUN'))],
#  [('my', 'PRON'), (('wine-making', 'VERB'), ('wine-making', 'NOUN'))],
#  [('to', 'PRT'), (('single', 'ADJ'), ('single', 'VERB'))],
#  [('out', 'PRT'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('oldest', 'ADJ'), (('bell-ringing', 'NOUN'), ('bell-ringing', 'ADJ'))],
#  [('in', 'ADP'), (('1637', 'NOUN'), ('1637', 'NUM'))],
#  [('remains', 'VERB'), (('male-only', 'X'), ('male-only', 'ADJ'))],
#  [('fact', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-230', 'NOUN'), ('*T*-230', 'X'))],
#  [('*T*-230', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('particularly', 'ADV'), (('galling', 'VERB'), ('galling', 'ADJ'))],
#  [('the', 'DET'), (('sole', 'NOUN'), ('sole', 'ADJ'))],
#  [("'s", 'PRT'), (('Cathedral', 'VERB'), ('Cathedral', 'NOUN'))],
#  [('lobbyists', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [(',', '.'), (('320', 'NOUN'), ('320', 'NUM'))],
#  [('$', '.'), (('18.95', 'NOUN'), ('18.95', 'NUM'))],
#  [('in', 'ADP'), (('common', 'ADJ'), ('common', 'NOUN'))],
#  [('Hammond', 'NOUN'), (('worries', 'NOUN'), ('worries', 'VERB'))],
#  [('will', 'VERB'), (('diminish', 'X'), ('diminish', 'VERB'))],
#  [('the', 'DET'), (('East', 'NOUN'), ('East', 'ADJ'))],
#  [('East', 'ADJ'), (('Anglian', 'NOUN'), ('Anglian', 'ADJ'))],
#  [('group', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-223', 'NOUN'), ('*T*-223', 'X'))],
#  [('bells', 'NOUN'), (('pealing', 'NOUN'), ('pealing', 'VERB'))],
#  [('$', '.'), (('130.7', 'NOUN'), ('130.7', 'NUM'))],
#  [('*T*-1', 'X'), (('worries', 'NOUN'), ('worries', 'VERB'))],
#  [('.', '.'), (('Continuing', 'NOUN'), ('Continuing', 'VERB'))],
#  [('.', '.'), (('Traditionally', 'NOUN'), ('Traditionally', 'ADV'))],
#  [('*ICH*-1', 'X'), (('Gayle', 'VERB'), ('Gayle', 'NOUN'))],
#  [('incentive', 'NOUN'), (('pay', 'VERB'), ('pay', 'NOUN'))],
#  [('opened', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('a', 'DET'), (('can', 'VERB'), ('can', 'NOUN'))],
#  [('are', 'VERB'), (('betting', 'X'), ('betting', 'VERB'))],
#  [('``', '.'), (('evolved', 'NOUN'), ('evolved', 'VERB'))],
#  [('evolved', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('$', '.'), (('415', 'NOUN'), ('415', 'NUM'))],
#  [('*U*', 'X'), (('charge', 'VERB'), ('charge', 'NOUN'))],
#  [('for', 'ADP'), (('underperforming', 'NOUN'), ('underperforming', 'VERB'))],
#  [('end', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('been', 'VERB'), (('obsessed', 'X'), ('obsessed', 'VERB'))],
#  [('*-87', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('off', 'PRT'), (('drastically', 'VERB'), ('drastically', 'ADV'))]]

# %% [markdown]
# #### Evaluating tagging accuracy

# %%
columns = ['Words','Vanilla_Viterbi']
POS_df = pd.DataFrame(columns = columns)

for x in tagged_seq:
    new_row = {'Words':x[0], 'Vanilla_Viterbi':x[1]}
    POS_df = POS_df.append(new_row, ignore_index=True)
    
x = []
for i in modified_viterbi_1:
    x.append(i[1])
POS_df.insert(2, "Viterbi_modification_1", x, True)

x = []
for i in modified_viterbi_2:
    x.append(i[1])
POS_df.insert(3, "Viterbi_modification_2", x, True)

x = []
for i in modified_viterbi_3:
    x.append(i[1])
POS_df.insert(4, "Viterbi_modification_3", x, True)  
POS_df.head(100)
# Out:
#       Words Vanilla_Viterbi Viterbi_modification_1 Viterbi_modification_2  \
# 0       The             DET                    DET                    DET
# 1     offer            NOUN                   NOUN                   NOUN
# 2         ,               .                      .                      .
# 3     which             DET                    DET                    DET
# 4     *T*-2               X                      X                      X
# ..      ...             ...                    ...                    ...
# 95    began            VERB                   VERB                   VERB
# 96  shortly             ADV                    ADV                    ADV
# 97    after             ADP                    ADP                    ADP
# 98     Oct.            NOUN                   NOUN                   NOUN
# 99       13             NUM                    NUM                    NUM
#
#    Viterbi_modification_3
# 0                     DET
# 1                    NOUN
# 2                       .
# 3                     DET
# 4                       X
# ..                    ...
# 95                   VERB
# 96                    ADV
# 97                    ADP
# 98                   NOUN
# 99                    NUM
#
# [100 rows x 5 columns]

# %%
Performance_df = POS_df[(POS_df['Viterbi_modification_1'] != POS_df['Viterbi_modification_2']) & (POS_df['Viterbi_modification_2'] != POS_df['Viterbi_modification_3']) & (POS_df['Viterbi_modification_1'] != POS_df['Viterbi_modification_3']) & (POS_df['Vanilla_Viterbi'] != POS_df['Viterbi_modification_1']) & (POS_df['Vanilla_Viterbi'] != POS_df['Viterbi_modification_2'])& (POS_df['Vanilla_Viterbi'] != POS_df['Viterbi_modification_3'])]
Performance_df
# Out:
#              Words Vanilla_Viterbi Viterbi_modification_1  \
# 163   relentlessly            PRON                   NOUN
# 460        cleaned            PRON                   NOUN
# 1106     escalated            PRON                   NOUN
# 1302  successfully            PRON                   NOUN
# 1319    repeatedly            PRON                   NOUN
# 1486    instituted            PRON                   NOUN
# 1636         shown            PRON                   NOUN
# 1890      enhanced            PRON                   NOUN
# 2318       granted            PRON                   NOUN
# 3133        purely            PRON                   NOUN
# 3224        hunted            PRON                   NOUN
# 3381      repaired            PRON                   NOUN
# 3539     conducted            PRON                   NOUN
# 3617   universally            PRON                   NOUN
# 4054           350            PRON                   NOUN
# 4220     male-only            PRON                   NOUN
# 4732      obsessed            PRON                   NOUN
# 4775   drastically            PRON                   NOUN
#
#      Viterbi_modification_2 Viterbi_modification_3
# 163                     ADV                      X
# 460                    VERB                      X
# 1106                   VERB                      X
# 1302                    ADV                   VERB
# 1319                    ADV                      X
# 1486                   VERB                      X
# 1636                   VERB                      X
# 1890                   VERB                      X
# 2318                   VERB                      X
# 3133                    ADV                      X
# 3224                   VERB                      X
# 3381                   VERB                      X
# 3539                   VERB                      X
# 3617                    ADV                      X
# 4054                    NUM                   VERB
# 4220                    ADV                      X
# 4732                   VERB                      X
# 4775                    ADV                   VERB

# %% [markdown]
# **Observation** -  The above dataframe 'Performance_df' shows how the words has been tagged differently by each modifications of Viterbi.<br> <br>
# **'917'** tagged as **'NUM'** by rule-based(Viterbi_modification_2) whereas it as tagged incorrectly as ***'ADP'***,***NOUN*** and ***'DET'*** by others.<br> <br>
# **'flirted', 'burned', 'echoed' and 'expunged'** tagged as **'VERB'** by rule-based(Viterbi_modification_2) whereas it as tagged incorrectly as **'ADP'**,**'NOUN'** and **'X'** by others.<br> <br>

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
Accuracy_df
# Out:
#                                            Algorithm  Accuracy
# 0                                    Vannila Viterbi  0.895816
# 1          Viterbi_modification_1(commonly used tag)  0.930962
# 2                 Viterbi_modification_2(rule-based)  0.938912
# 3   Viterbi_modification_3(handling emission prob...  0.931590

# %% [markdown]
# **Comments on tagging accuracy:** The tagging accuracy is high in  Viterbi_modification_2(rule-based) than Viterbi_modification_1(commonly used tag) and Viterbi_modification_3. <br> <br>
# In case of  Viterbi_modification_1(commonly used tag) the unknown words has been tagged with 'NOUN'. The most common tag in training data is 'NOUN' hence the unknown words in the test data has been tagged as 'NOUN'. <br> <br>
# In case of  Viterbi_modification_2(rule-based) the unknown words has been tagged with some basic grammar rules.<br> <br>
# In case of  Viterbi_modification_3,if the emission probability is 0, it is added to a least constant and then multiplied with transition probability. <br> <br>
#
# All these 3 Viterbi modifications, shows a good accuracy compared to the Vanilla Viterbi algorithm.

# %% [markdown]
# ### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %% [markdown]
# Performance_df - This dataframe contains the words that has differnt tags assigned by Vanilla Viterbi, Viterbi_modification_1,Viterbi_modification_2 and Viterbi_modification_3.

# %%
Performance_df
# Out:
#              Words Vanilla_Viterbi Viterbi_modification_1  \
# 163   relentlessly            PRON                   NOUN
# 460        cleaned            PRON                   NOUN
# 1106     escalated            PRON                   NOUN
# 1302  successfully            PRON                   NOUN
# 1319    repeatedly            PRON                   NOUN
# 1486    instituted            PRON                   NOUN
# 1636         shown            PRON                   NOUN
# 1890      enhanced            PRON                   NOUN
# 2318       granted            PRON                   NOUN
# 3133        purely            PRON                   NOUN
# 3224        hunted            PRON                   NOUN
# 3381      repaired            PRON                   NOUN
# 3539     conducted            PRON                   NOUN
# 3617   universally            PRON                   NOUN
# 4054           350            PRON                   NOUN
# 4220     male-only            PRON                   NOUN
# 4732      obsessed            PRON                   NOUN
# 4775   drastically            PRON                   NOUN
#
#      Viterbi_modification_2 Viterbi_modification_3
# 163                     ADV                      X
# 460                    VERB                      X
# 1106                   VERB                      X
# 1302                    ADV                   VERB
# 1319                    ADV                      X
# 1486                   VERB                      X
# 1636                   VERB                      X
# 1890                   VERB                      X
# 2318                   VERB                      X
# 3133                    ADV                      X
# 3224                   VERB                      X
# 3381                   VERB                      X
# 3539                   VERB                      X
# 3617                    ADV                      X
# 4054                    NUM                   VERB
# 4220                    ADV                      X
# 4732                   VERB                      X
# 4775                    ADV                   VERB

# %% [markdown]
# **Observation** -  The above dataframe 'Performance_df' shows how the words has been tagged by each modifications of Viterbi.<br> <br>
# **Case 1 :'917' and '890'** tagged as **'NUM'** by rule-based(Viterbi_modification_2) whereas it as tagged incorrectly as ***'ADP'***,***NOUN*** and ***'DET'*** by others.
# **Case 2 :'flirted', 'burned', 'echoed' and 'expunged'** tagged as **'VERB'** by rule-based(Viterbi_modification_2) whereas it as tagged incorrectly as **'ADP'**,**'NOUN'** and **'X'** by others.<br> <br>
# **Case 3 : 'stringently' and 'politically'** tagged as **'ADV'** by rule-based(Viterbi_modification_2) whereas it as tagged incorrectly as **'ADP'**,**'NOUN'** and **'X'**/**VERB** by others.<br> <br>

# %% [markdown]
# **Conclusion:** From the above dataframe we can conclude that rule-based taggers (Viterbi_modification_2) tags most of the words correctly and shows good performance too.

# %% [markdown]
# ### Sample Sentences

# %% [markdown]
# Few sample sentences has been executed and words has been tagged using Vanilla Viterbi, Viterbi_modification_1,Viterbi_modification_2 and Viterbi_modification_3.

# %% [markdown]
# ### Sample Sentence 1

# %%
from nltk.tokenize import word_tokenize
sample_sentences = 'Android is a mobile operating system developed by Google.'
sample_sentences = word_tokenize(sample_sentences)
Vanilla_Viterbi = Viterbi(sample_sentences)

modification_1 = Viterbi_modification_1(sample_sentences)
modification_2 = Viterbi_modification_2(sample_sentences)
modification_3 = Viterbi_modification_3(sample_sentences)

columns = ['Words','Vanilla_Viterbi']
sample_sentence_df_1 = pd.DataFrame(columns = columns)

for x in Vanilla_Viterbi:
    new_row = {'Words':x[0], 'Vanilla_Viterbi':x[1]}
    sample_sentence_df_1 = sample_sentence_df_1.append(new_row, ignore_index=True)
    
x = []
for i in modification_1:
    x.append(i[1])
sample_sentence_df_1.insert(2, "Viterbi_modification_1", x, True)

x = []
for i in modification_2:
    x.append(i[1])
sample_sentence_df_1.insert(3, "Viterbi_modification_2", x, True)

x = []
for i in modification_3:
    x.append(i[1])
sample_sentence_df_1.insert(4, "Viterbi_modification_3", x, True)  
sample_sentence_df_1.head(100)
# Out:
#        Words Vanilla_Viterbi Viterbi_modification_1 Viterbi_modification_2  \
# 0    Android            PRON                   NOUN                   NOUN
# 1         is            VERB                   VERB                   VERB
# 2          a             DET                    DET                    DET
# 3     mobile             ADJ                    ADJ                    ADJ
# 4  operating            NOUN                   NOUN                   NOUN
# 5     system            NOUN                   NOUN                   NOUN
# 6  developed            VERB                   VERB                   VERB
# 7         by             ADP                    ADP                    ADP
# 8     Google            PRON                   NOUN                   NOUN
# 9          .               .                      .                      .
#
#   Viterbi_modification_3
# 0                   NOUN
# 1                   VERB
# 2                    DET
# 3                    ADJ
# 4                   NOUN
# 5                   NOUN
# 6                   VERB
# 7                    ADP
# 8                   NOUN
# 9                      .

# %% [markdown]
# ### Sample Sentence 2

# %%
from nltk.tokenize import word_tokenize
sample_sentences = 'Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013.'
sample_sentences = word_tokenize(sample_sentences)
Vanilla_Viterbi = Viterbi(sample_sentences)
sample_sentences
modification_1 = Viterbi_modification_1(sample_sentences)
modification_2 = Viterbi_modification_2(sample_sentences)
modification_3 = Viterbi_modification_3(sample_sentences)

columns = ['Words','Vanilla_Viterbi']
sample_sentence_df_2 = pd.DataFrame(columns = columns)

for x in Vanilla_Viterbi:
    new_row = {'Words':x[0], 'Vanilla_Viterbi':x[1]}
    sample_sentence_df_2 = sample_sentence_df_2.append(new_row, ignore_index=True)
    
x = []
for i in modification_1:
    x.append(i[1])
sample_sentence_df_2.insert(2, "Viterbi_modification_1", x, True)

x = []
for i in modification_2:
    x.append(i[1])
sample_sentence_df_2.insert(3, "Viterbi_modification_2", x, True)

x = []
for i in modification_3:
    x.append(i[1])
sample_sentence_df_2.insert(4, "Viterbi_modification_3", x, True)  
sample_sentence_df_2.head(100)
# Out:
#            Words Vanilla_Viterbi Viterbi_modification_1  \
# 0        Android            PRON                   NOUN
# 1            has            VERB                   VERB
# 2           been            VERB                   VERB
# 3            the             DET                    DET
# 4   best-selling             ADJ                    ADJ
# 5             OS            PRON                   NOUN
# 6      worldwide            PRON                   NOUN
# 7             on             ADP                    ADP
# 8    smartphones            PRON                   NOUN
# 9          since             ADP                    ADP
# 10          2011            PRON                   NOUN
# 11           and            CONJ                   CONJ
# 12            on             ADP                    ADP
# 13       tablets            NOUN                   NOUN
# 14         since             ADP                    ADP
# 15          2013            PRON                   NOUN
# 16             .               .                      .
#
#    Viterbi_modification_2 Viterbi_modification_3
# 0                    NOUN                   NOUN
# 1                    VERB                   VERB
# 2                    VERB                   VERB
# 3                     DET                    DET
# 4                     ADJ                    ADJ
# 5                    NOUN                   NOUN
# 6                    NOUN                   NOUN
# 7                     ADP                    ADP
# 8                    NOUN                   NOUN
# 9                     ADP                    ADP
# 10                    NUM                   NOUN
# 11                   CONJ                   CONJ
# 12                    ADP                    ADP
# 13                   NOUN                   NOUN
# 14                    ADP                    ADP
# 15                    NUM                   NOUN
# 16                      .                      .

# %% [markdown]
# ### Sample Sentence 3

# %%
from nltk.tokenize import word_tokenize
sample_sentences = 'Twitter is an online news and social networking service on which users post and interact with messages known as tweets.'
sample_sentences = word_tokenize(sample_sentences)
Vanilla_Viterbi = Viterbi(sample_sentences)
sample_sentences
modification_1 = Viterbi_modification_1(sample_sentences)
modification_2 = Viterbi_modification_2(sample_sentences)
modification_3 = Viterbi_modification_3(sample_sentences)

columns = ['Words','Vanilla_Viterbi']
sample_sentence_df_3 = pd.DataFrame(columns = columns)

for x in Vanilla_Viterbi:
    new_row = {'Words':x[0], 'Vanilla_Viterbi':x[1]}
    sample_sentence_df_3 = sample_sentence_df_3.append(new_row, ignore_index=True)
    
x = []
for i in modification_1:
    x.append(i[1])
sample_sentence_df_3.insert(2, "Viterbi_modification_1", x, True)

x = []
for i in modification_2:
    x.append(i[1])
sample_sentence_df_3.insert(3, "Viterbi_modification_2", x, True)

x = []
for i in modification_3:
    x.append(i[1])
sample_sentence_df_3.insert(4, "Viterbi_modification_3", x, True)  
sample_sentence_df_3.head(100)
# Out:
#          Words Vanilla_Viterbi Viterbi_modification_1 Viterbi_modification_2  \
# 0      Twitter            PRON                   NOUN                   NOUN
# 1           is            VERB                   VERB                   VERB
# 2           an             DET                    DET                    DET
# 3       online            PRON                   NOUN                   NOUN
# 4         news            NOUN                   NOUN                   NOUN
# 5          and            CONJ                   CONJ                   CONJ
# 6       social             ADJ                    ADJ                    ADJ
# 7   networking            NOUN                   NOUN                   NOUN
# 8      service            NOUN                   NOUN                   NOUN
# 9           on             ADP                    ADP                    ADP
# 10       which             DET                    DET                    DET
# 11       users            NOUN                   NOUN                   NOUN
# 12        post            NOUN                   NOUN                   NOUN
# 13         and            CONJ                   CONJ                   CONJ
# 14    interact            PRON                   NOUN                   NOUN
# 15        with             ADP                    ADP                    ADP
# 16    messages            PRON                   NOUN                   NOUN
# 17       known            VERB                   VERB                   VERB
# 18          as             ADP                    ADP                    ADP
# 19      tweets            PRON                   NOUN                   NOUN
# 20           .               .                      .                      .
#
#    Viterbi_modification_3
# 0                    NOUN
# 1                    VERB
# 2                     DET
# 3                    NOUN
# 4                    NOUN
# 5                    CONJ
# 6                     ADJ
# 7                    NOUN
# 8                    NOUN
# 9                     ADP
# 10                    DET
# 11                   NOUN
# 12                   NOUN
# 13                   CONJ
# 14                   NOUN
# 15                    ADP
# 16                   NOUN
# 17                   VERB
# 18                    ADP
# 19                   NOUN
# 20                      .

# %% [markdown]
# ### Sample Sentence 4

# %%
from nltk.tokenize import word_tokenize
sample_sentences = 'NASA invited social media users to experience the launch of ICESAT-2 Satellite.'
sample_sentences = word_tokenize(sample_sentences)
Vanilla_Viterbi = Viterbi(sample_sentences)
sample_sentences
modification_1 = Viterbi_modification_1(sample_sentences)
modification_2 = Viterbi_modification_2(sample_sentences)
modification_3 = Viterbi_modification_3(sample_sentences)

columns = ['Words','Vanilla_Viterbi']
sample_sentence_df_4 = pd.DataFrame(columns = columns)

for x in Vanilla_Viterbi:
    new_row = {'Words':x[0], 'Vanilla_Viterbi':x[1]}
    sample_sentence_df_4 = sample_sentence_df_4.append(new_row, ignore_index=True)
    
x = []
for i in modification_1:
    x.append(i[1])
sample_sentence_df_4.insert(2, "Viterbi_modification_1", x, True)

x = []
for i in modification_2:
    x.append(i[1])
sample_sentence_df_4.insert(3, "Viterbi_modification_2", x, True)

x = []
for i in modification_3:
    x.append(i[1])
sample_sentence_df_4.insert(4, "Viterbi_modification_3", x, True)  
sample_sentence_df_4.head(100)
# Out:
#          Words Vanilla_Viterbi Viterbi_modification_1 Viterbi_modification_2  \
# 0         NASA            PRON                   NOUN                   NOUN
# 1      invited            PRON                   NOUN                   VERB
# 2       social             ADJ                    ADJ                    ADJ
# 3        media            NOUN                   NOUN                   NOUN
# 4        users            NOUN                   NOUN                   NOUN
# 5           to             PRT                    PRT                    PRT
# 6   experience            NOUN                   NOUN                   NOUN
# 7          the             DET                    DET                    DET
# 8       launch            NOUN                   NOUN                   NOUN
# 9           of             ADP                    ADP                    ADP
# 10    ICESAT-2            PRON                   NOUN                   NOUN
# 11   Satellite            PRON                   NOUN                   NOUN
# 12           .               .                      .                      .
#
#    Viterbi_modification_3
# 0                    NOUN
# 1                    NOUN
# 2                     ADJ
# 3                    NOUN
# 4                    NOUN
# 5                     PRT
# 6                    NOUN
# 7                     DET
# 8                    NOUN
# 9                     ADP
# 10                   NOUN
# 11                   NOUN
# 12                      .

# %% [markdown]
# ### Sample Sentence 5

# %%
from nltk.tokenize import word_tokenize
sample_sentences = 'Show me the price of the flights leaving Atlanta at about 3 in the afternoon and arriving in San Francisco.'
sample_sentences = word_tokenize(sample_sentences)
Vanilla_Viterbi = Viterbi(sample_sentences)
sample_sentences
modification_1 = Viterbi_modification_1(sample_sentences)
modification_2 = Viterbi_modification_2(sample_sentences)
modification_3 = Viterbi_modification_3(sample_sentences)

columns = ['Words','Vanilla_Viterbi']
sample_sentence_df_5 = pd.DataFrame(columns = columns)

for x in Vanilla_Viterbi:
    new_row = {'Words':x[0], 'Vanilla_Viterbi':x[1]}
    sample_sentence_df_5 = sample_sentence_df_5.append(new_row, ignore_index=True)
    
x = []
for i in modification_1:
    x.append(i[1])
sample_sentence_df_5.insert(2, "Viterbi_modification_1", x, True)

x = []
for i in modification_2:
    x.append(i[1])
sample_sentence_df_5.insert(3, "Viterbi_modification_2", x, True)

x = []
for i in modification_3:
    x.append(i[1])
sample_sentence_df_5.insert(4, "Viterbi_modification_3", x, True)  
sample_sentence_df_5.head(100)
# Out:
#         Words Vanilla_Viterbi Viterbi_modification_1 Viterbi_modification_2  \
# 0        Show            NOUN                   NOUN                   NOUN
# 1          me            PRON                   PRON                   PRON
# 2         the             DET                    DET                    DET
# 3       price            NOUN                   NOUN                   NOUN
# 4          of             ADP                    ADP                    ADP
# 5         the             DET                    DET                    DET
# 6     flights            NOUN                   NOUN                   NOUN
# 7     leaving            VERB                   VERB                   VERB
# 8     Atlanta            NOUN                   NOUN                   NOUN
# 9          at             ADP                    ADP                    ADP
# 10      about             ADP                    ADP                    ADP
# 11          3             NUM                    NUM                    NUM
# 12         in             ADP                    ADP                    ADP
# 13        the             DET                    DET                    DET
# 14  afternoon            NOUN                   NOUN                   NOUN
# 15        and            CONJ                   CONJ                   CONJ
# 16   arriving            PRON                   NOUN                   NOUN
# 17         in             ADP                    ADP                    ADP
# 18        San            NOUN                   NOUN                   NOUN
# 19  Francisco            NOUN                   NOUN                   NOUN
# 20          .               .                      .                      .
#
#    Viterbi_modification_3
# 0                    NOUN
# 1                    PRON
# 2                     DET
# 3                    NOUN
# 4                     ADP
# 5                     DET
# 6                    NOUN
# 7                    VERB
# 8                    NOUN
# 9                     ADP
# 10                    ADP
# 11                    NUM
# 12                    ADP
# 13                    DET
# 14                   NOUN
# 15                   CONJ
# 16                   NOUN
# 17                    ADP
# 18                   NOUN
# 19                   NOUN
# 20                      .

# %% [markdown]
# **Observation** - Rule-based tagger (Viterbi_modification_2) has tagged all the words correctly compared to Vanilla Viterbi,Viterbi_modification_1 and Viterbi_modification_3
