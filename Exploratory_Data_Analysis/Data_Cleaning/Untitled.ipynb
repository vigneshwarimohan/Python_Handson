# %%
import pandas as pd
my_dict ={"SI":['A','A','A','A','A','B','B','B','B'],
         "Values":['x','y','x','t','y','e','r','t','y']}

df = pd.DataFrame(my_dict)
final = df.groupby("SI")["Values"].apply(",".join).reset_index()
final
# Out:
#   SI     Values
# 0  A  x,y,x,t,y
# 1  B    e,r,t,y

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_test_df = pd.read_csv("E:/GIT_Repository/Python/Exploratory_Data_Analysis/EDA_Interview_Practice/SGC/train_test.csv")
train_test_df
# Out:
#         asfasf  asfasf.1 asfasf.2  \
# 0            1         0        3
# 1  PassengerId  Survived   Pclass
# 2            2         1        1
# 3            3         1        3
# 4            4         1        1
# 5            5         0        3
# 6            6         0        3
# 7            7         0        1
#
#                                             asfasf.3    asfa twrwtrer  sgads  \
# 0                            Braund, Mr. Owen Harris    male       22      1
# 1                                               Name     Sex      Age  SibSp
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       38      1
# 3                             Heikkinen, Miss. Laina  female       26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       35      1
# 5                           Allen, Mr. William Henry    male       35      0
# 6                                   Moran, Mr. James    male      NaN      0
# ...

# %%
headers = train_test_df.iloc[1]
print(headers)
train_test_df  = pd.DataFrame(train_test_df.values[1:], columns=headers)
train_test_df
# Out:
# asfasf                            1
# asfasf.1                          0
# asfasf.2                          3
# asfasf.3    Braund, Mr. Owen Harris
# asfa                           male
# twrwtrer                         22
# sgads                             1
# sdfds                             0
# sdf                       A/5 21171
# sf                             7.25
# sdf.1                           NaN
# rgdh                              S
# Name: 0, dtype: object
# 0            1         0       3  \
# 0  PassengerId  Survived  Pclass
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
# 0                            Braund, Mr. Owen Harris    male   22      1  \
# 0                                               Name     Sex  Age  SibSp
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# ...

# %%
train1_test_df = pd.read_csv("E:/GIT_Repository/Python/Exploratory_Data_Analysis/EDA_Interview_Practice/SGC/train1.csv")
train1_test_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
